# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from imblearn.over_sampling import SMOTE 
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import GridSearchCV
import warnings
warnings.simplefilter(action='ignore', category=Warning)
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Dataset

# %%
d = pd.read_csv('/media/loop/Backup/vm/tos1/tcp/online/tcp.csv')
d = d[(d[['Resolution(w)']] != 0).all(axis=1)]
d.isnull().values.any()
# drop rows with missing values
d.dropna(inplace=True)
X=d.iloc[:, 13:265] 
#Y=d.iloc[:,11]
Y=d.loc[:,d.columns.isin(['Resolution(w)'])]

# %% [markdown]
# # Features

# %%
X.columns=(['DL_Th_avg_CW','UL_Th_avg_CW','DL_Th_avg_TW-1','UL_Th_avg_TW-1','DL_Th_avg_TW-3','UL_Th_avg_TW-3','DL_Th_avg_TW-5','UL_Th_avg_TW-5','DL_Th_avg_TW-10','UL_Th_avg_TW-10','DL_Th_avg_TW-20','UL_Th_avg_TW-20','DL_Th_avg_SW','UL_Th_avg_SW',
            'DL_Pkt-N_total_CW','UL_Pkt-N_total_CW','DL_Pkt-N_total_TW-1','UL_Pkt-N_total_TW-1','DL_Pkt-N_total_TW-3','UL_Pkt-N_total_TW-3','DL_Pkt-N_total_TW-5','UL_Pkt-N_total_TW-5','DL_Pkt-N_total_TW-10','UL_Pkt-N_total_TW-10','DL_Pkt-N_total_TW-20','UL_Pkt-N_total_TW-20','DL_Pkt-N_total_SW','UL_Pkt-N_total_SW',
            'DL_Pkt-N-g100_total_CW', 'UL_Pkt-N-g100_total_CW', 'DL_Pkt-N-g100_total_TW-1','UL_Pkt-N-g100_total_TW-1','DL_Pkt-N-g100_total_TW-3','UL_Pkt-N-g100_total_TW-3','DL_Pkt-N-g100_total_TW-5','UL_Pkt-N-g100_total_TW-5','DL_Pkt-N-g100_total_TW-10','UL_Pkt-N-g100_total_TW-10','DL_Pkt-N-g100_total_TW-20','UL_Pkt-N-g100_total_TW-20','DL_Pkt-N-g100_total_SW','UL_Pkt-N-g100_total_SW',
            'DL_IA_mean_CW','UL_IA_mean_CW','DL_IA_mean_TW-1','UL_IA_mean_TW-1','DL_IA_mean_TW-3','UL_IA_mean_TW-3','DL_IA_mean_TW-5','UL_IA_mean_TW-5','DL_IA_mean_TW-10','UL_IA_mean_TW-10','DL_IA_mean_TW-20','UL_IA_mean_TW-20','DL_IA_mean_SW','UL_IA_mean_SW',
            'DL_IA_medn_CW','UL_IA_medn_CW','DL_IA_medn_TW-1','UL_IA_medn_TW-1','DL_IA_medn_TW-3','UL_IA_medn_TW-3','DL_IA_medn_TW-5','UL_IA_medn_TW-5','DL_IA_medn_TW-10','UL_IA_medn_TW-10','DL_IA_medn_TW-20','UL_IA_medn_TW-20','DL_IA_med_SW','UL_IA_medn_SW',
            'DL_IA_std_CW','UL_IA_std_CW','DL_IA_std_TW-1','UL_IA_std_TW-1','DL_IA_std_TW-3','UL_IA_std_TW-3','DL_IA_std_TW-5','UL_IA_std_TW-5','DL_IA_std_TW-10','UL_IA_std_TW-10','DL_IA_std_TW-20','UL_IA_std_TW-20','DL_IA_std_SW','UL_IA_std_SW',
            'DL_IA_max_CW','UL_IA_max_CW','DL_IA_max_TW-1','UL_IA_max_TW-1','DL_IA_max_TW-3','UL_IA_max_TW-3','DL_IA_max_TW-5','UL_IA_max_TW-5','DL_IA_max_TW-10','UL_IA_max_TW-10','DL_IA_max_TW-20','UL_IA_max_TW-20','DL_IA_max_SW','UL_IA_max_SW',
            'DL_IA_min_CW','UL_IA_min_CW','DL_IA_min_TW-1','UL_IA_min_TW-1','DL_IA_min_TW-3','UL_IA_min_TW-3','DL_IA_min_TW-5','UL_IA_min_TW-5','DL_IA_min_TW-10','UL_IA_min_TW-10','DL_IA_min_TW-20','UL_IA_min_TW-20','DL_IA_min_SW','UL_IA_min_SW',
            'DL_Pkt-S_mean_CW','UL_Pkt-S_mean_CW','DL_Pkt-S_mean_TW-1','UL_Pkt-S_mean_TW-1','DL_Pkt-S_mean_TW-3','UL_Pkt-S_mean_TW-3','DL_Pkt-S_mean_TW-5','UL_Pkt-S_mean_TW-5','DL_Pkt-S_mean_TW-10','UL_Pkt-S_mean_TW-10','DL_Pkt-S_mean_TW-20','UL_Pkt-S_mean_TW-20','DL_Pkt-S_mean_SW','UL_Pkt-S_mean_SW',
            'DL_Pkt-S_medn_CW','UL_Pkt-S_medn_CW','DL_Pkt-S_medn_TW-1','UL_Pkt-S_medn_TW-1','DL_Pkt-S_medn_TW-3','UL_Pkt-S_medn_TW-3','DL_Pkt-S_medn_TW-5','UL_Pkt-S_medn_TW-5','DL_Pkt-S_medn_TW-10','UL_Pkt-S_medn_TW-10','DL_Pkt-S_medn_TW-20','UL_Pkt-S_medn_TW-20','DL_Pkt-S_medn_SW','UL_Pkt-S_medn_SW',
            'DL_Pkt-S_std_CW','UL_Pkt-S_std_CW','DL_Pkt-S_std_TW-1','UL_Pkt-S_std_TW-1','DL_Pkt-S_std_TW-3','UL_Pkt-S_std_TW-3','DL_Pkt-S_std_TW-5','UL_Pkt-S_std_TW-5','DL_Pkt-S_std_TW-10','UL_Pkt-S_std_TW-10','DL_Pkt-S_std_TW-20','UL_Pkt-S_std_TW-20','DL_Pkt-S_std_SW','UL_Pkt-S_std_SW',
            'DL_Pkt-S_max_CW','UL_Pkt-S_max_CW','DL_Pkt-S_max_TW-1','UL_Pkt-S_max_TW-1','DL_Pkt-S_max_TW-3','UL_Pkt-S_max_TW-3','DL_Pkt-S_max_TW-5','UL_Pkt-S_max_TW-5','DL_Pkt-S_max_TW-10','UL_Pkt-S_max_TW-10','DL_Pkt-S_max_TW-20','UL_Pkt-S_max_TW-20','DL_Pkt-S_max_SW','UL_Pkt-S_max_SW',
            'DL_Pkt-S_min_CW','UL_Pkt-S_min_CW','DL_Pkt-S_min_TW-1','UL_Pkt-S_min_TW-1','DL_Pkt-S_min_TW-3','UL_Pkt-S_min_TW-3','DL_Pkt-S_min_TW-5','UL_Pkt-S_min_TW-5','DL_Pkt-S_min_TW-10','UL_Pkt-S_min_TW-10','DL_Pkt-S_min_TW-20','UL_Pkt-S_min_TW-20','DL_Pkt-S_min_SW','UL_Pkt-S_min_SW',
            'DL_Pkt-S-g100_mean_CW','UL_Pkt-S-g100_mean_CW','DL_Pkt-S-g100_mean_TW-1','UL_Pkt-S-g100_mean_TW-1','DL_Pkt-S-g100_mean_TW-3','UL_Pkt-S-g100_mean_TW-3','DL_Pkt-S-g100_mean_TW-5','UL_Pkt-S-g100_mean_TW-5','DL_Pkt-S-g100_mean_TW-10','UL_Pkt-S-g100_mean_TW-10','DL_Pkt-S-g100_mean_TW-20','UL_Pkt-S-g100_mean_TW-20','DL_Pkt-S-g100_mean_SW','UL_Pkt-S-g100_mean_SW',    
            'DL_Pkt-S-g100_medn_CW','UL_Pkt-S-g100_medn_CW','DL_Pkt-S-g100_medn_TW-1','UL_Pkt-S-g100_medn_TW-1','DL_Pkt-S-g100_medn_TW-3','UL_Pkt-S-g100_medn_TW-3','DL_Pkt-S-g100_medn_TW-5','UL_Pkt-S-g100_medn_TW-5','DL_Pkt-S-g100_medn_TW-10','UL_Pkt-S-g100_medn_TW-10','DL_Pkt-S-g100_medn_TW-20','UL_Pkt-S-g100_medn_TW-20','DL_Pkt-S-g100_medn_SW','UL_Pkt-S-g100_medn_SW',
            'DL_Pkt-S-g100_std_CW','UL_Pkt-S-g100_std_CW','DL_Pkt-S-g100_std_TW-1','UL_Pkt-S-g100_std_TW-1','DL_Pkt-S-g100_std_TW-3','UL_Pkt-S-g100_std_TW-3','DL_Pkt-S-g100_std_TW-5','UL_Pkt-S-g100_std_TW-5','DL_Pkt-S-g100_std_TW-10','UL_Pkt-S-g100_std_TW-10','DL_Pkt-S-g100_std_TW-20','UL_Pkt-S-g100_std_TW-20','DL_Pkt-S-g100_std_SW','UL_Pkt-S-g100_std_SW',
            'DL_Pkt-S--g100_max_CW','UL_Pkt-S-g100_max_CW','DL_Pkt-S-g100_max_TW-1','UL_Pkt-S-g100_max_TW-1','DL_Pkt-S-g100_max_TW-3','UL_Pkt-S-g100_max_TW-3','DL_Pkt-S-g100_max_TW-5','UL_Pkt-S-g100_max_TW-5','DL_Pkt-S-g100_max_TW-10','UL_Pkt-S-g100_max_TW-10','DL_Pkt-S-g100_max_TW-20','UL_Pkt-S-g100_max_TW-20','DL_Pkt-S-g100_max_SW','UL_Pkt-S-g100_max_SW',
            'DL_Pkt-S-g100_min_CW','UL_Pkt-S-g100_min_CW','DL_Pkt-S-g100_min_TW-1','UL_Pkt-S-g100_min_TW-1','DL_Pkt-S-g100_min_TW-3','UL_Pkt-S-g100_min_TW-3','DL_Pkt-S-g100_min_TW-5','UL_Pkt-S-g100_min_TW-5','DL_Pkt-S-g100_min_TW-10','UL_Pkt-S-g100_min_TW-10','DL_Pkt-S-g100_min_TW-20','UL_Pkt-S-g100_min_TW-20','DL_Pkt-S-g100_min_SW','UL_Pkt-S-g100_min_SW'])

# %% [markdown]
# # Target

# %%
conditions = [
    (Y[['Resolution(w)']]==320) ,  #LD
    (Y[['Resolution(w)']]==384),   #LD
    (Y[['Resolution(w)']]==512),   #SD
    (Y[['Resolution(w)']]==640),   #SD
    (Y[['Resolution(w)']]==736),   #SD
    (Y[['Resolution(w)']]==1280),  #HD
    (Y[['Resolution(w)']]==1920),  #HD
    ]

choices = ['0', '0', '1','1', '1', '2','2']
Y['quality'] = np.select(conditions, choices, default='None')

# %%
conditions = [
    (Y[['Resolution(w)']]==320) ,  
    (Y[['Resolution(w)']]==384),   #LD
    (Y[['Resolution(w)']]==512),   #SD
    (Y[['Resolution(w)']]==640),   #SD
    (Y[['Resolution(w)']]==736),   #SD
    (Y[['Resolution(w)']]==1280),  #HD
    (Y[['Resolution(w)']]==1920),  #HD
    ]

choices = ['LD', 'LD', 'SD','SD', 'SD', 'HD','HD']
Y['quality1'] = np.select(conditions, choices, default='None')
yy=Y['quality']

# %% [markdown]
# # Distribution of Target

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
sns.set(font_scale=1.2, style="whitegrid")
plt.figure(figsize=(10, 8))
#df = pd.DataFrame(np.array([['a'], ['a'], ['b']]), columns=['current_status'])
ax = sns.countplot(y='quality1', data=Y,palette = "tab20")
ax.grid(False)
plt.title('Distribution of  Resolutions',weight="bold")
plt.xlabel('Percentages and Numbers ',weight="bold")
plt.ylabel('Resolutions',weight="bold")
#plt.yticks(np.arange(0, 1200, 120))
plt.xticks(np.arange(0, 45000,5000))
plt.tick_params(axis='x',  colors='black')
plt.tick_params(axis='y', colors='black')

total = len(Y['quality1'])
for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_width()/total)
        x = p.get_x() + p.get_width() / 2
        y = p.get_y() - 0.02
        ax.annotate(percentage, (x, y))

#plt.show()
plt.savefig('tcp-resolution distrubutions.pdf')

# %% [markdown]
# # Model Benchmark

# %%
seed = 42

# prepare models

param_grids=[]
##logistic
param_grids_0= {           
    'penalty':['l1', 'l2'], 
}
param_grids.append(param_grids_0)

##knn
param_grids_1 = {                      
    'n_neighbors': [3,5,7,10,25]
}
param_grids.append(param_grids_1)

## Decision Tree
param_grids_2 = { 
    'criterion':['gini', 'entropy'],
    'max_depth': [ 3, 10, 50, None],
    'min_samples_leaf': [1, 3, 5],
    'min_samples_split': [2, 4, 8],
    'class_weight': ['balanced',None]
}

param_grids.append(param_grids_2)
## NB
param_grids_3 = {   
    'priors':[None],
    'var_smoothing':[1e-09]
}

param_grids.append(param_grids_3)
 ## SVM
param_grids_4 = {  
     'gamma' :['scale'],
     'kernel' : [ 'rbf', 'poly'],
     #'degree' : [1,3,6],
     'C' : [0.01, 0.1, 1]

}
param_grids.append(param_grids_4)
 ### Random foresst
param_grids_5 = { 
    'max_depth': [ 3, 10, 50, 90, 100],
    'max_features': ['auto',None],
    'n_estimators': [100, 200,500],
    'min_samples_leaf': [3, 4, 5],
    'min_samples_split': [8, 10, 12],
    'class_weight': ['balanced',None]
}
param_grids.append(param_grids_5)
### MLP
param_grids_6 = {    
    'hidden_layer_sizes': [(50,50,50), (50,100,50), (100,)],
    'activation': ['identity', 'logistic', 'tanh', 'relu'],
    'solver': ['sgd', 'adam', 'lbfgs' ],
    'alpha': [0.0001, 0.05],
    #'learning_rate': ['constant','adaptive'],
}
param_grids.append(param_grids_6)

models = []
models.append((LogisticRegression()))
models.append((KNeighborsClassifier()))
models.append((DecisionTreeClassifier()))
models.append((GaussianNB()))
models.append((SVC()))
models.append((RandomForestClassifier()))
models.append((MLPClassifier()))


best_estimator=[]


for i in range(7):
    #print(param_grids[i])
    #param_grids= param_grids_%d' % (i))
    grid_search = GridSearchCV(estimator = models[i], param_grid = param_grids[i],  cv =5, n_jobs = -1, verbose = 1, return_train_score=True)
    grid_search.fit(X, yy)
    #print(grid_search.best_params_)
    
    best_estimator.append(grid_search.best_estimator_)
    
print('----------------------------------------')
print('Best parameters for seven algorithms')
print('----------------------------------------')
print()

for j in range(7):
    print( best_estimator[j])
    print('\n')
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 40 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 out of  10 | elapsed:   12.4s remaining:    3.1s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   12.4s finished
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 40 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed: 16.9min finished
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 40 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:   48.8s
# [Parallel(n_jobs=-1)]: Done 370 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 720 out of 720 | elapsed:  5.3min finished
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 40 concurrent workers.
# ...

# %%
import warnings
warnings.filterwarnings('ignore')
import pickle

print('----------------------------------------')
#print('Box plot of all model cross validation accuracy')
print('----------------------------------------')
print()
# prepare configuration for cross validation test harness
seed = 42
# prepare models
models = []

# models.append(('LR',  best_estimator[0])) #LogisticRegression()
# models.append(('KNN', best_estimator[1])) #KNeighborsClassifier()))
# models.append(('DTC', best_estimator[2])) #DecisionTreeClassifier()))
# models.append(('GNB', best_estimator[3]))
# models.append(('SVM', best_estimator[5]))
models.append(('RFC', RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
                       criterion='gini', max_depth=90, max_features='auto',
                       max_leaf_nodes=None, max_samples=None,
                       min_impurity_decrease=0.0, min_impurity_split=None,
                       min_samples_leaf=4, min_samples_split=12,
                       min_weight_fraction_leaf=0.0, n_estimators=500,
                       n_jobs=None, oob_score=False, random_state=None,
                       verbose=0, warm_start=False)))
# models.append(('MLP', best_estimator[6]))
# evaluate each model in turn
# evaluate each model in turn
ac = []
tr = []
names = []
scoring = 'accuracy'
for name, model in models:
    kfold = model_selection.KFold(n_splits=5, random_state=seed)
    cv_results = model_selection.cross_validate(model, X, yy, cv=kfold)
    ac.append((cv_results['test_score'])*100)
    tr.append((cv_results['fit_time'])/60)
    names.append(name)
    
    a_msg = "Accuracy %s: %f (%f)" % (name, ((cv_results['test_score'])*100).mean(), ((cv_results['test_score'])*100).std())
    t_msg = "Training time %s: %f (%f)" % (name, ((cv_results['fit_time'])/60).mean(),  ((cv_results['fit_time'])/60).std())
    print(a_msg)
    print(t_msg)
# boxplot algorithm comparison
# Out:
# ----------------------------------------
# ----------------------------------------
#
# Accuracy RFC: 91.028565 (0.340239)
# Training time RFC: 3.448446 (0.029093)

# %% [markdown]
# # Current Window

# %%
# C_all=X.loc[:,X.columns.isin(['DL_Th_CW','UL_Th_CW','DL_Pkt_CW','UL_Pkt_CW','DL_Pkt-g100_CW', 'UL_Pkt-g100_CW', 'DL_IA_mean_CW','UL_IA_mean_CW','DL_IA_medn_CW','UL_IA_medn_CW','DL_IA_std_CW','UL_IA_std_CW','DL_IA_max_CW','UL_IA_max_CW','DL_IA_min_CW','UL_IA_min_CW','DL_Pkt-S_mean_CW','UL_Pkt-S_mean_CW','DL_Pkt-S_medn_CW','UL_Pkt-S_medn_CW','DL_Pkt-S_std_CW','UL_Pkt-S_std_CW', 'DL_Pkt-S_max_CW','UL_Pkt-S_max_CW','DL_Pkt-S_min_CW','UL_Pkt-S_min_CW','DL_Pkt-S-g100_mean_CW','UL_Pkt-S-g100_mean_CW','DL_Pkt-S-g100_medn_CW','UL_Pkt-S-g100_medn_CW','DL_Pkt-S-g100_std_CW','UL_Pkt-S-g100_std_CW',
# 'DL_Pkt-S--g100_max_CW','UL_Pkt-S-g100_max_CW','DL_Pkt-S-g100_min_CW','UL_Pkt-S-g100_min_CW'])]
C_all=X.loc[:,X.columns.isin(['DL_Th_avg_CW','UL_Th_avg_CW','DL_Pkt-N_total_CW','UL_Pkt-N_total_CW','DL_Pkt-N-g100_total_CW', 'UL_Pkt-N-g100_total_CW', 'DL_IA_mean_CW','UL_IA_mean_CW','DL_IA_medn_CW','UL_IA_medn_CW','DL_IA_std_CW','UL_IA_std_CW','DL_IA_max_CW','UL_IA_max_CW','DL_IA_min_CW','UL_IA_min_CW','DL_Pkt-S_mean_CW','UL_Pkt-S_mean_CW','DL_Pkt-S_medn_CW','UL_Pkt-S_medn_CW','DL_Pkt-S_std_CW','UL_Pkt-S_std_CW', 'DL_Pkt-S_max_CW','UL_Pkt-S_max_CW','DL_Pkt-S_min_CW','UL_Pkt-S_min_CW','DL_Pkt-S-g100_mean_CW','UL_Pkt-S-g100_mean_CW','DL_Pkt-S-g100_medn_CW','UL_Pkt-S-g100_medn_CW','DL_Pkt-S-g100_std_CW','UL_Pkt-S-g100_std_CW',
'DL_Pkt-S--g100_max_CW','UL_Pkt-S-g100_max_CW','DL_Pkt-S-g100_min_CW','UL_Pkt-S-g100_min_CW'])]

# %%
F=C_all.columns

# %%
yy.value_counts()
# Out:
# 2    39897
# 1    33322
# 0    32394
# Name: quality, dtype: int64

# %%
clf = RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
                       criterion='gini', max_depth=90, max_features='auto',
                       max_leaf_nodes=None, max_samples=None,
                       min_impurity_decrease=0.0, min_impurity_split=None,
                       min_samples_leaf=4, min_samples_split=12,
                       min_weight_fraction_leaf=0.0, n_estimators=500,
                       n_jobs=None, oob_score=False, random_state=None,
                       verbose=0, warm_start=False)
clf.fit(C_all, yy)

importances = clf.feature_importances_
indices = np.argsort(importances)
top_k = 15
new_indices = indices[-top_k:]
# fig = plt.figure(figsize=(26, 12))
# plt.rcParams["axes.grid"] = False
# plt.rcParams['font.size'] = 18
# plt.rc('ytick',labelsize=17)
# plt.rc('xtick',labelsize=17)
# #plt.title('Feature Importances')
# plt.barh(range(len(new_indices)), importances[new_indices], color='c', align='center')
# plt.yticks(range(len(new_indices)), [F[i] for i in new_indices])
# #plt.xticks((0, 0.02, 0.07))
# #plt.xlabel('Relative Importance')
# #plt.show()
# plt.savefig('CW-top10.pdf')
fig = plt.figure(figsize=(10,6))
plt.rcParams["axes.grid"] = False
ax = fig.add_subplot(111)
ax.barh(range(len(new_indices)), importances[new_indices], color='c',align='center')
plt.yticks(range(len(new_indices)), [F[i] for i in new_indices])

plt.tight_layout()
#plt.show()
plt.savefig('CW-15.pdf')

# %%
L=[]
for i in new_indices:
    l='%s'%F[i]
    L.append(l)
L
# Out:
# ['UL_Pkt-S-g100_mean_CW',
#  'UL_Pkt-S-g100_medn_CW',
#  'UL_Pkt-S-g100_std_CW',
#  'DL_Pkt-S-g100_mean_CW',
#  'DL_Pkt-S_mean_CW',
#  'DL_IA_std_CW',
#  'UL_IA_std_CW',
#  'DL_IA_min_CW',
#  'DL_Th_avg_CW',
#  'UL_IA_mean_CW',
#  'DL_IA_mean_CW',
#  'DL_IA_max_CW',
#  'UL_IA_max_CW',
#  'UL_IA_medn_CW',
#  'DL_IA_medn_CW']

# %%
C_ten=X.loc[:,X.columns.isin(['UL_Pkt-S-g100_mean_CW',
 'UL_Pkt-S-g100_medn_CW',
 'UL_Pkt-S-g100_std_CW',
 'DL_Pkt-S-g100_mean_CW',
 'DL_Pkt-S_mean_CW',
 'DL_IA_std_CW',
 'UL_IA_std_CW',
 'DL_IA_min_CW',
 'DL_Th_avg_CW',
 'UL_IA_mean_CW',
 'DL_IA_mean_CW',
 'DL_IA_max_CW',
 'UL_IA_max_CW',
 'UL_IA_medn_CW',
 'DL_IA_medn_CW'])]

# %%
C_all_train, C_all_test,C_all_y_train, C_all_y_test = train_test_split( C_all, yy, test_size=0.2, random_state=101)
C_ten_train, C_ten_test,C_ten_y_train, C_ten_y_test = train_test_split( C_ten, yy, test_size=0.2, random_state=101)

# %%
# load the model from disk
model =RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
                       criterion='gini', max_depth=90, max_features='auto',
                       max_leaf_nodes=None, max_samples=None,
                       min_impurity_decrease=0.0, min_impurity_split=None,
                       min_samples_leaf=4, min_samples_split=12,
                       min_weight_fraction_leaf=0.0, n_estimators=500,
                       n_jobs=None, oob_score=False, random_state=None,
                       verbose=0, warm_start=False)
model.fit(C_all_train, C_all_y_train)


y_pred = model.predict(C_all_test)


accuracy = metrics.accuracy_score( C_all_y_test, y_pred)
print()
print('------------------------------------------------------')
print ("Accuracy of our RF classification  model based on test data is : {0:.4f}".format(accuracy))
print('------------------------------------------------------')

print()
print('------------------------------------------------------')
print ("Classification Report\n")
print('------------------------------------------------------')

print ("{0}".format(metrics.classification_report(C_all_y_test.ravel(), y_pred,target_names = ['LD', 'SD', 'HD'])))
# Out:
# ------------------------------------------------------
# Accuracy of our RF classification  model based on test data is : 0.6230
# ------------------------------------------------------
#
# ------------------------------------------------------
# Classification Report
#
# ------------------------------------------------------
#               precision    recall  f1-score   support
#
#           LD       0.77      0.41      0.54      6544
#           SD       0.70      0.48      0.57      6546
#           HD       0.56      0.91      0.69      8033
#
#     accuracy                           0.62     21123
#    macro avg       0.68      0.60      0.60     21123
# weighted avg       0.67      0.62      0.61     21123

# %%
# load the model from disk
model =RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
                       criterion='gini', max_depth=90, max_features='auto',
                       max_leaf_nodes=None, max_samples=None,
                       min_impurity_decrease=0.0, min_impurity_split=None,
                       min_samples_leaf=4, min_samples_split=12,
                       min_weight_fraction_leaf=0.0, n_estimators=500,
                       n_jobs=None, oob_score=False, random_state=None,
                       verbose=0, warm_start=False)

model.fit(C_ten_train, C_ten_y_train)


y_pred = model.predict(C_ten_test)


accuracy = metrics.accuracy_score( C_ten_y_test.ravel(), y_pred)
print()
print('------------------------------------------------------')
print ("Accuracy of our RF classification  model based on test data is : {0:.4f}".format(accuracy))
print('------------------------------------------------------')

print()
print('------------------------------------------------------')
print ("Classification Report\n")
print('------------------------------------------------------')

print ("{0}".format(metrics.classification_report(C_ten_y_test.ravel(), y_pred,target_names = ['LD', 'SD', 'HD'])))
# Out:
# ------------------------------------------------------
# Accuracy of our RF classification  model based on test data is : 0.6253
# ------------------------------------------------------
#
# ------------------------------------------------------
# Classification Report
#
# ------------------------------------------------------
#               precision    recall  f1-score   support
#
#           LD       0.78      0.41      0.54      6544
#           SD       0.71      0.48      0.57      6546
#           HD       0.56      0.92      0.69      8033
#
#     accuracy                           0.63     21123
#    macro avg       0.68      0.60      0.60     21123
# weighted avg       0.67      0.63      0.61     21123

# %% [markdown]
# # Trend window

# %%

                       n_jobs=None, oob_score=False, random_state=None,
                       verbose=0, warm_start=False)
clf.fit(T_all, yy)

importances = clf.feature_importances_
indices = np.argsort(importances)
top_k = 15
new_indices = indices[-top_k:]
# fig = plt.figure(figsize=(26, 12))
# plt.rcParams["axes.grid"] = False
# plt.rcParams['font.size'] = 18
# plt.rc('ytick',labelsize=15)
# plt.rc('xtick',labelsize=15)
# #plt.title('Feature Importances')
# plt.barh(range(len(new_indices)), importances[new_indices], color='c', align='center')
# plt.yticks(range(len(new_indices)), [F1[i] for i in new_indices])
# #plt.xticks((0, 0.02, 0.07))
# #plt.xlabel('Relative Importance')
# #plt.show()
# plt.savefig('TW-top10.pdf')
fig = plt.figure(figsize=(10,6))
plt.rcParams["axes.grid"] = False
ax = fig.add_subplot(111)
ax.barh(range(len(new_indices)), importances[new_indices], color='c',align='center')
plt.yticks(range(len(new_indices)), [F1[i] for i in new_indices])

plt.tight_layout()
#plt.show()
plt.savefig('TW-15.pdf')

# %%
L=[]
for i in new_indices:
    l='%s'%F1[i]
    L.append(l)
L
# Out:
# ['UL_Th_avg_TW-20',
#  'DL_Pkt-S-g100_mean_TW-20',
#  'DL_Pkt-S_mean_TW-20',
#  'DL_IA_medn_TW-20',
#  'UL_Pkt-S-g100_std_TW-20',
#  'UL_Pkt-N_total_TW-20',
#  'DL_Pkt-N-g100_total_TW-20',
#  'UL_Pkt-S-g100_medn_TW-20',
#  'UL_Pkt-S_mean_TW-20',
#  'DL_IA_std_TW-20',
#  'DL_IA_mean_TW-20',
#  'UL_IA_std_TW-20',
#  'UL_Pkt-S_std_TW-20',
#  'UL_IA_mean_TW-20',
#  'UL_Pkt-S-g100_mean_TW-20']

# %%
T_ten=X.loc[:,X.columns.isin(['UL_Th_avg_TW-20',
 'DL_Pkt-S-g100_mean_TW-20',
 'DL_Pkt-S_mean_TW-20',
 'DL_IA_medn_TW-20',
 'UL_Pkt-S-g100_std_TW-20',
 'UL_Pkt-N_total_TW-20',
 'DL_Pkt-N-g100_total_TW-20',
 'UL_Pkt-S-g100_medn_TW-20',
 'UL_Pkt-S_mean_TW-20',
 'DL_IA_std_TW-20',
 'DL_IA_mean_TW-20',
 'UL_IA_std_TW-20',
 'UL_Pkt-S_std_TW-20',
 'UL_IA_mean_TW-20',
 'UL_Pkt-S-g100_mean_TW-20'])]

# %%
T_all_train, T_all_test,T_all_y_train, T_all_y_test = train_test_split( T_all, yy, test_size=0.2, random_state=101)
T_ten_train, T_ten_test,T_ten_y_train, T_ten_y_test = train_test_split( T_ten, yy, test_size=0.2, random_state=101)

# %%
# load the model from disk
model =  RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
                       criterion='gini', max_depth=90, max_features='auto',
                       max_leaf_nodes=None, max_samples=None,
                       min_impurity_decrease=0.0, min_impurity_split=None,
                       min_samples_leaf=4, min_samples_split=12,
                       min_weight_fraction_leaf=0.0, n_estimators=500,
                       n_jobs=None, oob_score=False, random_state=None,
                       verbose=0, warm_start=False)

model.fit(T_all_train, T_all_y_train)

y_pred = model.predict(T_all_test)


accuracy = metrics.accuracy_score( T_all_y_test, y_pred)
print()
print('------------------------------------------------------')
print ("Accuracy of our RF classification  model based on test data is : {0:.4f}".format(accuracy))
print('------------------------------------------------------')

print()
print('------------------------------------------------------')
print ("Classification Report\n")
print('------------------------------------------------------')

print ("{0}".format(metrics.classification_report(T_all_y_test.ravel(), y_pred,target_names = ['LD', 'SD', 'HD'])))
# Out:
# ------------------------------------------------------
# Accuracy of our RF classification  model based on test data is : 0.8809
# ------------------------------------------------------
#
# ------------------------------------------------------
# Classification Report
#
# ------------------------------------------------------
#               precision    recall  f1-score   support
#
#           LD       0.97      0.77      0.86      6544
#           SD       0.97      0.85      0.90      6546
#           HD       0.79      0.99      0.88      8033
#
#     accuracy                           0.88     21123
#    macro avg       0.91      0.87      0.88     21123
# weighted avg       0.90      0.88      0.88     21123

# %%
# load the model from disk
model =  RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
                       criterion='gini', max_depth=90, max_features='auto',
                       max_leaf_nodes=None, max_samples=None,
                       min_impurity_decrease=0.0, min_impurity_split=None,
                       min_samples_leaf=4, min_samples_split=12,
                       min_weight_fraction_leaf=0.0, n_estimators=500,
                       n_jobs=None, oob_score=False, random_state=None,
                       verbose=0, warm_start=False)

model.fit(T_ten_train, T_ten_y_train)
y_pred = model.predict(T_ten_test)


accuracy = metrics.accuracy_score( T_ten_y_test, y_pred)
print()
print('------------------------------------------------------')
print ("Accuracy of our RF classification  model based on test data is : {0:.4f}".format(accuracy))
print('------------------------------------------------------')

print()
print('------------------------------------------------------')
print ("Classification Report\n")
print('------------------------------------------------------')

print ("{0}".format(metrics.classification_report(T_ten_y_test.ravel(), y_pred,target_names = ['LD', 'SD', 'HD'])))
# Out:
# ------------------------------------------------------
# Accuracy of our RF classification  model based on test data is : 0.8664
# ------------------------------------------------------
#
# ------------------------------------------------------
# Classification Report
#
# ------------------------------------------------------
#               precision    recall  f1-score   support
#
#           LD       0.94      0.76      0.84      6544
#           SD       0.94      0.83      0.88      6546
#           HD       0.78      0.98      0.87      8033
#
#     accuracy                           0.87     21123
#    macro avg       0.89      0.86      0.87     21123
# weighted avg       0.88      0.87      0.87     21123

# %% [markdown]
# # Session window

# %%
# S_all=X.loc[:,X.columns.isin(['DL_Th_SW','UL_Th_SW','DL_Pkt_SW','UL_Pkt_SW','DL_Pkt-g100_SW','UL_Pkt-g100_SW','DL_IA_mean_SW','UL_IA_mean_SW','DL_IA_medn_SW','UL_IA_medn_SW','DL_IA_SWtd_SW','UL_IA_SWtd_SW','DL_IA_max_SW','UL_IA_max_SW','DL_IA_min_SW','UL_IA_min_SW','DL_Pkt-S_mean_SW','UL_Pkt-S_mean_SW','UL_Pkt-S_medn_TW-20','DL_Pkt-S_medn_SW','UL_Pkt-S_medn_SW','DL_Pkt-S_SWtd_SW','UL_Pkt-S_SWtd_SW','DL_Pkt-S_max_SW','UL_Pkt-S_max_SW','DL_Pkt-S_min_SW','UL_Pkt-S_min_SW','DL_Pkt-S-g100_mean_SW','UL_Pkt-S-g100_mean_SW','DL_Pkt-S-g100_medn_SW','UL_Pkt-S-g100_medn_SW','DL_Pkt-S-g100_SWtd_SW','UL_Pkt-S-g100_SWtd_SW','DL_Pkt-S-g100_max_SW','UL_Pkt-S-g100_max_SW','DL_Pkt-S-g100_min_SW','UL_Pkt-S-g100_min_SW'])]
#S_all=X.loc[:,X.columns.isin(['DL_Th_avg_SW','UL_Th_avg_SW','DL_Pkt-N_total_SW','UL_Pkt-N_total_SW','DL_Pkt-N-g100_total_SW','UL_Pkt-N-g100_total_SW','DL_IA_mean_SW','UL_IA_mean_SW','DL_IA_medn_SW','UL_IA_medn_SW','DL_IA_SWtd_SW','UL_IA_SWtd_SW','DL_IA_max_SW','UL_IA_max_SW','DL_IA_min_SW','UL_IA_min_SW','DL_Pkt-S_mean_SW','UL_Pkt-S_mean_SW','UL_Pkt-S_medn_TW-20','DL_Pkt-S_medn_SW','UL_Pkt-S_medn_SW','DL_Pkt-S_SWtd_SW','UL_Pkt-S_SWtd_SW','DL_Pkt-S_max_SW','UL_Pkt-S_max_SW','DL_Pkt-S_min_SW','UL_Pkt-S_min_SW','DL_Pkt-S-g100_mean_SW','UL_Pkt-S-g100_mean_SW','DL_Pkt-S-g100_medn_SW','UL_Pkt-S-g100_medn_SW','DL_Pkt-S-g100_SWtd_SW','UL_Pkt-S-g100_SWtd_SW','DL_Pkt-S-g100_max_SW','UL_Pkt-S-g100_max_SW','DL_Pkt-S-g100_min_SW','UL_Pkt-S-g100_min_SW'])]
S_all=X.loc[:,X.columns.isin(['DL_Th_avg_SW','UL_Th_avg_SW','DL_Pkt-N_total_SW','UL_Pkt-N_total_SW','DL_Pkt-N-g100_total_SW','UL_Pkt-N-g100_total_SW',
      'DL_IA_mean_SW','UL_IA_mean_SW','DL_IA_medn_SW','UL_IA_medn_SW','DL_IA_std_SW','UL_IA_std_SW','DL_IA_max_SW','UL_IA_max_SW','DL_IA_min_SW','UL_IA_min_SW',
      'DL_Pkt-S_mean_SW','UL_Pkt-S_mean_SW','UL_Pkt-S_medn_TW-20','DL_Pkt-S_medn_SW','UL_Pkt-S_medn_SW','DL_Pkt-S_std_SW','UL_Pkt-S_std_SW','DL_Pkt-S_max_SW','UL_Pkt-S_max_SW','DL_Pkt-S_min_SW','UL_Pkt-S_min_SW',
      'DL_Pkt-S-g100_mean_SW','UL_Pkt-S-g100_mean_SW','DL_Pkt-S-g100_medn_SW','UL_Pkt-S-g100_medn_SW','DL_Pkt-S-g100_std_SW','UL_Pkt-S-g100_std_SW','DL_Pkt-S-g100_max_SW','UL_Pkt-S-g100_max_SW','DL_Pkt-S-g100_min_SW','UL_Pkt-S-g100_min_SW'])]

# %%
F2=S_all.columns

# %%
S_all.shape
# Out:
# (105613, 36)

# %%
clf =  RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
                       criterion='gini', max_depth=90, max_features='auto',
                       max_leaf_nodes=None, max_samples=None,
                       min_impurity_decrease=0.0, min_impurity_split=None,
                       min_samples_leaf=4, min_samples_split=12,
                       min_weight_fraction_leaf=0.0, n_estimators=500,
                       n_jobs=None, oob_score=False, random_state=None,
                       verbose=0, warm_start=False)
clf.fit(S_all, yy)

importances = clf.feature_importances_
indices = np.argsort(importances)
top_k = 15
new_indices = indices[-top_k:]
# fig = plt.figure(figsize=(26, 12))
# plt.rcParams["axes.grid"] = False
# plt.rcParams['font.size'] = 18
# plt.rc('ytick',labelsize=15)
# plt.rc('xtick',labelsize=15)
# #plt.title('Feature Importances')
# plt.barh(range(len(new_indices)), importances[new_indices], color='c', align='edge')
# plt.yticks(range(len(new_indices)), [F2[i] for i in new_indices])
# #plt.xticks((0, 0.02, 0.07))
# #plt.xlabel('Relative Importance')
# #plt.show()
# plt.savefig('SW.pdf')
fig = plt.figure(figsize=(10,6))
plt.rcParams["axes.grid"] = False
ax = fig.add_subplot(111)
ax.barh(range(len(new_indices)), importances[new_indices], color='c',align='center')
plt.yticks(range(len(new_indices)), [F2[i] for i in new_indices])

plt.tight_layout()
#plt.show()
plt.savefig('SW.pdf')

# %%
L=[]
for i in new_indices:
    l='%s'%F2[i]
    L.append(l)
L
# Out:
# ['UL_Pkt-S-g100_mean_SW',
#  'DL_Pkt-S-g100_mean_SW',
#  'UL_Pkt-N-g100_total_SW',
#  'UL_Pkt-S_mean_SW',
#  'DL_Pkt-S_mean_SW',
#  'DL_Pkt-N_total_SW',
#  'UL_Pkt-S_std_SW',
#  'DL_IA_std_SW',
#  'DL_Pkt-N-g100_total_SW',
#  'DL_IA_mean_SW',
#  'UL_Pkt-N_total_SW',
#  'UL_IA_mean_SW',
#  'UL_IA_std_SW',
#  'UL_Th_avg_SW',
#  'DL_Th_avg_SW']

# %%
S_ten=X.loc[:,X.columns.isin(['UL_Pkt-S-g100_mean_SW',
 'DL_Pkt-S-g100_mean_SW',
 'UL_Pkt-N-g100_total_SW',
 'UL_Pkt-S_mean_SW',
 'DL_Pkt-S_mean_SW',
 'DL_Pkt-N_total_SW',
 'UL_Pkt-S_std_SW',
 'DL_IA_std_SW',
 'DL_Pkt-N-g100_total_SW',
 'DL_IA_mean_SW',
 'UL_Pkt-N_total_SW',
 'UL_IA_mean_SW',
 'UL_IA_std_SW',
 'UL_Th_avg_SW',
 'DL_Th_avg_SW'])]

# %%
S_all_train, S_all_test,S_all_y_train, S_all_y_test = train_test_split( S_all, yy, test_size=0.2, random_state=101)
S_ten_train, S_ten_test,S_ten_y_train, S_ten_y_test = train_test_split( S_ten, yy, test_size=0.2, random_state=101)

# %%
# load the model from disk
model =  RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
                       criterion='gini', max_depth=90, max_features='auto',
                       max_leaf_nodes=None, max_samples=None,
                       min_impurity_decrease=0.0, min_impurity_split=None,
                       min_samples_leaf=4, min_samples_split=12,
                       min_weight_fraction_leaf=0.0, n_estimators=500,
                       n_jobs=None, oob_score=False, random_state=None,
                       verbose=0, warm_start=False)
model.fit(S_all_train, S_all_y_train)


y_pred = model.predict(S_all_test)


accuracy = metrics.accuracy_score( S_all_y_test, y_pred)
print()
print('------------------------------------------------------')
print ("Accuracy of our RF classification  model based on test data is : {0:.4f}".format(accuracy))
print('------------------------------------------------------')

print()
print('------------------------------------------------------')
print ("Classification Report\n")
print('------------------------------------------------------')

print ("{0}".format(metrics.classification_report(S_all_y_test.ravel(), y_pred,target_names = ['LD', 'SD', 'HD'])))
# Out:
# ------------------------------------------------------
# Accuracy of our RF classification  model based on test data is : 0.9813
# ------------------------------------------------------
#
# ------------------------------------------------------
# Classification Report
#
# ------------------------------------------------------
#               precision    recall  f1-score   support
#
#           LD       0.99      0.98      0.98      6544
#           SD       0.98      0.97      0.97      6546
#           HD       0.98      1.00      0.99      8033
#
#     accuracy                           0.98     21123
#    macro avg       0.98      0.98      0.98     21123
# weighted avg       0.98      0.98      0.98     21123

# %%
# load the model from disk
model = RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
                       criterion='gini', max_depth=90, max_features='auto',
                       max_leaf_nodes=None, max_samples=None,
                       min_impurity_decrease=0.0, min_impurity_split=None,
                       min_samples_leaf=4, min_samples_split=12,
                       min_weight_fraction_leaf=0.0, n_estimators=500,
                       n_jobs=None, oob_score=False, random_state=None,
                       verbose=0, warm_start=False)
model.fit(S_ten_train, S_ten_y_train)
y_pred = model.predict(S_ten_test)


accuracy = metrics.accuracy_score( S_ten_y_test, y_pred)
print()
print('------------------------------------------------------')
print ("Accuracy of our RF classification  model based on test data is : {0:.4f}".format(accuracy))
print('------------------------------------------------------')

print()
print('------------------------------------------------------')
print ("Classification Report\n")
print('------------------------------------------------------')

print ("{0}".format(metrics.classification_report(S_ten_y_test.ravel(), y_pred,target_names = ['LD', 'SD', 'HD'])))
# Out:
# ------------------------------------------------------
# Accuracy of our RF classification  model based on test data is : 0.9798
# ------------------------------------------------------
#
# ------------------------------------------------------
# Classification Report
#
# ------------------------------------------------------
#               precision    recall  f1-score   support
#
#           LD       0.98      0.97      0.98      6544
#           SD       0.98      0.97      0.97      6546
#           HD       0.98      0.99      0.99      8033
#
#     accuracy                           0.98     21123
#    macro avg       0.98      0.98      0.98     21123
# weighted avg       0.98      0.98      0.98     21123

# %% [markdown]
# # All Window

# %%
A_all=X.loc[:,X.columns.isin(['DL_Th_avg_CW','UL_Th_avg_CW','DL_Th_avg_TW-1','UL_Th_avg_TW-1','DL_Th_avg_TW-3','UL_Th_avg_TW-3','DL_Th_avg_TW-5','UL_Th_avg_TW-5','DL_Th_avg_TW-10','UL_Th_avg_TW-10','DL_Th_avg_TW-20','UL_Th_avg_TW-20','DL_Th_avg_SW','UL_Th_avg_SW',
            'DL_Pkt-N_total_CW','UL_Pkt-N_total_CW','DL_Pkt-N_total_TW-1','UL_Pkt-N_total_TW-1','DL_Pkt-N_total_TW-3','UL_Pkt-N_total_TW-3','DL_Pkt-N_total_TW-5','UL_Pkt-N_total_TW-5','DL_Pkt-N_total_TW-10','UL_Pkt-N_total_TW-10','DL_Pkt-N_total_TW-20','UL_Pkt-N_total_TW-20','DL_Pkt-N_total_SW','UL_Pkt-N_total_SW',
            'DL_Pkt-N-g100_total_CW', 'UL_Pkt-N-g100_total_CW', 'DL_Pkt-N-g100_total_TW-1','UL_Pkt-N-g100_total_TW-1','DL_Pkt-N-g100_total_TW-3','UL_Pkt-N-g100_total_TW-3','DL_Pkt-N-g100_total_TW-5','UL_Pkt-N-g100_total_TW-5','DL_Pkt-N-g100_total_TW-10','UL_Pkt-N-g100_total_TW-10','DL_Pkt-N-g100_total_TW-20','UL_Pkt-N-g100_total_TW-20','DL_Pkt-N-g100_total_SW','UL_Pkt-N-g100_total_SW',
            'DL_IA_mean_CW','UL_IA_mean_CW','DL_IA_mean_TW-1','UL_IA_mean_TW-1','DL_IA_mean_TW-3','UL_IA_mean_TW-3','DL_IA_mean_TW-5','UL_IA_mean_TW-5','DL_IA_mean_TW-10','UL_IA_mean_TW-10','DL_IA_mean_TW-20','UL_IA_mean_TW-20','DL_IA_mean_SW','UL_IA_mean_SW',
            'DL_IA_medn_CW','UL_IA_medn_CW','DL_IA_medn_TW-1','UL_IA_medn_TW-1','DL_IA_medn_TW-3','UL_IA_medn_TW-3','DL_IA_medn_TW-5','UL_IA_medn_TW-5','DL_IA_medn_TW-10','UL_IA_medn_TW-10','DL_IA_medn_TW-20','UL_IA_medn_TW-20','DL_IA_med_SW','UL_IA_medn_SW',
            'DL_IA_std_CW','UL_IA_std_CW','DL_IA_std_TW-1','UL_IA_std_TW-1','DL_IA_std_TW-3','UL_IA_std_TW-3','DL_IA_std_TW-5','UL_IA_std_TW-5','DL_IA_std_TW-10','UL_IA_std_TW-10','DL_IA_std_TW-20','UL_IA_std_TW-20','DL_IA_std_SW','UL_IA_std_SW',
            'DL_IA_max_CW','UL_IA_max_CW','DL_IA_max_TW-1','UL_IA_max_TW-1','DL_IA_max_TW-3','UL_IA_max_TW-3','DL_IA_max_TW-5','UL_IA_max_TW-5','DL_IA_max_TW-10','UL_IA_max_TW-10','DL_IA_max_TW-20','UL_IA_max_TW-20','DL_IA_max_SW','UL_IA_max_SW',
            'DL_IA_min_CW','UL_IA_min_CW','DL_IA_min_TW-1','UL_IA_min_TW-1','DL_IA_min_TW-3','UL_IA_min_TW-3','DL_IA_min_TW-5','UL_IA_min_TW-5','DL_IA_min_TW-10','UL_IA_min_TW-10','DL_IA_min_TW-20','UL_IA_min_TW-20','DL_IA_min_SW','UL_IA_min_SW',
            'DL_Pkt-S_mean_CW','UL_Pkt-S_mean_CW','DL_Pkt-S_mean_TW-1','UL_Pkt-S_mean_TW-1','DL_Pkt-S_mean_TW-3','UL_Pkt-S_mean_TW-3','DL_Pkt-S_mean_TW-5','UL_Pkt-S_mean_TW-5','DL_Pkt-S_mean_TW-10','UL_Pkt-S_mean_TW-10','DL_Pkt-S_mean_TW-20','UL_Pkt-S_mean_TW-20','DL_Pkt-S_mean_SW','UL_Pkt-S_mean_SW',
            'DL_Pkt-S_medn_CW','UL_Pkt-S_medn_CW','DL_Pkt-S_medn_TW-1','UL_Pkt-S_medn_TW-1','DL_Pkt-S_medn_TW-3','UL_Pkt-S_medn_TW-3','DL_Pkt-S_medn_TW-5','UL_Pkt-S_medn_TW-5','DL_Pkt-S_medn_TW-10','UL_Pkt-S_medn_TW-10','DL_Pkt-S_medn_TW-20','UL_Pkt-S_medn_TW-20','DL_Pkt-S_medn_SW','UL_Pkt-S_medn_SW',
            'DL_Pkt-S_std_CW','UL_Pkt-S_std_CW','DL_Pkt-S_std_TW-1','UL_Pkt-S_std_TW-1','DL_Pkt-S_std_TW-3','UL_Pkt-S_std_TW-3','DL_Pkt-S_std_TW-5','UL_Pkt-S_std_TW-5','DL_Pkt-S_std_TW-10','UL_Pkt-S_std_TW-10','DL_Pkt-S_std_TW-20','UL_Pkt-S_std_TW-20','DL_Pkt-S_std_SW','UL_Pkt-S_std_SW',
            'DL_Pkt-S_max_CW','UL_Pkt-S_max_CW','DL_Pkt-S_max_TW-1','UL_Pkt-S_max_TW-1','DL_Pkt-S_max_TW-3','UL_Pkt-S_max_TW-3','DL_Pkt-S_max_TW-5','UL_Pkt-S_max_TW-5','DL_Pkt-S_max_TW-10','UL_Pkt-S_max_TW-10','DL_Pkt-S_max_TW-20','UL_Pkt-S_max_TW-20','DL_Pkt-S_max_SW','UL_Pkt-S_max_SW',
            'DL_Pkt-S_min_CW','UL_Pkt-S_min_CW','DL_Pkt-S_min_TW-1','UL_Pkt-S_min_TW-1','DL_Pkt-S_min_TW-3','UL_Pkt-S_min_TW-3','DL_Pkt-S_min_TW-5','UL_Pkt-S_min_TW-5','DL_Pkt-S_min_TW-10','UL_Pkt-S_min_TW-10','DL_Pkt-S_min_TW-20','UL_Pkt-S_min_TW-20','DL_Pkt-S_min_SW','UL_Pkt-S_min_SW',
            'DL_Pkt-S-g100_mean_CW','UL_Pkt-S-g100_mean_CW','DL_Pkt-S-g100_mean_TW-1','UL_Pkt-S-g100_mean_TW-1','DL_Pkt-S-g100_mean_TW-3','UL_Pkt-S-g100_mean_TW-3','DL_Pkt-S-g100_mean_TW-5','UL_Pkt-S-g100_mean_TW-5','DL_Pkt-S-g100_mean_TW-10','UL_Pkt-S-g100_mean_TW-10','DL_Pkt-S-g100_mean_TW-20','UL_Pkt-S-g100_mean_TW-20','DL_Pkt-S-g100_mean_SW','UL_Pkt-S-g100_mean_SW',    
            'DL_Pkt-S-g100_medn_CW','UL_Pkt-S-g100_medn_CW','DL_Pkt-S-g100_medn_TW-1','UL_Pkt-S-g100_medn_TW-1','DL_Pkt-S-g100_medn_TW-3','UL_Pkt-S-g100_medn_TW-3','DL_Pkt-S-g100_medn_TW-5','UL_Pkt-S-g100_medn_TW-5','DL_Pkt-S-g100_medn_TW-10','UL_Pkt-S-g100_medn_TW-10','DL_Pkt-S-g100_medn_TW-20','UL_Pkt-S-g100_medn_TW-20','DL_Pkt-S-g100_medn_SW','UL_Pkt-S-g100_medn_SW',
            'DL_Pkt-S-g100_std_CW','UL_Pkt-S-g100_std_CW','DL_Pkt-S-g100_std_TW-1','UL_Pkt-S-g100_std_TW-1','DL_Pkt-S-g100_std_TW-3','UL_Pkt-S-g100_std_TW-3','DL_Pkt-S-g100_std_TW-5','UL_Pkt-S-g100_std_TW-5','DL_Pkt-S-g100_std_TW-10','UL_Pkt-S-g100_std_TW-10','DL_Pkt-S-g100_std_TW-20','UL_Pkt-S-g100_std_TW-20','DL_Pkt-S-g100_std_SW','UL_Pkt-S-g100_std_SW',
            'DL_Pkt-S--g100_max_CW','UL_Pkt-S-g100_max_CW','DL_Pkt-S-g100_max_TW-1','UL_Pkt-S-g100_max_TW-1','DL_Pkt-S-g100_max_TW-3','UL_Pkt-S-g100_max_TW-3','DL_Pkt-S-g100_max_TW-5','UL_Pkt-S-g100_max_TW-5','DL_Pkt-S-g100_max_TW-10','UL_Pkt-S-g100_max_TW-10','DL_Pkt-S-g100_max_TW-20','UL_Pkt-S-g100_max_TW-20','DL_Pkt-S-g100_max_SW','UL_Pkt-S-g100_max_SW',
            'DL_Pkt-S-g100_min_CW','UL_Pkt-S-g100_min_CW','DL_Pkt-S-g100_min_TW-1','UL_Pkt-S-g100_min_TW-1','DL_Pkt-S-g100_min_TW-3','UL_Pkt-S-g100_min_TW-3','DL_Pkt-S-g100_min_TW-5','UL_Pkt-S-g100_min_TW-5','DL_Pkt-S-g100_min_TW-10','UL_Pkt-S-g100_min_TW-10','DL_Pkt-S-g100_min_TW-20','UL_Pkt-S-g100_min_TW-20','DL_Pkt-S-g100_min_SW','UL_Pkt-S-g100_min_SW'])]

# %%
F3=A_all.columns

# %%
clf =  RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
                       criterion='gini', max_depth=90, max_features='auto',
                       max_leaf_nodes=None, max_samples=None,
                       min_impurity_decrease=0.0, min_impurity_split=None,
                       min_samples_leaf=4, min_samples_split=12,
                       min_weight_fraction_leaf=0.0, n_estimators=500,
                       n_jobs=None, oob_score=False, random_state=None,
                       verbose=0, warm_start=False)

clf.fit(A_all, yy)

importances = clf.feature_importances_
indices = np.argsort(importances)
top_k = 15
new_indices = indices[-top_k:]
# fig = plt.figure(figsize=(15, 10))
# plt.rcParams["axes.grid"] = False
# #plt.title('Feature Importances')
# plt.barh(range(len(new_indices)), importances[new_indices], color='c', align='edge')
# plt.yticks(range(len(new_indices)), [F3[i] for i in new_indices])
# #plt.xticks((0, 0.02, 0.07))
# plt.xlabel('Relative Importance')
# #plt.show()
# plt.savefig('b.pdf')
fig = plt.figure(figsize=(10,6))
plt.rcParams["axes.grid"] = False
ax = fig.add_subplot(111)
ax.barh(range(len(new_indices)), importances[new_indices], color='c',align='center')
plt.yticks(range(len(new_indices)), [F3[i] for i in new_indices])

plt.tight_layout()
#plt.show()
plt.savefig('full.pdf')

# %%
L=[]
for i in new_indices:
    l='%s'%F3[i]
    L.append(l)
L
# Out:
# ['UL_Pkt-S-g100_mean_SW',
#  'DL_Pkt-N-g100_total_TW-20',
#  'DL_Pkt-S-g100_mean_SW',
#  'UL_Pkt-S_mean_SW',
#  'DL_Pkt-S_mean_SW',
#  'UL_Pkt-S_std_SW',
#  'DL_Pkt-N_total_SW',
#  'DL_Pkt-N-g100_total_SW',
#  'DL_IA_std_SW',
#  'DL_IA_mean_SW',
#  'UL_Pkt-N_total_SW',
#  'UL_Th_avg_SW',
#  'UL_IA_mean_SW',
#  'UL_IA_std_SW',
#  'DL_Th_avg_SW']

# %%
A_ten=X.loc[:,X.columns.isin(['UL_Pkt-S-g100_mean_SW',
 'DL_Pkt-N-g100_total_TW-20',
 'DL_Pkt-S-g100_mean_SW',
 'UL_Pkt-S_mean_SW',
 'DL_Pkt-S_mean_SW',
 'UL_Pkt-S_std_SW',
 'DL_Pkt-N_total_SW',
 'DL_Pkt-N-g100_total_SW',
 'DL_IA_std_SW',
 'DL_IA_mean_SW',
 'UL_Pkt-N_total_SW',
 'UL_Th_avg_SW',
 'UL_IA_mean_SW',
 'UL_IA_std_SW',
 'DL_Th_avg_SW'])]

# %%
A_all_train, A_all_test,A_all_y_train, A_all_y_test = train_test_split( A_all, yy, test_size=0.2, random_state=None)
A_ten_train, A_ten_test,A_ten_y_train, A_ten_y_test = train_test_split( A_ten, yy, test_size=0.2, random_state=None)

# %%
from sklearn.model_selection import cross_validate
scoring = ['precision_weighted', 'recall_weighted', 'f1_weighted']
clf =  RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
                       criterion='gini', max_depth=90, max_features='auto',
                       max_leaf_nodes=None, max_samples=None,
                       min_impurity_decrease=0.0, min_impurity_split=None,
                       min_samples_leaf=4, min_samples_split=12,
                       min_weight_fraction_leaf=0.0, n_estimators=500,
                       n_jobs=None, oob_score=False, random_state=None,
                       verbose=0, warm_start=False)

scores = cross_validate(clf, A_ten, yy, cv=5,scoring=scoring, return_train_score=False)

# %%
scores
# Out:
# {'fit_time': array([70.55903649, 71.68864059, 70.80562115, 68.68062687, 67.67115355]),
#  'score_time': array([1.21751142, 1.27305317, 1.18658781, 1.15315199, 1.14781356]),
#  'test_precision_weighted': array([0.91109182, 0.8971012 , 0.89918782, 0.89787159, 0.89525502]),
#  'test_recall_weighted': array([0.91132888, 0.8968423 , 0.89883066, 0.89773696, 0.89518038]),
#  'test_f1_weighted': array([0.91117721, 0.89652671, 0.89873162, 0.89753421, 0.89473267])}

# %%
# load the model from disk
model =  RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
                       criterion='gini', max_depth=90, max_features='auto',
                       max_leaf_nodes=None, max_samples=None,
                       min_impurity_decrease=0.0, min_impurity_split=None,
                       min_samples_leaf=4, min_samples_split=12,
                       min_weight_fraction_leaf=0.0, n_estimators=500,
                       n_jobs=None, oob_score=False, random_state=None,
                       verbose=0, warm_start=False)
model.fit(A_all_train, A_all_y_train)


y_pred = model.predict(A_all_test)


accuracy = metrics.accuracy_score(A_all_y_test, y_pred)
print()
print('------------------------------------------------------')
print ("Accuracy of our RF classification  model based on test data is : {0:.4f}".format(accuracy))
print('------------------------------------------------------')

print()
print('------------------------------------------------------')
print ("Classification Report\n")
print('------------------------------------------------------')

print ("{0}".format(metrics.classification_report(A_all_y_test.ravel(), y_pred,target_names = ['LD', 'SD', 'HD'])))
# Out:
# ------------------------------------------------------
# Accuracy of our RF classification  model based on test data is : 0.9806
# ------------------------------------------------------
#
# ------------------------------------------------------
# Classification Report
#
# ------------------------------------------------------
#               precision    recall  f1-score   support
#
#           LD       0.98      0.97      0.98      6544
#           SD       0.98      0.97      0.97      6546
#           HD       0.98      0.99      0.99      8033
#
#     accuracy                           0.98     21123
#    macro avg       0.98      0.98      0.98     21123
# weighted avg       0.98      0.98      0.98     21123

# %%
# load the model from disk
model =  RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
                       criterion='gini', max_depth=90, max_features='auto',
                       max_leaf_nodes=None, max_samples=None,
                       min_impurity_decrease=0.0, min_impurity_split=None,
                       min_samples_leaf=4, min_samples_split=12,
                       min_weight_fraction_leaf=0.0, n_estimators=500,
                       n_jobs=None, oob_score=False, random_state=None,
                       verbose=0, warm_start=False)
model.fit(A_ten_train, A_ten_y_train)
y_pred = model.predict(A_ten_test)


accuracy = metrics.accuracy_score( A_ten_y_test, y_pred)
print()
print('------------------------------------------------------')
print ("Accuracy of our RF classification  model based on test data is : {0:.4f}".format(accuracy))
print('------------------------------------------------------')

print()
print('------------------------------------------------------')
print ("Classification Report\n")
print('------------------------------------------------------')

print ("{0}".format(metrics.classification_report(A_ten_y_test.ravel(), y_pred,target_names = ['LD', 'SD', 'HD'])))
# Out:
# ------------------------------------------------------
# Accuracy of our RF classification  model based on test data is : 0.9773
# ------------------------------------------------------
#
# ------------------------------------------------------
# Classification Report
#
# ------------------------------------------------------
#               precision    recall  f1-score   support
#
#           LD       0.98      0.97      0.97      6424
#           SD       0.97      0.97      0.97      6733
#           HD       0.98      0.99      0.99      7966
#
#     accuracy                           0.98     21123
#    macro avg       0.98      0.98      0.98     21123
# weighted avg       0.98      0.98      0.98     21123

# %%
from sklearn.metrics import plot_confusion_matrix
print()
print('------------------------------------------------------')
print ("Confusion Matrix Result \n")
print('------------------------------------------------------')

np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
titles_options = [("Confusion matrix without normalization", None), ("Normalized Confusion Matrix", 'true')]

for title, normalize in titles_options:
    fig, ax = plt.subplots(figsize=(8, 6))
    disp = plot_confusion_matrix(model,A_ten_test, A_ten_y_test, display_labels=['LD','SD','HD'],
                                 cmap=plt.cm.Blues,normalize=normalize,ax=ax)
    disp.ax_.set_title(title)

    print(title)
    print(disp.confusion_matrix)
    plt.savefig('normalized_confusion.pdf')
#plt.show()
# Out:
# ------------------------------------------------------
# Confusion Matrix Result
#
# ------------------------------------------------------
# Confusion matrix without normalization
# [[6374  114   56]
#  [ 105 6331  110]
#  [   6   45 7982]]
# Normalized Confusion Matrix
# [[9.74e-01 1.74e-02 8.56e-03]
#  [1.60e-02 9.67e-01 1.68e-02]
#  [7.47e-04 5.60e-03 9.94e-01]]
