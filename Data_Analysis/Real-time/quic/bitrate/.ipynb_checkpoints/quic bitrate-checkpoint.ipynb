# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from imblearn.over_sampling import SMOTE 
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import GridSearchCV
import warnings
warnings.simplefilter(action='ignore', category=Warning)
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Dataset

# %%
d = pd.read_csv('/media/loop/Backup/vm/tos1/quic/online/quic.csv')
d = d[(d[['Bitrate']] != 0).all(axis=1)]
d.isnull().values.any()
# drop rows with missing values
d.dropna(inplace=True)
X=d.iloc[:, 13:265] 
#Y=d.iloc[:,11]
Y=d.loc[:,d.columns.isin(['Bitrate'])]

# %%
Y.dropna(inplace=True)

# %% [markdown]
# # Features

# %%
X.columns=(['DL_Th_CW','UL_Th_CW','DL_Th_TW-1','UL_Th_TW-1','DL_Th_TW-3','UL_Th_TW-3','DL_Th_TW-5','UL_Th_TW-5','DL_Th_TW-10','UL_Th_TW-10','DL_Th_TW-20','UL_Th_TW-20','DL_Th_SW','UL_Th_SW','DL_Pkt_CW','UL_Pkt_CW','DL_Pkt_TW-1','UL_Pkt_TW-1','DL_Pkt_TW-3','UL_Pkt_TW-3','DL_Pkt_TW-5','UL_Pkt_TW-5','DL_Pkt_TW-10','UL_Pkt_TW-10','DL_Pkt_TW-20','UL_Pkt_TW-20','DL_Pkt_SW','UL_Pkt_SW','DL_Pkt-gt100_CW', 'UL_Pkt-gt100_CW', 'DL_Pkt-gt100_TW-1','UL_Pkt-gt100_TW-1','DL_Pkt-gt100_TW-3','UL_Pkt-gt100_TW-3','DL_Pkt-gt100_TW-5','UL_Pkt-gt100_TW-5','DL_Pkt-gt100_TW-10','UL_Pkt-gt100_TW-10','DL_Pkt-gt100_TW-20','UL_Pkt-gt100_TW-20','DL_Pkt-gt100_SW','UL_Pkt-gt100_SW','DL_IA_mean_CW','UL_IA_mean_CW','DL_IA_mean_TW-1','UL_IA_mean_TW-1','DL_IA_mean_TW-3','UL_IA_mean_TW-3','DL_IA_mean_TW-5','UL_IA_mean_TW-5','DL_IA_mean_TW-10','UL_IA_mean_TW-10','DL_IA_mean_TW-20','UL_IA_mean_TW-20','DL_IA_mean_SW','UL_IA_mean_SW','DL_IA_median_CW','UL_IA_median_CW','DL_IA_median_TW-1','UL_IA_median_TW-1','DL_IA_median_TW-3','UL_IA_median_TW-3','DL_IA_median_TW-5','UL_IA_median_TW-5','DL_IA_median_TW-10','UL_IA_median_TW-10','DL_IA_median_TW-20','UL_IA_median_TW-20','DL_IA_median_SW','UL_IA_median_SW','DL_IA_std_CW','UL_IA_std_CW','DL_IA_std_TW-1','UL_IA_std_TW-1','DL_IA_std_TW-3','UL_IA_std_TW-3','DL_IA_std_TW-5','UL_IA_std_TW-5','DL_IA_std_TW-10','UL_IA_std_TW-10','DL_IA_std_TW-20','UL_IA_std_TW-20','DL_IA_std_SW','UL_IA_std_SW',
'DL_IA_max_CW','UL_IA_max_CW','DL_IA_max_TW-1','UL_IA_max_TW-1','DL_IA_max_TW-3','UL_IA_max_TW-3','DL_IA_max_TW-5','UL_IA_max_TW-5','DL_IA_max_TW-10','UL_IA_max_TW-10','DL_IA_max_TW-20','UL_IA_max_TW-20','DL_IA_max_SW','UL_IA_max_SW','DL_IA_min_CW','UL_IA_min_CW','DL_IA_min_TW-1','UL_IA_min_TW-1','DL_IA_min_TW-3','UL_IA_min_TW-3','DL_IA_min_TW-5','UL_IA_min_TW-5','DL_IA_min_TW-10','UL_IA_min_TW-10','DL_IA_min_TW-20','UL_IA_min_TW-20','DL_IA_min_SW','UL_IA_min_SW','DL_Pkt-Size_mean_CW','UL_Pkt-Size_mean_CW','DL_Pkt-Size_mean_TW-1','UL_Pkt-Size_mean_TW-1','DL_Pkt-Size_mean_TW-3','UL_Pkt-Size_mean_TW-3','DL_Pkt-Size_mean_TW-5','UL_Pkt-Size_mean_TW-5','DL_Pkt-Size_mean_TW-10','UL_Pkt-Size_mean_TW-10','DL_Pkt-Size_mean_TW-20','UL_Pkt-Size_mean_TW-20','DL_Pkt-Size_mean_SW','UL_Pkt-Size_mean_SW','DL_Pkt-Size_median_CW','UL_Pkt-Size_median_CW','DL_Pkt-Size_median_TW-1','UL_Pkt-Size_median_TW-1','DL_Pkt-Size_median_TW-3','UL_Pkt-Size_median_TW-3','DL_Pkt-Size_median_TW-5','UL_Pkt-Size_median_TW-5','DL_Pkt-Size_median_TW-10','UL_Pkt-Size_median_TW-10','DL_Pkt-Size_median_TW-20','UL_Pkt-Size_median_TW-20','DL_Pkt-Size_median_SW','UL_Pkt-Size_median_SW',
'DL_Pkt-Size_std_CW','UL_Pkt-Size_std_CW','DL_Pkt-Size_std_TW-1','UL_Pkt-Size_std_TW-1','DL_Pkt-Size_std_TW-3','UL_Pkt-Size_std_TW-3','DL_Pkt-Size_std_TW-5','UL_Pkt-Size_std_TW-5','DL_Pkt-Size_std_TW-10','UL_Pkt-Size_std_TW-10','DL_Pkt-Size_std_TW-20','UL_Pkt-Size_std_TW-20','DL_Pkt-Size_std_SW','UL_Pkt-Size_std_SW','DL_Pkt-Size_max_CW','UL_Pkt-Size_max_CW','DL_Pkt-Size_max_TW-1','UL_Pkt-Size_max_TW-1','DL_Pkt-Size_max_TW-3','UL_Pkt-Size_max_TW-3','DL_Pkt-Size_max_TW-5','UL_Pkt-Size_max_TW-5','DL_Pkt-Size_max_TW-10','UL_Pkt-Size_max_TW-10','DL_Pkt-Size_max_TW-20','UL_Pkt-Size_max_TW-20','DL_Pkt-Size_max_SW','UL_Pkt-Size_max_SW','DL_Pkt-Size_min_CW','UL_Pkt-Size_min_CW','DL_Pkt-Size_min_TW-1','UL_Pkt-Size_min_TW-1','DL_Pkt-Size_min_TW-3','UL_Pkt-Size_min_TW-3','DL_Pkt-Size_min_TW-5','UL_Pkt-Size_min_TW-5','DL_Pkt-Size_min_TW-10','UL_Pkt-Size_min_TW-10','DL_Pkt-Size_min_TW-20','UL_Pkt-Size_min_TW-20','DL_Pkt-Size_min_SW','UL_Pkt-Size_min_SW','DL_Pkt-Size-gt100_mean_CW','UL_Pkt-Size-gt100_mean_CW','DL_Pkt-Size-gt100_mean_TW-1','UL_Pkt-Size-gt100_mean_TW-1','DL_Pkt-Size-gt100_mean_TW-3','UL_Pkt-Size-gt100_mean_TW-3','DL_Pkt-Size-gt100_mean_TW-5','UL_Pkt-Size-gt100_mean_TW-5','DL_Pkt-Size-gt100_mean_TW-10','UL_Pkt-Size-gt100_mean_TW-10','DL_Pkt-Size-gt100_mean_TW-20','UL_Pkt-Size-gt100_mean_TW-20','DL_Pkt-Size-gt100_mean_SW','UL_Pkt-Size-gt100_mean_SW',    
'DL_Pkt-Size-gt100_median_CW','UL_Pkt-Size-gt100_median_CW','DL_Pkt-Size-gt100_median_TW-1','UL_Pkt-Size-gt100_median_TW-1','DL_Pkt-Size-gt100_median_TW-3','UL_Pkt-Size-gt100_median_TW-3','DL_Pkt-Size-gt100_median_TW-5','UL_Pkt-Size-gt100_median_TW-5','DL_Pkt-Size-gt100_median_TW-10','UL_Pkt-Size-gt100_median_TW-10','DL_Pkt-Size-gt100_median_TW-20','UL_Pkt-Size-gt100_median_TW-20','DL_Pkt-Size-gt100_median_SW','UL_Pkt-Size-gt100_median_SW','DL_Pkt-Size-gt100_std_CW','UL_Pkt-Size-gt100_std_CW','DL_Pkt-Size-gt100_std_TW-1','UL_Pkt-Size-gt100_std_TW-1','DL_Pkt-Size-gt100_std_TW-3','UL_Pkt-Size-gt100_std_TW-3','DL_Pkt-Size-gt100_std_TW-5','UL_Pkt-Size-gt100_std_TW-5','DL_Pkt-Size-gt100_std_TW-10','UL_Pkt-Size-gt100_std_TW-10','DL_Pkt-Size-gt100_std_TW-20','UL_Pkt-Size-gt100_std_TW-20','DL_Pkt-Size-gt100_std_SW','UL_Pkt-Size-gt100_std_SW','DL_Pkt-Size--gt100_max_CW','UL_Pkt-Size-gt100_max_CW','DL_Pkt-Size-gt100_max_TW-1','UL_Pkt-Size-gt100_max_TW-1','DL_Pkt-Size-gt100_max_TW-3','UL_Pkt-Size-gt100_max_TW-3','DL_Pkt-Size-gt100_max_TW-5','UL_Pkt-Size-gt100_max_TW-5','DL_Pkt-Size-gt100_max_TW-10','UL_Pkt-Size-gt100_max_TW-10','DL_Pkt-Size-gt100_max_TW-20','UL_Pkt-Size-gt100_max_TW-20','DL_Pkt-Size-gt100_max_SW','UL_Pkt-Size-gt100_max_SW','DL_Pkt-Size-gt100_min_CW','UL_Pkt-Size-gt100_min_CW','DL_Pkt-Size-gt100_min_TW-1','UL_Pkt-Size-gt100_min_TW-1','DL_Pkt-Size-gt100_min_TW-3','UL_Pkt-Size-gt100_min_TW-3','DL_Pkt-Size-gt100_min_TW-5','UL_Pkt-Size-gt100_min_TW-5','DL_Pkt-Size-gt100_min_TW-10','UL_Pkt-Size-gt100_min_TW-10','DL_Pkt-Size-gt100_min_TW-20','UL_Pkt-Size-gt100_min_TW-20','DL_Pkt-Size-gt100_min_SW','UL_Pkt-Size-gt100_min_SW'])

# %% [markdown]
# # Target

# %%
conditions = [
    (Y['Bitrate']<=700 ),  
    (Y['Bitrate']>700) & (Y['Bitrate']<=2500),   
    (Y['Bitrate']>2500)  
    ]

choices = [0,1,2]
Y['bitrate1'] = np.select(conditions, choices, default='None')
yy=Y['bitrate1']

# %%
conditions = [
    (Y['Bitrate']<=700 ),  
    (Y['Bitrate']>700) & (Y['Bitrate']<=2500),   
    (Y['Bitrate']>2500)  
    ]

choices = ['Low','Moderate','High']
Y['bitrate2'] = np.select(conditions, choices, default='None')

# %% [markdown]
# # Distribution of Target

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
sns.set(font_scale=1.2, style="whitegrid")
plt.figure(figsize=(10, 8))
#df = pd.DataFrame(np.array([['a'], ['a'], ['b']]), columns=['current_status'])
ax = sns.countplot(y='bitrate2', data=Y,palette = "tab20")
ax.grid(False)
plt.title('Distribution of  Bitrates',weight="bold")
plt.xlabel('Percentages and Numbers ',weight="bold")
plt.ylabel('Bitrates',weight="bold")
#plt.yticks(np.arange(0, 1200, 120))
#plt.xticks(np.arange(0, 45000,5000))
plt.tick_params(axis='x',  colors='black')
plt.tick_params(axis='y', colors='black')

total = len(Y['bitrate2'])
for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_width()/total)
        x = p.get_x() + p.get_width() / 2
        y = p.get_y() - 0.02
        ax.annotate(percentage, (x, y))

#plt.show()
plt.savefig('resolution distrubutions-wo-balnace.pdf')

# %%
from imblearn.over_sampling import SMOTE
X.shape
yy.shape
smote=SMOTE(sampling_strategy='minority',random_state=42) # resample all class same
X, yy=smote.fit_resample(X,yy)
print('----------------------------------------')
print()
print('Applied Synthetic Minority Over-sampling Technique (SMOTE) to balance the dataset')
print('----------------------------------------')
print()
print(X.shape, yy.shape)
yyy=pd.DataFrame(yy)
yyy.columns = ['bitrate3']
# Out:
# ----------------------------------------
#
# Applied Synthetic Minority Over-sampling Technique (SMOTE) to balance the dataset
# ----------------------------------------
#
# (138213, 252) (138213,)

# %%
conditions = [
    (yyy['bitrate3']=='0'),  
    (yyy['bitrate3']=='1'),   
    (yyy['bitrate3']=='2')  
    ]

choices = ['Low','Moderate','High']
yyy['bitrate4'] = np.select(conditions, choices, default='None')

# %%
sns.set(font_scale=1.2, style="whitegrid")
plt.figure(figsize=(10, 8))
#df = pd.DataFrame(np.array([['a'], ['a'], ['b']]), columns=['current_status'])
ax = sns.countplot(y='bitrate4', data=yyy,palette = "tab20")
ax.grid(False)
plt.title('Distribution of  Bitrates',weight="bold")
plt.xlabel('Percentages and Numbers ',weight="bold")
plt.ylabel('Bitrates',weight="bold")
#plt.yticks(np.arange(0, 1200, 120))
plt.xticks(np.arange(0, 45000,5000))
plt.tick_params(axis='x',  colors='black')
plt.tick_params(axis='y', colors='black')

total = len(yyy['bitrate4'])
for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_width()/total)
        x = p.get_x() + p.get_width() / 2
        y = p.get_y() - 0.02
        ax.annotate(percentage, (x, y))

#plt.show()
plt.savefig('resolution distrubutions-with-balanace.pdf')

# %%
yy.shape
# Out:
# (105613,)

# %% [markdown]
# # Model Benchmark

# %%
seed = 42

# prepare models

param_grids=[]
##logistic
param_grids_0= {           
    'penalty':['l1', 'l2'], 
}
param_grids.append(param_grids_0)

##knn
param_grids_1 = {                      
    'n_neighbors': [3,5,7,10,25]
}
param_grids.append(param_grids_1)

## Decision Tree
param_grids_2 = { 
    'criterion':['gini', 'entropy'],
    'max_depth': [ 3, 10, 50, None],
    'min_samples_leaf': [3, 4, 5],
    'min_samples_split': [8, 10, 12],
    'class_weight': ['balanced',None]
}

param_grids.append(param_grids_2)
## NB
param_grids_3 = {   
    'priors':[None],
    'var_smoothing':[1e-09]
}

param_grids.append(param_grids_3)
 ## SVM
param_grids_4 = {  
     'gamma' :['scale'],
     'kernel' : [ 'rbf', 'poly'],
     #'degree' : [1,3,6],
     'C' : [0.01, 0.1, 1]

}
param_grids.append(param_grids_4)
 ### Random foresst
param_grids_5 = {      
    'bootstrap': [True],
    'max_depth': [ 3, 10, 50, 90, 100],
    'max_features': [3],
    'n_estimators': [100, 200,500],
    'min_samples_leaf': [3, 4, 5],
    'min_samples_split': [8, 10, 12],
    'class_weight': ['balanced',None]
}
param_grids.append(param_grids_5)
### MLP
param_grids_6 = {    
    'hidden_layer_sizes': [(50,50,50), (50,100,50), (100,)],
    'activation': ['identity', 'logistic', 'tanh', 'relu'],
    'solver': ['sgd', 'adam', 'lbfgs' ],
    'alpha': [0.0001, 0.05],
    'learning_rate': ['constant','adaptive'],
}
param_grids.append(param_grids_6)

models = []
models.append((LogisticRegression()))
models.append((KNeighborsClassifier()))
models.append((DecisionTreeClassifier()))
models.append((GaussianNB()))
models.append((SVC()))
models.append((RandomForestClassifier()))
models.append((MLPClassifier()))


best_estimator=[]


for i in range(7):
    #print(param_grids[i])
    #param_grids= param_grids_%d' % (i))
    grid_search = GridSearchCV(estimator = models[i], param_grid = param_grids[i],  cv =5, n_jobs = -1, verbose = 0, return_train_score=True)
    grid_search.fit(X, yy)
    #print(grid_search.best_params_)
    
    best_estimator.append(grid_search.best_estimator_)
    
print('----------------------------------------')
print('Best parameters for seven algorithms')
print('----------------------------------------')
print()

for j in range(7):
    print( best_estimator[j])
    print('\n')
# Out:
# ----------------------------------------
# Best parameters for seven algorithms
# ----------------------------------------
#
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
#
#
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=7, p=2,
#                      weights='uniform')
#
#
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=5, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')
#
#
# GaussianNB(priors=None, var_smoothing=1e-09)
#
#
# SVC(C=1, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='poly',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)
#
#
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=50, max_features=3,
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=3, min_samples_split=8,
#                        min_weight_fraction_leaf=0.0, n_estimators=500,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
#
#
# MLPClassifier(activation='identity', alpha=0.0001, batch_size='auto',
#               beta_1=0.9, beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(50, 50, 50), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=200,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=None, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)

# %%
import warnings
warnings.filterwarnings('ignore')
import pickle

print('----------------------------------------')
#print('Box plot of all model cross validation accuracy')
print('----------------------------------------')
print()
# prepare configuration for cross validation test harness
seed = 42
# prepare models
models = []

models.append(('LR',  best_estimator[0])) #LogisticRegression()
models.append(('KNN', best_estimator[1])) #KNeighborsClassifier()))
models.append(('DTC', best_estimator[2])) #DecisionTreeClassifier()))
models.append(('GNB', best_estimator[3]))
models.append(('SVM', best_estimator[4]))
models.append(('RFC', best_estimator[5]))
models.append(('MLP', best_estimator[6]))
# evaluate each model in turn
# evaluate each model in turn
ac = []
tr = []
names = []
scoring = 'accuracy'
for name, model in models:
    kfold = model_selection.KFold(n_splits=5, random_state=seed)
    cv_results = model_selection.cross_validate(model, X, yy, cv=kfold)
    ac.append((cv_results['test_score'])*100)
    tr.append((cv_results['fit_time'])/60)
    names.append(name)
    
    a_msg = "Accuracy %s: %f (%f)" % (name, ((cv_results['test_score'])*100).mean(), ((cv_results['test_score'])*100).std())
    t_msg = "Training time %s: %f (%f)" % (name, ((cv_results['fit_time'])/60).mean(),  ((cv_results['fit_time'])/60).std())
    print(a_msg)
    print(t_msg)
# boxplot algorithm comparison
# Out:
# ----------------------------------------
# ----------------------------------------
#
# Accuracy LR: 67.516305 (0.677247)
# Training time LR: 0.076912 (0.002990)
# Accuracy KNN: 77.841734 (0.630534)
# Training time KNN: 0.089488 (0.000696)
# Accuracy DTC: 87.813043 (0.552920)
# Training time DTC: 0.193096 (0.002197)
# Accuracy GNB: 55.567028 (1.203602)
# Training time GNB: 0.008672 (0.000110)
# Accuracy SVM: 63.858604 (0.732002)
# Training time SVM: 40.863441 (0.202958)
# Accuracy RFC: 89.719059 (0.808203)
# Training time RFC: 0.895835 (0.002887)
# Accuracy MLP: 66.160526 (11.810405)
# Training time MLP: 2.748320 (0.023874)

# %%
X.columns=(['DL_Th_CW','UL_Th_CW','DL_Th_TW-1','UL_Th_TW-1','DL_Th_TW-3','UL_Th_TW-3','DL_Th_TW-5','UL_Th_TW-5','DL_Th_TW-10','UL_Th_TW-10','DL_Th_TW-20','UL_Th_TW-20','DL_Th_SW','UL_Th_SW',
            'DL_Pkt_CW','UL_Pkt_CW','DL_Pkt_TW-1','UL_Pkt_TW-1','DL_Pkt_TW-3','UL_Pkt_TW-3','DL_Pkt_TW-5','UL_Pkt_TW-5','DL_Pkt_TW-10','UL_Pkt_TW-10','DL_Pkt_TW-20','UL_Pkt_TW-20','DL_Pkt_SW','UL_Pkt_SW',
            'DL_Pkt-g100_CW', 'UL_Pkt-g100_CW', 'DL_Pkt-g100_TW-1','UL_Pkt-g100_TW-1','DL_Pkt-g100_TW-3','UL_Pkt-g100_TW-3','DL_Pkt-g100_TW-5','UL_Pkt-g100_TW-5','DL_Pkt-g100_TW-10','UL_Pkt-g100_TW-10','DL_Pkt-g100_TW-20','UL_Pkt-g100_TW-20','DL_Pkt-g100_SW','UL_Pkt-g100_SW',
            'DL_IA_mean_CW','UL_IA_mean_CW','DL_IA_mean_TW-1','UL_IA_mean_TW-1','DL_IA_mean_TW-3','UL_IA_mean_TW-3','DL_IA_mean_TW-5','UL_IA_mean_TW-5','DL_IA_mean_TW-10','UL_IA_mean_TW-10','DL_IA_mean_TW-20','UL_IA_mean_TW-20','DL_IA_mean_SW','UL_IA_mean_SW',
            'DL_IA_medn_CW','UL_IA_medn_CW','DL_IA_medn_TW-1','UL_IA_medn_TW-1','DL_IA_medn_TW-3','UL_IA_medn_TW-3','DL_IA_medn_TW-5','UL_IA_medn_TW-5','DL_IA_medn_TW-10','UL_IA_medn_TW-10','DL_IA_medn_TW-20','UL_IA_medn_TW-20','DL_IA_med_SW','UL_IA_medn_SW',
            'DL_IA_std_CW','UL_IA_std_CW','DL_IA_std_TW-1','UL_IA_std_TW-1','DL_IA_std_TW-3','UL_IA_std_TW-3','DL_IA_std_TW-5','UL_IA_std_TW-5','DL_IA_std_TW-10','UL_IA_std_TW-10','DL_IA_std_TW-20','UL_IA_std_TW-20','DL_IA_std_SW','UL_IA_std_SW',
            'DL_IA_max_CW','UL_IA_max_CW','DL_IA_max_TW-1','UL_IA_max_TW-1','DL_IA_max_TW-3','UL_IA_max_TW-3','DL_IA_max_TW-5','UL_IA_max_TW-5','DL_IA_max_TW-10','UL_IA_max_TW-10','DL_IA_max_TW-20','UL_IA_max_TW-20','DL_IA_max_SW','UL_IA_max_SW',
            'DL_IA_min_CW','UL_IA_min_CW','DL_IA_min_TW-1','UL_IA_min_TW-1','DL_IA_min_TW-3','UL_IA_min_TW-3','DL_IA_min_TW-5','UL_IA_min_TW-5','DL_IA_min_TW-10','UL_IA_min_TW-10','DL_IA_min_TW-20','UL_IA_min_TW-20','DL_IA_min_SW','UL_IA_min_SW',
            'DL_Pkt-S_mean_CW','UL_Pkt-S_mean_CW','DL_Pkt-S_mean_TW-1','UL_Pkt-S_mean_TW-1','DL_Pkt-S_mean_TW-3','UL_Pkt-S_mean_TW-3','DL_Pkt-S_mean_TW-5','UL_Pkt-S_mean_TW-5','DL_Pkt-S_mean_TW-10','UL_Pkt-S_mean_TW-10','DL_Pkt-S_mean_TW-20','UL_Pkt-S_mean_TW-20','DL_Pkt-S_mean_SW','UL_Pkt-S_mean_SW',
            'DL_Pkt-S_medn_CW','UL_Pkt-S_medn_CW','DL_Pkt-S_medn_TW-1','UL_Pkt-S_medn_TW-1','DL_Pkt-S_medn_TW-3','UL_Pkt-S_medn_TW-3','DL_Pkt-S_medn_TW-5','UL_Pkt-S_medn_TW-5','DL_Pkt-S_medn_TW-10','UL_Pkt-S_medn_TW-10','DL_Pkt-S_medn_TW-20','UL_Pkt-S_medn_TW-20','DL_Pkt-S_medn_SW','UL_Pkt-S_medn_SW',
            'DL_Pkt-S_std_CW','UL_Pkt-S_std_CW','DL_Pkt-S_std_TW-1','UL_Pkt-S_std_TW-1','DL_Pkt-S_std_TW-3','UL_Pkt-S_std_TW-3','DL_Pkt-S_std_TW-5','UL_Pkt-S_std_TW-5','DL_Pkt-S_std_TW-10','UL_Pkt-S_std_TW-10','DL_Pkt-S_std_TW-20','UL_Pkt-S_std_TW-20','DL_Pkt-S_std_SW','UL_Pkt-S_std_SW',
            'DL_Pkt-S_max_CW','UL_Pkt-S_max_CW','DL_Pkt-S_max_TW-1','UL_Pkt-S_max_TW-1','DL_Pkt-S_max_TW-3','UL_Pkt-S_max_TW-3','DL_Pkt-S_max_TW-5','UL_Pkt-S_max_TW-5','DL_Pkt-S_max_TW-10','UL_Pkt-S_max_TW-10','DL_Pkt-S_max_TW-20','UL_Pkt-S_max_TW-20','DL_Pkt-S_max_SW','UL_Pkt-S_max_SW',
            'DL_Pkt-S_min_CW','UL_Pkt-S_min_CW','DL_Pkt-S_min_TW-1','UL_Pkt-S_min_TW-1','DL_Pkt-S_min_TW-3','UL_Pkt-S_min_TW-3','DL_Pkt-S_min_TW-5','UL_Pkt-S_min_TW-5','DL_Pkt-S_min_TW-10','UL_Pkt-S_min_TW-10','DL_Pkt-S_min_TW-20','UL_Pkt-S_min_TW-20','DL_Pkt-S_min_SW','UL_Pkt-S_min_SW',
            'DL_Pkt-S-g100_mean_CW','UL_Pkt-S-g100_mean_CW','DL_Pkt-S-g100_mean_TW-1','UL_Pkt-S-g100_mean_TW-1','DL_Pkt-S-g100_mean_TW-3','UL_Pkt-S-g100_mean_TW-3','DL_Pkt-S-g100_mean_TW-5','UL_Pkt-S-g100_mean_TW-5','DL_Pkt-S-g100_mean_TW-10','UL_Pkt-S-g100_mean_TW-10','DL_Pkt-S-g100_mean_TW-20','UL_Pkt-S-g100_mean_TW-20','DL_Pkt-S-g100_mean_SW','UL_Pkt-S-g100_mean_SW',    
            'DL_Pkt-S-g100_medn_CW','UL_Pkt-S-g100_medn_CW','DL_Pkt-S-g100_medn_TW-1','UL_Pkt-S-g100_medn_TW-1','DL_Pkt-S-g100_medn_TW-3','UL_Pkt-S-g100_medn_TW-3','DL_Pkt-S-g100_medn_TW-5','UL_Pkt-S-g100_medn_TW-5','DL_Pkt-S-g100_medn_TW-10','UL_Pkt-S-g100_medn_TW-10','DL_Pkt-S-g100_medn_TW-20','UL_Pkt-S-g100_medn_TW-20','DL_Pkt-S-g100_medn_SW','UL_Pkt-S-g100_medn_SW',
            'DL_Pkt-S-g100_std_CW','UL_Pkt-S-g100_std_CW','DL_Pkt-S-g100_std_TW-1','UL_Pkt-S-g100_std_TW-1','DL_Pkt-S-g100_std_TW-3','UL_Pkt-S-g100_std_TW-3','DL_Pkt-S-g100_std_TW-5','UL_Pkt-S-g100_std_TW-5','DL_Pkt-S-g100_std_TW-10','UL_Pkt-S-g100_std_TW-10','DL_Pkt-S-g100_std_TW-20','UL_Pkt-S-g100_std_TW-20','DL_Pkt-S-g100_std_SW','UL_Pkt-S-g100_std_SW',
            'DL_Pkt-S--g100_max_CW','UL_Pkt-S-g100_max_CW','DL_Pkt-S-g100_max_TW-1','UL_Pkt-S-g100_max_TW-1','DL_Pkt-S-g100_max_TW-3','UL_Pkt-S-g100_max_TW-3','DL_Pkt-S-g100_max_TW-5','UL_Pkt-S-g100_max_TW-5','DL_Pkt-S-g100_max_TW-10','UL_Pkt-S-g100_max_TW-10','DL_Pkt-S-g100_max_TW-20','UL_Pkt-S-g100_max_TW-20','DL_Pkt-S-g100_max_SW','UL_Pkt-S-g100_max_SW',
            'DL_Pkt-S-g100_min_CW','UL_Pkt-S-g100_min_CW','DL_Pkt-S-g100_min_TW-1','UL_Pkt-S-g100_min_TW-1','DL_Pkt-S-g100_min_TW-3','UL_Pkt-S-g100_min_TW-3','DL_Pkt-S-g100_min_TW-5','UL_Pkt-S-g100_min_TW-5','DL_Pkt-S-g100_min_TW-10','UL_Pkt-S-g100_min_TW-10','DL_Pkt-S-g100_min_TW-20','UL_Pkt-S-g100_min_TW-20','DL_Pkt-S-g100_min_SW','UL_Pkt-S-g100_min_SW'])

# %% [markdown]
# # Current Window

# %%
C_all=X.loc[:,X.columns.isin(['DL_Th_CW','UL_Th_CW','DL_Pkt_CW','UL_Pkt_CW','DL_Pkt-g100_CW', 'UL_Pkt-g100_CW', 'DL_IA_mean_CW','UL_IA_mean_CW','DL_IA_medn_CW','UL_IA_medn_CW','DL_IA_std_CW','UL_IA_std_CW','DL_IA_max_CW','UL_IA_max_CW','DL_IA_min_CW','UL_IA_min_CW','DL_Pkt-S_mean_CW','UL_Pkt-S_mean_CW','DL_Pkt-S_medn_CW','UL_Pkt-S_medn_CW','DL_Pkt-S_std_CW','UL_Pkt-S_std_CW', 'DL_Pkt-S_max_CW','UL_Pkt-S_max_CW','DL_Pkt-S_min_CW','UL_Pkt-S_min_CW','DL_Pkt-S-g100_mean_CW','UL_Pkt-S-g100_mean_CW','DL_Pkt-S-g100_medn_CW','UL_Pkt-S-g100_medn_CW','DL_Pkt-S-g100_std_CW','UL_Pkt-S-g100_std_CW',
'DL_Pkt-S--g100_max_CW','UL_Pkt-S-g100_max_CW','DL_Pkt-S-g100_min_CW','UL_Pkt-S-g100_min_CW'])]

# %%
F=C_all.columns

# %%
yy.value_counts()
# Out:
# 0    42722
# 2    35303
# 1    27588
# Name: bitrate1, dtype: int64

# %%
clf = RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
                       criterion='gini', max_depth=50, max_features=3,
                       max_leaf_nodes=None, max_samples=None,
                       min_impurity_decrease=0.0, min_impurity_split=None,
                       min_samples_leaf=3, min_samples_split=8,
                       min_weight_fraction_leaf=0.0, n_estimators=500,
                       n_jobs=None, oob_score=False, random_state=None,
                       verbose=0, warm_start=False)

clf.fit(C_all, yy)

importances = clf.feature_importances_
indices = np.argsort(importances)
top_k = 15
new_indices = indices[-top_k:]
# fig = plt.figure(figsize=(26, 12))
# plt.rcParams["axes.grid"] = False
# plt.rcParams['font.size'] = 18
# plt.rc('ytick',labelsize=17)
# plt.rc('xtick',labelsize=17)
# #plt.title('Feature Importances')
# plt.barh(range(len(new_indices)), importances[new_indices], color='c', align='center')
# plt.yticks(range(len(new_indices)), [F[i] for i in new_indices])
# #plt.xticks((0, 0.02, 0.07))
# #plt.xlabel('Relative Importance')
# #plt.show()
# plt.savefig('CW-top10.pdf')
fig = plt.figure(figsize=(10,6))
plt.rcParams["axes.grid"] = False
ax = fig.add_subplot(111)
ax.barh(range(len(new_indices)), importances[new_indices], color='c',align='center')
plt.yticks(range(len(new_indices)), [F[i] for i in new_indices])

plt.tight_layout()
#plt.show()
plt.savefig('CW-15.pdf')

# %%
L=[]
for i in new_indices:
    l='%s'%F[i]
    L.append(l)
L
# Out:
# ['DL_Pkt-g100_CW',
#  'DL_Pkt_CW',
#  'UL_IA_min_CW',
#  'DL_Pkt-S-g100_mean_CW',
#  'DL_Pkt-S_mean_CW',
#  'DL_IA_max_CW',
#  'UL_IA_max_CW',
#  'DL_Th_CW',
#  'DL_IA_min_CW',
#  'UL_IA_std_CW',
#  'DL_IA_std_CW',
#  'UL_IA_mean_CW',
#  'DL_IA_mean_CW',
#  'UL_IA_medn_CW',
#  'DL_IA_medn_CW']

# %%
C_ten=X.loc[:,X.columns.isin(['DL_Pkt-g100_CW',
 'DL_Pkt_CW',
 'UL_IA_min_CW',
 'DL_Pkt-S-g100_mean_CW',
 'DL_Pkt-S_mean_CW',
 'DL_IA_max_CW',
 'UL_IA_max_CW',
 'DL_Th_CW',
 'DL_IA_min_CW',
 'UL_IA_std_CW',
 'DL_IA_std_CW',
 'UL_IA_mean_CW',
 'DL_IA_mean_CW',
 'UL_IA_medn_CW',
 'DL_IA_medn_CW'])]

# %%
C_all_train, C_all_test,C_all_y_train, C_all_y_test = train_test_split( C_all, yy, test_size=0.2, random_state=101)
C_ten_train, C_ten_test,C_ten_y_train, C_ten_y_test = train_test_split( C_ten, yy, test_size=0.2, random_state=101)

# %%
# load the model from disk
model = RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
                       criterion='gini', max_depth=50, max_features=3,
                       max_leaf_nodes=None, max_samples=None,
                       min_impurity_decrease=0.0, min_impurity_split=None,
                       min_samples_leaf=3, min_samples_split=8,
                       min_weight_fraction_leaf=0.0, n_estimators=500,
                       n_jobs=None, oob_score=False, random_state=None,
                       verbose=0, warm_start=False)

model.fit(C_all_train, C_all_y_train)


y_pred = model.predict(C_all_test)


accuracy = metrics.accuracy_score( C_all_y_test, y_pred)
print()
print('------------------------------------------------------')
print ("Accuracy of our RF classification  model based on test data is : {0:.4f}".format(accuracy))
print('------------------------------------------------------')

print()
print('------------------------------------------------------')
print ("Classification Report\n")
print('------------------------------------------------------')

print ("{0}".format(metrics.classification_report(C_all_y_test.ravel(), y_pred,target_names = ['class Poor', 'class Average', 'class Good'])))
# Out:
# ------------------------------------------------------
# Accuracy of our RF classification  model based on test data is : 0.6087
# ------------------------------------------------------
#
# ------------------------------------------------------
# Classification Report
#
# ------------------------------------------------------
#                precision    recall  f1-score   support
#
#    class Poor       0.79      0.50      0.61      8606
# class Average       0.70      0.38      0.49      5415
#    class Good       0.51      0.91      0.66      7102
#
#      accuracy                           0.61     21123
#     macro avg       0.67      0.60      0.59     21123
#  weighted avg       0.67      0.61      0.60     21123

# %%
# load the model from disk
model = RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
                       criterion='gini', max_depth=50, max_features=3,
                       max_leaf_nodes=None, max_samples=None,
                       min_impurity_decrease=0.0, min_impurity_split=None,
                       min_samples_leaf=3, min_samples_split=8,
                       min_weight_fraction_leaf=0.0, n_estimators=500,
                       n_jobs=None, oob_score=False, random_state=None,
                       verbose=0, warm_start=False)

model.fit(C_ten_train, C_ten_y_train)


y_pred = model.predict(C_ten_test)


accuracy = metrics.accuracy_score( C_ten_y_test, y_pred)
print()
print('------------------------------------------------------')
print ("Accuracy of our RF classification  model based on test data is : {0:.4f}".format(accuracy))
print('------------------------------------------------------')

print()
print('------------------------------------------------------')
print ("Classification Report\n")
print('------------------------------------------------------')

print ("{0}".format(metrics.classification_report(C_ten_y_test.ravel(), y_pred,target_names = ['class Poor', 'class Average', 'class Good'])))
# Out:
# ------------------------------------------------------
# Accuracy of our RF classification  model based on test data is : 0.6014
# ------------------------------------------------------
#
# ------------------------------------------------------
# Classification Report
#
# ------------------------------------------------------
#                precision    recall  f1-score   support
#
#    class Poor       0.76      0.49      0.59      8606
# class Average       0.70      0.40      0.51      5415
#    class Good       0.51      0.90      0.65      7102
#
#      accuracy                           0.60     21123
#     macro avg       0.66      0.59      0.58     21123
#  weighted avg       0.66      0.60      0.59     21123

# %% [markdown]
# # Trend window

# %%
T_all=X.loc[:,X.columns.isin(['DL_Th_TW-1','UL_Th_TW-1','DL_Th_TW-3','UL_Th_TW-3','DL_Th_TW-5','UL_Th_TW-5','DL_Th_TW-10','UL_Th_TW-10','DL_Th_TW-20','UL_Th_TW-20','DL_Pkt_TW-1','UL_Pkt_TW-1','DL_Pkt_TW-3','UL_Pkt_TW-3','DL_Pkt_TW-5','UL_Pkt_TW-5','DL_Pkt_TW-10','UL_Pkt_TW-10','DL_Pkt_TW-20','UL_Pkt_TW-20', 'DL_Pkt-g100_TW-1','UL_Pkt-g100_TW-1','DL_Pkt-g100_TW-3','UL_Pkt-g100_TW-3','DL_Pkt-g100_TW-5','UL_Pkt-g100_TW-5','DL_Pkt-g100_TW-10','UL_Pkt-g100_TW-10','DL_Pkt-g100_TW-20','UL_Pkt-g100_TW-20','DL_IA_mean_TW-1','UL_IA_mean_TW-1','DL_IA_mean_TW-3','UL_IA_mean_TW-3','DL_IA_mean_TW-5','UL_IA_mean_TW-5','DL_IA_mean_TW-10','UL_IA_mean_TW-10','DL_IA_mean_TW-20','UL_IA_mean_TW-20','DL_IA_medn_TW-1','UL_IA_medn_TW-1','DL_IA_medn_TW-3','UL_IA_medn_TW-3','DL_IA_medn_TW-5','UL_IA_medn_TW-5','DL_IA_medn_TW-10','UL_IA_medn_TW-10','DL_IA_medn_TW-20','UL_IA_medn_TW-20','DL_IA_std_TW-1','UL_IA_std_TW-1','DL_IA_std_TW-3','UL_IA_std_TW-3','DL_IA_std_TW-5','UL_IA_std_TW-5','DL_IA_std_TW-10','UL_IA_std_TW-10','DL_IA_std_TW-20','UL_IA_std_TW-20','DL_IA_max_TW-1','UL_IA_max_TW-1','DL_IA_max_TW-3','UL_IA_max_TW-3','DL_IA_max_TW-5','UL_IA_max_TW-5','DL_IA_max_TW-10','UL_IA_max_TW-10','DL_IA_max_TW-20','UL_IA_max_TW-20','DL_IA_min_TW-1','UL_IA_min_TW-1','DL_IA_min_TW-3','UL_IA_min_TW-3','DL_IA_min_TW-5','UL_IA_min_TW-5','DL_IA_min_TW-10','UL_IA_min_TW-10','DL_IA_min_TW-20','UL_IA_min_TW-20','DL_Pkt-S_mean_TW-1','UL_Pkt-S_mean_TW-1','DL_Pkt-S_mean_TW-3','UL_Pkt-S_mean_TW-3','DL_Pkt-S_mean_TW-5','UL_Pkt-S_mean_TW-5','DL_Pkt-S_mean_TW-10','UL_Pkt-S_mean_TW-10','DL_Pkt-S_mean_TW-20','UL_Pkt-S_mean_TW-20','DL_Pkt-S_medn_TW-1','UL_Pkt-S_medn_TW-1','DL_Pkt-S_medn_TW-3','UL_Pkt-S_medn_TW-3','DL_Pkt-S_medn_TW-5','UL_Pkt-S_medn_TW-5','DL_Pkt-S_medn_TW-10','UL_Pkt-S_medn_TW-10','DL_Pkt-S_medn_TW-20','UL_Pkt-S_medn_TW-20','DL_Pkt-S_std_TW-1','UL_Pkt-S_std_TW-1','DL_Pkt-S_std_TW-3','UL_Pkt-S_std_TW-3','DL_Pkt-S_std_TW-5','UL_Pkt-S_std_TW-5','DL_Pkt-S_std_TW-10','UL_Pkt-S_std_TW-10','DL_Pkt-S_std_TW-20','UL_Pkt-S_std_TW-20','DL_Pkt-S_max_TW-1','UL_Pkt-S_max_TW-1','DL_Pkt-S_max_TW-3','UL_Pkt-S_max_TW-3','DL_Pkt-S_max_TW-5','UL_Pkt-S_max_TW-5','DL_Pkt-S_max_TW-10','UL_Pkt-S_max_TW-10','DL_Pkt-S_max_TW-20','UL_Pkt-S_max_TW-20','DL_Pkt-S_min_TW-1','UL_Pkt-S_min_TW-1','DL_Pkt-S_min_TW-3','UL_Pkt-S_min_TW-3','DL_Pkt-S_min_TW-5','UL_Pkt-S_min_TW-5','DL_Pkt-S_min_TW-10','UL_Pkt-S_min_TW-10','DL_Pkt-S_min_TW-20','UL_Pkt-S_min_TW-20','DL_Pkt-S-g100_mean_TW-1','UL_Pkt-S-g100_mean_TW-1','DL_Pkt-S-g100_mean_TW-3','UL_Pkt-S-g100_mean_TW-3','DL_Pkt-S-g100_mean_TW-5','UL_Pkt-S-g100_mean_TW-5','DL_Pkt-S-g100_mean_TW-10','UL_Pkt-S-g100_mean_TW-10','DL_Pkt-S-g100_mean_TW-20','UL_Pkt-S-g100_mean_TW-20','DL_Pkt-S-g100_medn_TW-1','UL_Pkt-S-g100_medn_TW-1','DL_Pkt-S-g100_medn_TW-3','UL_Pkt-S-g100_medn_TW-3','DL_Pkt-S-g100_medn_TW-5','UL_Pkt-S-g100_medn_TW-5','DL_Pkt-S-g100_medn_TW-10','UL_Pkt-S-g100_medn_TW-10','DL_Pkt-S-g100_medn_TW-20','UL_Pkt-S-g100_medn_TW-20','DL_Pkt-S-g100_std_TW-1','UL_Pkt-S-g100_std_TW-1','DL_Pkt-S-g100_std_TW-3','UL_Pkt-S-g100_std_TW-3','DL_Pkt-S-g100_std_TW-5','UL_Pkt-S-g100_std_TW-5','DL_Pkt-S-g100_std_TW-10','UL_Pkt-S-g100_std_TW-10','DL_Pkt-S-g100_std_TW-20','UL_Pkt-S-g100_std_TW-20','DL_Pkt-S-g100_max_TW-1','UL_Pkt-S-g100_max_TW-1','DL_Pkt-S-g100_max_TW-3','UL_Pkt-S-g100_max_TW-3','DL_Pkt-S-g100_max_TW-5','UL_Pkt-S-g100_max_TW-5','DL_Pkt-S-g100_max_TW-10','UL_Pkt-S-g100_max_TW-10','DL_Pkt-S-g100_max_TW-20','UL_Pkt-S-g100_max_TW-20','DL_Pkt-S-g100_min_TW-1','UL_Pkt-S-g100_min_TW-1','DL_Pkt-S-g100_min_TW-3','UL_Pkt-S-g100_min_TW-3','DL_Pkt-S-g100_min_TW-5','UL_Pkt-S-g100_min_TW-5','DL_Pkt-S-g100_min_TW-10','UL_Pkt-S-g100_min_TW-10','DL_Pkt-S-g100_min_TW-20','UL_Pkt-S-g100_min_TW-20'])]

# %%
F1=T_all.columns

# %%
clf = RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
                       criterion='gini', max_depth=50, max_features=3,
                       max_leaf_nodes=None, max_samples=None,
                       min_impurity_decrease=0.0, min_impurity_split=None,
                       min_samples_leaf=3, min_samples_split=8,
                       min_weight_fraction_leaf=0.0, n_estimators=500,
                       n_jobs=None, oob_score=False, random_state=None,
                       verbose=0, warm_start=False)

clf.fit(T_all, yy)

importances = clf.feature_importances_
indices = np.argsort(importances)
top_k = 15
new_indices = indices[-top_k:]
# fig = plt.figure(figsize=(26, 12))
# plt.rcParams["axes.grid"] = False
# plt.rcParams['font.size'] = 18
# plt.rc('ytick',labelsize=15)
# plt.rc('xtick',labelsize=15)
# #plt.title('Feature Importances')
# plt.barh(range(len(new_indices)), importances[new_indices], color='c', align='center')
# plt.yticks(range(len(new_indices)), [F1[i] for i in new_indices])
# #plt.xticks((0, 0.02, 0.07))
# #plt.xlabel('Relative Importance')
# #plt.show()
# plt.savefig('TW-top10.pdf')
fig = plt.figure(figsize=(10,6))
plt.rcParams["axes.grid"] = False
ax = fig.add_subplot(111)
ax.barh(range(len(new_indices)), importances[new_indices], color='c',align='center')
plt.yticks(range(len(new_indices)), [F1[i] for i in new_indices])

plt.tight_layout()
#plt.show()
plt.savefig('TW-15.pdf')

# %%
L=[]
for i in new_indices:
    l='%s'%F1[i]
    L.append(l)
L
# Out:
# ['DL_IA_medn_TW-20',
#  'DL_Pkt-S-g100_mean_TW-20',
#  'DL_Pkt-S_mean_TW-20',
#  'UL_Th_TW-20',
#  'UL_Pkt_TW-20',
#  'DL_Pkt-g100_TW-20',
#  'UL_Pkt-S-g100_std_TW-20',
#  'UL_Pkt-S-g100_medn_TW-20',
#  'UL_IA_mean_TW-20',
#  'DL_IA_mean_TW-20',
#  'UL_IA_std_TW-20',
#  'UL_Pkt-S_mean_TW-20',
#  'DL_IA_std_TW-20',
#  'UL_Pkt-S-g100_mean_TW-20',
#  'UL_Pkt-S_std_TW-20']

# %%
T_ten=X.loc[:,X.columns.isin(['DL_IA_medn_TW-20',
 'DL_Pkt-S-g100_mean_TW-20',
 'DL_Pkt-S_mean_TW-20',
 'UL_Th_TW-20',
 'UL_Pkt_TW-20',
 'DL_Pkt-g100_TW-20',
 'UL_Pkt-S-g100_std_TW-20',
 'UL_Pkt-S-g100_medn_TW-20',
 'UL_IA_mean_TW-20',
 'DL_IA_mean_TW-20',
 'UL_IA_std_TW-20',
 'UL_Pkt-S_mean_TW-20',
 'DL_IA_std_TW-20',
 'UL_Pkt-S-g100_mean_TW-20',
 'UL_Pkt-S_std_TW-20'])]

# %%
T_all_train, T_all_test,T_all_y_train, T_all_y_test = train_test_split( T_all, yy, test_size=0.2, random_state=101)
T_ten_train, T_ten_test,T_ten_y_train, T_ten_y_test = train_test_split( T_ten, yy, test_size=0.2, random_state=101)

# %%
# load the model from disk
model =  RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
                       criterion='gini', max_depth=50, max_features=3,
                       max_leaf_nodes=None, max_samples=None,
                       min_impurity_decrease=0.0, min_impurity_split=None,
                       min_samples_leaf=3, min_samples_split=8,
                       min_weight_fraction_leaf=0.0, n_estimators=500,
                       n_jobs=None, oob_score=False, random_state=None,
                       verbose=0, warm_start=False)
model.fit(T_all_train, T_all_y_train)


y_pred = model.predict(T_all_test)


accuracy = metrics.accuracy_score( T_all_y_test, y_pred)
print()
print('------------------------------------------------------')
print ("Accuracy of our RF classification  model based on test data is : {0:.4f}".format(accuracy))
print('------------------------------------------------------')

print()
print('------------------------------------------------------')
print ("Classification Report\n")
print('------------------------------------------------------')

print ("{0}".format(metrics.classification_report(T_all_y_test.ravel(), y_pred,target_names = ['LD', 'SD', 'HD'])))
# Out:
# ------------------------------------------------------
# Accuracy of our RF classification  model based on test data is : 0.8567
# ------------------------------------------------------
#
# ------------------------------------------------------
# Classification Report
#
# ------------------------------------------------------
#               precision    recall  f1-score   support
#
#           LD       0.95      0.81      0.87      8606
#           SD       0.95      0.77      0.85      5415
#           HD       0.74      0.98      0.84      7102
#
#     accuracy                           0.86     21123
#    macro avg       0.88      0.85      0.86     21123
# weighted avg       0.88      0.86      0.86     21123

# %%
# load the model from disk
model = RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
                       criterion='gini', max_depth=50, max_features=3,
                       max_leaf_nodes=None, max_samples=None,
                       min_impurity_decrease=0.0, min_impurity_split=None,
                       min_samples_leaf=3, min_samples_split=8,
                       min_weight_fraction_leaf=0.0, n_estimators=500,
                       n_jobs=None, oob_score=False, random_state=None,
                       verbose=0, warm_start=False)
model.fit(T_ten_train, T_ten_y_train)
y_pred = model.predict(T_ten_test)


accuracy = metrics.accuracy_score( T_ten_y_test, y_pred)
print()
print('------------------------------------------------------')
print ("Accuracy of our RF classification  model based on test data is : {0:.4f}".format(accuracy))
print('------------------------------------------------------')

print()
print('------------------------------------------------------')
print ("Classification Report\n")
print('------------------------------------------------------')

print ("{0}".format(metrics.classification_report(T_ten_y_test.ravel(), y_pred,target_names = ['LD', 'SD', 'HD'])))
# Out:
# ------------------------------------------------------
# Accuracy of our RF classification  model based on test data is : 0.8565
# ------------------------------------------------------
#
# ------------------------------------------------------
# Classification Report
#
# ------------------------------------------------------
#               precision    recall  f1-score   support
#
#           LD       0.95      0.80      0.87      8606
#           SD       0.94      0.78      0.85      5415
#           HD       0.74      0.98      0.85      7102
#
#     accuracy                           0.86     21123
#    macro avg       0.88      0.85      0.86     21123
# weighted avg       0.88      0.86      0.86     21123

# %% [markdown]
# # Session window

# %%
S_all=X.loc[:,X.columns.isin(['DL_Th_SW','UL_Th_SW','DL_Pkt_SW','UL_Pkt_SW','DL_Pkt-g100_SW','UL_Pkt-g100_SW','DL_IA_mean_SW','UL_IA_mean_SW','DL_IA_medn_SW','UL_IA_medn_SW','DL_IA_SWtd_SW','UL_IA_SWtd_SW','DL_IA_max_SW','UL_IA_max_SW','DL_IA_min_SW','UL_IA_min_SW','DL_Pkt-S_mean_SW','UL_Pkt-S_mean_SW','UL_Pkt-S_medn_TW-20','DL_Pkt-S_medn_SW','UL_Pkt-S_medn_SW','DL_Pkt-S_SWtd_SW','UL_Pkt-S_SWtd_SW','DL_Pkt-S_max_SW','UL_Pkt-S_max_SW','DL_Pkt-S_min_SW','UL_Pkt-S_min_SW','DL_Pkt-S-g100_mean_SW','UL_Pkt-S-g100_mean_SW','DL_Pkt-S-g100_medn_SW','UL_Pkt-S-g100_medn_SW','DL_Pkt-S-g100_SWtd_SW','UL_Pkt-S-g100_SWtd_SW','DL_Pkt-S-g100_max_SW','UL_Pkt-S-g100_max_SW','DL_Pkt-S-g100_min_SW','UL_Pkt-S-g100_min_SW'])]

# %%
F2=S_all.columns

# %%
clf =  RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
                       criterion='gini', max_depth=50, max_features=3,
                       max_leaf_nodes=None, max_samples=None,
                       min_impurity_decrease=0.0, min_impurity_split=None,
                       min_samples_leaf=3, min_samples_split=8,
                       min_weight_fraction_leaf=0.0, n_estimators=500,
                       n_jobs=None, oob_score=False, random_state=None,
                       verbose=0, warm_start=False)
clf.fit(S_all, yy)

importances = clf.feature_importances_
indices = np.argsort(importances)
top_k = 15
new_indices = indices[-top_k:]
# fig = plt.figure(figsize=(26, 12))
# plt.rcParams["axes.grid"] = False
# plt.rcParams['font.size'] = 18
# plt.rc('ytick',labelsize=15)
# plt.rc('xtick',labelsize=15)
# #plt.title('Feature Importances')
# plt.barh(range(len(new_indices)), importances[new_indices], color='c', align='edge')
# plt.yticks(range(len(new_indices)), [F2[i] for i in new_indices])
# #plt.xticks((0, 0.02, 0.07))
# #plt.xlabel('Relative Importance')
# #plt.show()
# plt.savefig('SW.pdf')
fig = plt.figure(figsize=(10,6))
plt.rcParams["axes.grid"] = False
ax = fig.add_subplot(111)
ax.barh(range(len(new_indices)), importances[new_indices], color='c',align='center')
plt.yticks(range(len(new_indices)), [F2[i] for i in new_indices])

plt.tight_layout()
#plt.show()
plt.savefig('SW.pdf')

# %%
L=[]
for i in new_indices:
    l='%s'%F2[i]
    L.append(l)
L
# Out:
# ['DL_Pkt-S_max_SW',
#  'UL_Pkt-S-g100_medn_SW',
#  'UL_IA_medn_SW',
#  'UL_Pkt-g100_SW',
#  'UL_Pkt-S-g100_mean_SW',
#  'DL_Pkt-S-g100_mean_SW',
#  'DL_Pkt-S_mean_SW',
#  'UL_Pkt-S_mean_SW',
#  'DL_Pkt_SW',
#  'DL_Pkt-g100_SW',
#  'UL_Pkt_SW',
#  'DL_IA_mean_SW',
#  'UL_Th_SW',
#  'UL_IA_mean_SW',
#  'DL_Th_SW']

# %%
S_ten=X.loc[:,X.columns.isin(['DL_Pkt-S_max_SW',
 'UL_Pkt-S-g100_medn_SW',
 'UL_IA_medn_SW',
 'UL_Pkt-g100_SW',
 'UL_Pkt-S-g100_mean_SW',
 'DL_Pkt-S-g100_mean_SW',
 'DL_Pkt-S_mean_SW',
 'UL_Pkt-S_mean_SW',
 'DL_Pkt_SW',
 'DL_Pkt-g100_SW',
 'UL_Pkt_SW',
 'DL_IA_mean_SW',
 'UL_Th_SW',
 'UL_IA_mean_SW',
 'DL_Th_SW'])]

# %%
S_all_train, S_all_test,S_all_y_train, S_all_y_test = train_test_split( S_all, yy, test_size=0.2, random_state=101)
S_ten_train, S_ten_test,S_ten_y_train, S_ten_y_test = train_test_split( S_ten, yy, test_size=0.2, random_state=101)

# %%
# load the model from disk
model =  RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
                       criterion='gini', max_depth=50, max_features=3,
                       max_leaf_nodes=None, max_samples=None,
                       min_impurity_decrease=0.0, min_impurity_split=None,
                       min_samples_leaf=3, min_samples_split=8,
                       min_weight_fraction_leaf=0.0, n_estimators=500,
                       n_jobs=None, oob_score=False, random_state=None,
                       verbose=0, warm_start=False)
model.fit(S_all_train, S_all_y_train)


y_pred = model.predict(S_all_test)


accuracy = metrics.accuracy_score( S_all_y_test, y_pred)
print()
print('------------------------------------------------------')
print ("Accuracy of our RF classification  model based on test data is : {0:.4f}".format(accuracy))
print('------------------------------------------------------')

print()
print('------------------------------------------------------')
print ("Classification Report\n")
print('------------------------------------------------------')

print ("{0}".format(metrics.classification_report(S_all_y_test.ravel(), y_pred,target_names = ['loq', 'moderate', 'high'])))
# Out:
# ------------------------------------------------------
# Accuracy of our RF classification  model based on test data is : 0.9782
# ------------------------------------------------------
#
# ------------------------------------------------------
# Classification Report
#
# ------------------------------------------------------
#               precision    recall  f1-score   support
#
#          loq       0.99      0.98      0.98      8606
#     moderate       0.98      0.95      0.96      5415
#         high       0.97      1.00      0.98      7102
#
#     accuracy                           0.98     21123
#    macro avg       0.98      0.98      0.98     21123
# weighted avg       0.98      0.98      0.98     21123

# %%
# load the model from disk
model = RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
                       criterion='gini', max_depth=50, max_features=3,
                       max_leaf_nodes=None, max_samples=None,
                       min_impurity_decrease=0.0, min_impurity_split=None,
                       min_samples_leaf=3, min_samples_split=8,
                       min_weight_fraction_leaf=0.0, n_estimators=500,
                       n_jobs=None, oob_score=False, random_state=None,
                       verbose=0, warm_start=False)
model.fit(S_ten_train, S_ten_y_train)
y_pred = model.predict(S_ten_test)


accuracy = metrics.accuracy_score( S_ten_y_test, y_pred)
print()
print('------------------------------------------------------')
print ("Accuracy of our RF classification  model based on test data is : {0:.4f}".format(accuracy))
print('------------------------------------------------------')

print()
print('------------------------------------------------------')
print ("Classification Report\n")
print('------------------------------------------------------')

print ("{0}".format(metrics.classification_report(S_ten_y_test.ravel(), y_pred,target_names = ['low', 'moderate', 'high'])))
# Out:
# ------------------------------------------------------
# Accuracy of our RF classification  model based on test data is : 0.9770
# ------------------------------------------------------
#
# ------------------------------------------------------
# Classification Report
#
# ------------------------------------------------------
#               precision    recall  f1-score   support
#
#          low       0.99      0.98      0.98      8606
#     moderate       0.98      0.95      0.96      5415
#         high       0.97      0.99      0.98      7102
#
#     accuracy                           0.98     21123
#    macro avg       0.98      0.97      0.98     21123
# weighted avg       0.98      0.98      0.98     21123

# %% [markdown]
# # All Window

# %%
A_all=X.loc[:,X.columns.isin(['DL_Th_CW','UL_Th_CW','DL_Th_TW-1','UL_Th_TW-1','DL_Th_TW-3','UL_Th_TW-3','DL_Th_TW-5','UL_Th_TW-5','DL_Th_TW-10','UL_Th_TW-10','DL_Th_TW-20','UL_Th_TW-20','DL_Th_SW','UL_Th_SW',
            'DL_Pkt_CW','UL_Pkt_CW','DL_Pkt_TW-1','UL_Pkt_TW-1','DL_Pkt_TW-3','UL_Pkt_TW-3','DL_Pkt_TW-5','UL_Pkt_TW-5','DL_Pkt_TW-10','UL_Pkt_TW-10','DL_Pkt_TW-20','UL_Pkt_TW-20','DL_Pkt_SW','UL_Pkt_SW',
            'DL_Pkt-g100_CW', 'UL_Pkt-g100_CW', 'DL_Pkt-g100_TW-1','UL_Pkt-g100_TW-1','DL_Pkt-g100_TW-3','UL_Pkt-g100_TW-3','DL_Pkt-g100_TW-5','UL_Pkt-g100_TW-5','DL_Pkt-g100_TW-10','UL_Pkt-g100_TW-10','DL_Pkt-g100_TW-20','UL_Pkt-g100_TW-20','DL_Pkt-g100_SW','UL_Pkt-g100_SW',
            'DL_IA_mean_CW','UL_IA_mean_CW','DL_IA_mean_TW-1','UL_IA_mean_TW-1','DL_IA_mean_TW-3','UL_IA_mean_TW-3','DL_IA_mean_TW-5','UL_IA_mean_TW-5','DL_IA_mean_TW-10','UL_IA_mean_TW-10','DL_IA_mean_TW-20','UL_IA_mean_TW-20','DL_IA_mean_SW','UL_IA_mean_SW',
            'DL_IA_medn_CW','UL_IA_medn_CW','DL_IA_medn_TW-1','UL_IA_medn_TW-1','DL_IA_medn_TW-3','UL_IA_medn_TW-3','DL_IA_medn_TW-5','UL_IA_medn_TW-5','DL_IA_medn_TW-10','UL_IA_medn_TW-10','DL_IA_medn_TW-20','UL_IA_medn_TW-20','DL_IA_med_SW','UL_IA_medn_SW',
            'DL_IA_std_CW','UL_IA_std_CW','DL_IA_std_TW-1','UL_IA_std_TW-1','DL_IA_std_TW-3','UL_IA_std_TW-3','DL_IA_std_TW-5','UL_IA_std_TW-5','DL_IA_std_TW-10','UL_IA_std_TW-10','DL_IA_std_TW-20','UL_IA_std_TW-20','DL_IA_std_SW','UL_IA_std_SW',
            'DL_IA_max_CW','UL_IA_max_CW','DL_IA_max_TW-1','UL_IA_max_TW-1','DL_IA_max_TW-3','UL_IA_max_TW-3','DL_IA_max_TW-5','UL_IA_max_TW-5','DL_IA_max_TW-10','UL_IA_max_TW-10','DL_IA_max_TW-20','UL_IA_max_TW-20','DL_IA_max_SW','UL_IA_max_SW',
            'DL_IA_min_CW','UL_IA_min_CW','DL_IA_min_TW-1','UL_IA_min_TW-1','DL_IA_min_TW-3','UL_IA_min_TW-3','DL_IA_min_TW-5','UL_IA_min_TW-5','DL_IA_min_TW-10','UL_IA_min_TW-10','DL_IA_min_TW-20','UL_IA_min_TW-20','DL_IA_min_SW','UL_IA_min_SW',
            'DL_Pkt-S_mean_CW','UL_Pkt-S_mean_CW','DL_Pkt-S_mean_TW-1','UL_Pkt-S_mean_TW-1','DL_Pkt-S_mean_TW-3','UL_Pkt-S_mean_TW-3','DL_Pkt-S_mean_TW-5','UL_Pkt-S_mean_TW-5','DL_Pkt-S_mean_TW-10','UL_Pkt-S_mean_TW-10','DL_Pkt-S_mean_TW-20','UL_Pkt-S_mean_TW-20','DL_Pkt-S_mean_SW','UL_Pkt-S_mean_SW',
            'DL_Pkt-S_medn_CW','UL_Pkt-S_medn_CW','DL_Pkt-S_medn_TW-1','UL_Pkt-S_medn_TW-1','DL_Pkt-S_medn_TW-3','UL_Pkt-S_medn_TW-3','DL_Pkt-S_medn_TW-5','UL_Pkt-S_medn_TW-5','DL_Pkt-S_medn_TW-10','UL_Pkt-S_medn_TW-10','DL_Pkt-S_medn_TW-20','UL_Pkt-S_medn_TW-20','DL_Pkt-S_medn_SW','UL_Pkt-S_medn_SW',
            'DL_Pkt-S_std_CW','UL_Pkt-S_std_CW','DL_Pkt-S_std_TW-1','UL_Pkt-S_std_TW-1','DL_Pkt-S_std_TW-3','UL_Pkt-S_std_TW-3','DL_Pkt-S_std_TW-5','UL_Pkt-S_std_TW-5','DL_Pkt-S_std_TW-10','UL_Pkt-S_std_TW-10','DL_Pkt-S_std_TW-20','UL_Pkt-S_std_TW-20','DL_Pkt-S_std_SW','UL_Pkt-S_std_SW',
            'DL_Pkt-S_max_CW','UL_Pkt-S_max_CW','DL_Pkt-S_max_TW-1','UL_Pkt-S_max_TW-1','DL_Pkt-S_max_TW-3','UL_Pkt-S_max_TW-3','DL_Pkt-S_max_TW-5','UL_Pkt-S_max_TW-5','DL_Pkt-S_max_TW-10','UL_Pkt-S_max_TW-10','DL_Pkt-S_max_TW-20','UL_Pkt-S_max_TW-20','DL_Pkt-S_max_SW','UL_Pkt-S_max_SW',
            'DL_Pkt-S_min_CW','UL_Pkt-S_min_CW','DL_Pkt-S_min_TW-1','UL_Pkt-S_min_TW-1','DL_Pkt-S_min_TW-3','UL_Pkt-S_min_TW-3','DL_Pkt-S_min_TW-5','UL_Pkt-S_min_TW-5','DL_Pkt-S_min_TW-10','UL_Pkt-S_min_TW-10','DL_Pkt-S_min_TW-20','UL_Pkt-S_min_TW-20','DL_Pkt-S_min_SW','UL_Pkt-S_min_SW',
            'DL_Pkt-S-g100_mean_CW','UL_Pkt-S-g100_mean_CW','DL_Pkt-S-g100_mean_TW-1','UL_Pkt-S-g100_mean_TW-1','DL_Pkt-S-g100_mean_TW-3','UL_Pkt-S-g100_mean_TW-3','DL_Pkt-S-g100_mean_TW-5','UL_Pkt-S-g100_mean_TW-5','DL_Pkt-S-g100_mean_TW-10','UL_Pkt-S-g100_mean_TW-10','DL_Pkt-S-g100_mean_TW-20','UL_Pkt-S-g100_mean_TW-20','DL_Pkt-S-g100_mean_SW','UL_Pkt-S-g100_mean_SW',    
            'DL_Pkt-S-g100_medn_CW','UL_Pkt-S-g100_medn_CW','DL_Pkt-S-g100_medn_TW-1','UL_Pkt-S-g100_medn_TW-1','DL_Pkt-S-g100_medn_TW-3','UL_Pkt-S-g100_medn_TW-3','DL_Pkt-S-g100_medn_TW-5','UL_Pkt-S-g100_medn_TW-5','DL_Pkt-S-g100_medn_TW-10','UL_Pkt-S-g100_medn_TW-10','DL_Pkt-S-g100_medn_TW-20','UL_Pkt-S-g100_medn_TW-20','DL_Pkt-S-g100_medn_SW','UL_Pkt-S-g100_medn_SW',
            'DL_Pkt-S-g100_std_CW','UL_Pkt-S-g100_std_CW','DL_Pkt-S-g100_std_TW-1','UL_Pkt-S-g100_std_TW-1','DL_Pkt-S-g100_std_TW-3','UL_Pkt-S-g100_std_TW-3','DL_Pkt-S-g100_std_TW-5','UL_Pkt-S-g100_std_TW-5','DL_Pkt-S-g100_std_TW-10','UL_Pkt-S-g100_std_TW-10','DL_Pkt-S-g100_std_TW-20','UL_Pkt-S-g100_std_TW-20','DL_Pkt-S-g100_std_SW','UL_Pkt-S-g100_std_SW',
            'DL_Pkt-S--g100_max_CW','UL_Pkt-S-g100_max_CW','DL_Pkt-S-g100_max_TW-1','UL_Pkt-S-g100_max_TW-1','DL_Pkt-S-g100_max_TW-3','UL_Pkt-S-g100_max_TW-3','DL_Pkt-S-g100_max_TW-5','UL_Pkt-S-g100_max_TW-5','DL_Pkt-S-g100_max_TW-10','UL_Pkt-S-g100_max_TW-10','DL_Pkt-S-g100_max_TW-20','UL_Pkt-S-g100_max_TW-20','DL_Pkt-S-g100_max_SW','UL_Pkt-S-g100_max_SW',
            'DL_Pkt-S-g100_min_CW','UL_Pkt-S-g100_min_CW','DL_Pkt-S-g100_min_TW-1','UL_Pkt-S-g100_min_TW-1','DL_Pkt-S-g100_min_TW-3','UL_Pkt-S-g100_min_TW-3','DL_Pkt-S-g100_min_TW-5','UL_Pkt-S-g100_min_TW-5','DL_Pkt-S-g100_min_TW-10','UL_Pkt-S-g100_min_TW-10','DL_Pkt-S-g100_min_TW-20','UL_Pkt-S-g100_min_TW-20','DL_Pkt-S-g100_min_SW','UL_Pkt-S-g100_min_SW'])]

# %%
F3=A_all.columns

# %%
clf = RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
                       criterion='gini', max_depth=50, max_features=3,
                       max_leaf_nodes=None, max_samples=None,
                       min_impurity_decrease=0.0, min_impurity_split=None,
                       min_samples_leaf=3, min_samples_split=8,
                       min_weight_fraction_leaf=0.0, n_estimators=500,
                       n_jobs=None, oob_score=False, random_state=None,
                       verbose=0, warm_start=False)
clf.fit(A_all, yy)

importances = clf.feature_importances_
indices = np.argsort(importances)
top_k = 15
new_indices = indices[-top_k:]
# fig = plt.figure(figsize=(15, 10))
# plt.rcParams["axes.grid"] = False
# #plt.title('Feature Importances')
# plt.barh(range(len(new_indices)), importances[new_indices], color='c', align='edge')
# plt.yticks(range(len(new_indices)), [F3[i] for i in new_indices])
# #plt.xticks((0, 0.02, 0.07))
# plt.xlabel('Relative Importance')
# #plt.show()
# plt.savefig('b.pdf')
fig = plt.figure(figsize=(10,6))
plt.rcParams["axes.grid"] = False
ax = fig.add_subplot(111)
ax.barh(range(len(new_indices)), importances[new_indices], color='c',align='center')
plt.yticks(range(len(new_indices)), [F3[i] for i in new_indices])

plt.tight_layout()
#plt.show()
plt.savefig('full.pdf')

# %%
L=[]
for i in new_indices:
    l='%s'%F3[i]
    L.append(l)
L
# Out:
# ['UL_Pkt-S-g100_medn_SW',
#  'DL_Pkt-S-g100_mean_SW',
#  'UL_Pkt-S-g100_mean_SW',
#  'UL_Pkt-S_mean_SW',
#  'UL_Pkt-S_std_SW',
#  'DL_Pkt-S_mean_SW',
#  'DL_Pkt_SW',
#  'DL_IA_mean_SW',
#  'DL_IA_std_SW',
#  'DL_Pkt-g100_SW',
#  'UL_Pkt_SW',
#  'UL_IA_std_SW',
#  'UL_IA_mean_SW',
#  'UL_Th_SW',
#  'DL_Th_SW']

# %%
A_ten=X.loc[:,X.columns.isin(['UL_Pkt-S-g100_medn_SW',
 'DL_Pkt-S-g100_mean_SW',
 'UL_Pkt-S-g100_mean_SW',
 'UL_Pkt-S_mean_SW',
 'UL_Pkt-S_std_SW',
 'DL_Pkt-S_mean_SW',
 'DL_Pkt_SW',
 'DL_IA_mean_SW',
 'DL_IA_std_SW',
 'DL_Pkt-g100_SW',
 'UL_Pkt_SW',
 'UL_IA_std_SW',
 'UL_IA_mean_SW',
 'UL_Th_SW',
 'DL_Th_SW'])]

# %%
A_all_train, A_all_test,A_all_y_train, A_all_y_test = train_test_split( A_all, yy, test_size=0.2, random_state=101)
A_ten_train, A_ten_test,A_ten_y_train, A_ten_y_test = train_test_split( A_ten, yy, test_size=0.2, random_state=101)

# %%
# load the model from disk
model =  RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
                       criterion='gini', max_depth=50, max_features=3,
                       max_leaf_nodes=None, max_samples=None,
                       min_impurity_decrease=0.0, min_impurity_split=None,
                       min_samples_leaf=3, min_samples_split=8,
                       min_weight_fraction_leaf=0.0, n_estimators=500,
                       n_jobs=None, oob_score=False, random_state=None,
                       verbose=0, warm_start=False)
model.fit(A_all_train, A_all_y_train)


y_pred = model.predict(A_all_test)


accuracy = metrics.accuracy_score(A_all_y_test, y_pred)
print()
print('------------------------------------------------------')
print ("Accuracy of our RF classification  model based on test data is : {0:.4f}".format(accuracy))
print('------------------------------------------------------')

print()
print('------------------------------------------------------')
print ("Classification Report\n")
print('------------------------------------------------------')

print ("{0}".format(metrics.classification_report(A_all_y_test.ravel(), y_pred,target_names = ['loq', 'moderate', 'high'])))
# Out:
# ------------------------------------------------------
# Accuracy of our RF classification  model based on test data is : 0.9687
# ------------------------------------------------------
#
# ------------------------------------------------------
# Classification Report
#
# ------------------------------------------------------
#               precision    recall  f1-score   support
#
#          loq       0.97      0.98      0.98      8606
#     moderate       0.97      0.93      0.95      5415
#         high       0.96      0.99      0.98      7102
#
#     accuracy                           0.97     21123
#    macro avg       0.97      0.96      0.97     21123
# weighted avg       0.97      0.97      0.97     21123

# %%
# load the model from disk
model = RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
                       criterion='gini', max_depth=50, max_features=3,
                       max_leaf_nodes=None, max_samples=None,
                       min_impurity_decrease=0.0, min_impurity_split=None,
                       min_samples_leaf=3, min_samples_split=8,
                       min_weight_fraction_leaf=0.0, n_estimators=500,
                       n_jobs=None, oob_score=False, random_state=None,
                       verbose=0, warm_start=False)
model.fit(A_ten_train, A_ten_y_train)
y_pred = model.predict(A_ten_test)


accuracy = metrics.accuracy_score( A_ten_y_test, y_pred)
print()
print('------------------------------------------------------')
print ("Accuracy of our RF classification  model based on test data is : {0:.4f}".format(accuracy))
print('------------------------------------------------------')

print()
print('------------------------------------------------------')
print ("Classification Report\n")
print('------------------------------------------------------')

print ("{0}".format(metrics.classification_report(A_ten_y_test.ravel(), y_pred,target_names = ['low', 'moderate', 'high'])))
# Out:
# ------------------------------------------------------
# Accuracy of our RF classification  model based on test data is : 0.9763
# ------------------------------------------------------
#
# ------------------------------------------------------
# Classification Report
#
# ------------------------------------------------------
#               precision    recall  f1-score   support
#
#          low       0.99      0.98      0.98      8606
#     moderate       0.97      0.95      0.96      5415
#         high       0.97      0.99      0.98      7102
#
#     accuracy                           0.98     21123
#    macro avg       0.98      0.97      0.97     21123
# weighted avg       0.98      0.98      0.98     21123

# %%
from sklearn.metrics import plot_confusion_matrix
print()
print('------------------------------------------------------')
print ("Confusion Matrix Result \n")
print('------------------------------------------------------')

np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
titles_options = [("Confusion matrix without normalization", None), ("Normalized Confusion Matrix", 'true')]

for title, normalize in titles_options:
    fig, ax = plt.subplots(figsize=(10, 10))
    disp = plot_confusion_matrix(model,A_ten_test, A_ten_y_test, display_labels=['Low','Moderate','High'],
                                 cmap=plt.cm.Blues,normalize=normalize,ax=ax)
    disp.ax_.set_title(title)

    print(title)
    print(disp.confusion_matrix)
plt.savefig('normalized_confusion.pdf')
#plt.show()
# Out:
# ------------------------------------------------------
# Confusion Matrix Result
#
# ------------------------------------------------------
# Confusion matrix without normalization
# [[8439   97   70]
#  [ 114 5122  179]
#  [   3   37 7062]]
# Normalized Confusion Matrix
# [[9.81e-01 1.13e-02 8.13e-03]
#  [2.11e-02 9.46e-01 3.31e-02]
#  [4.22e-04 5.21e-03 9.94e-01]]
