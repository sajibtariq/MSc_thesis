# %%
import nest_asyncio
nest_asyncio.apply()
import pandas as pd
from scapy.all import *
import numpy as np
import pandas as pd

mode=['3g','4g','5g'] 
#mode=['5g'] 
host=[1] 

algo=['conventional','bba', 'arbiter','elastic','bba','logistic'] # adaptation algorithm  'elastic','bba','logistic'

#algo=['logistic'] 
net3= ['train', 'ferry','car','bus','metro'] # mobility for 3g

net4=['bus', 'train', 'static','car','pedestrian'] # mobility for 4g

net5=[ 'Static-1','Static-2', 'Static-3', 'Driving-1', 'Driving-2'] # mobility for 5g

prot=['tcp']

sertype=['WSGI']

video_id=['tos1']

iteration = 1


for it in range(iteration):
    it=it+5
    for md in mode:
            if md =='3g':
                net=net3
            elif md=='4g':
                net=net4
            elif md=='5g':
                net=net5
            for ii in net:
                for vd in video_id:
                    for kk in sertype:
                        for ll in host:
                            for mm in algo:
                                 for pp in prot:
                                    try:
                                        

                                        xx=pd.read_csv('/media/loop/Backup/vm/tos1/'+str(it)+'/iteration_' + str(it)+ '_video_' + str(vd)+'_mode_'+(md)+ '_net_' + str(ii) +'_host_'+ str(ll)+ '_algo_' + str(mm)+ '_protocol_' + str(pp)+'_server_' + str(kk)+'/time-log.csv', header=None)
        
                                        xx=xx.drop([0])

                                        data= pd.DataFrame(columns= ['iteration','mode','mobility','video','server-type','host','algo','protocol',
                                                'Time(s)','Stall_event','Bitrate', 'Resolution(w)','Resolution(h)',
                                                'd_th_05','u_th_05','d_th_1','u_th_1','d_th_3','u_th_3','d_th_5','u_th_5','d_th_10','u_th_10','d_th_20','u_th_20','d_th_all','u_th_all',                      
                                                'd_pk_05','u_pk_05','d_pk_1','u_pk_1','d_pk_3','u_pk_3','d_pk_5','u_pk_5','d_pk_10','u_pk_10','d_pk_20','u_pk_20','d_pk_all','u_pk_all',
                                                'd_pkgt100_05','u_pkgt100_05','d_pkgt100_1','u_pkgt100_1','d_pkgt100_3','u_pkgt100_3','d_pkgt100_5','u_pkgt100_5','d_pkgt100_10','u_pkgt100_10','d_pkgt100_20','u_pkgt100_20','d_pkgt100_all','u_pkgt100_all',
                                                'd_ia_mean_05','u_ia_mean_05','d_ia_mean_1','u_ia_mean_1','d_ia_mean_3','u_ia_mean_3','d_ia_mean_5','u_ia_mean_5','d_ia_mean_10','u_ia_mean_10','d_ia_mean_20','u_ia_mean_20','d_ia_mean_all','u_ia_mean_all',
                                                'd_ia_median_05','u_ia_median_05','d_ia_median_1','u_ia_median_1','d_ia_median_3','u_ia_median_3','d_ia_median_5','u_ia_medina_5','d_ia_median_10','u_ia_median_10','d_ia_median_20','u_ia_median_20','d_ia_median_all','u_ia_median_all',
                                                'd_ia_std_05','u_ia_std_05','d_ia_std_1','u_ia_std_1','d_ia_std_3','u_ia_std_3','d_ia_std_5','u_ia_std_5','d_ia_std_10','u_ia_std_10','d_ia_std_20','u_ia_std_20','d_ia_std_all','u_ia_std_all',
                                                'd_ia_max_05','u_ia_max_05','d_ia_max_1','u_ia_max_1','d_ia_max_3','u_ia_max_3','d_ia_max_5','u_ia_max_5','d_ia_max_10','u_ia_max_10','d_ia_max_20','u_ia_max_20','d_ia_max_all','u_ia_max_all',
                                                'd_ia_min_05','u_ia_min_05','d_ia_min_1','u_ia_min_1','d_ia_min_3','u_ia_min_3','d_ia_min_5','u_ia_min_5','d_ia_min_10','u_ia_min_10','d_ia_min_20','u_ia_min_20','d_ia_min_all','u_ia_min_all',
                                                'd_pk_size_mean_05','u_pk_size_mean_05','d_pk_size_mean_1','u_pk_size_mean_1','d_pk_size_mean_3','u_pk_size_mean_3','d_pk_size_mean_5','u_pk_size_mean_5','d_pk_size_mean_10','u_pk_size_mean_10','d_pk_size_mean_20','u_pk_size_mean_20','d_pk_size_mean_all','u_pk_size_mean_all',
                                                'd_pk_size_median_05','u_pk_size_median_05','d_pk_size_median_1','u_pk_size_median_1','d_pk_size_median_3','u_pk_size_median_3','d_pk_size_median_5','u_pk_size_medina_5','d_pk_size_median_10','u_pk_size_median_10','d_pk_size_median_20','u_pk_size_median_20','d_pk_size_median_all','u_pk_size_median_all',
                                                'd_pk_size_std_05','u_pk_size_std_05','d_pk_size_std_1','u_pk_size_std_1','d_pk_size_std_3','u_pk_size_std_3','d_pk_size_std_5','u_pk_size_std_5','d_pk_size_std_10','u_pk_size_std_10','d_pk_size_std_20','u_pk_size_std_20','d_pk_size_std_all','u_pk_size_std_all',
                                                'd_pk_size_max_05','u_pk_size_max_05','d_pk_size_max_1','u_pk_size_max_1','d_pk_size_max_3','u_pk_size_max_3','d_pk_size_max_5','u_pk_size_max_5','d_pk_size_max_10','u_pk_size_max_10','d_pk_size_max_20','u_pk_size_max_20','d_pk_size_max_all','u_pk_size_max_all',
                                                'd_pk_size_min_05','u_pk_size_min_05','d_pk_size_min_1','u_pk_size_min_1','d_pk_size_min_3','u_pk_size_min_3','d_pk_size_min_5','u_pk_size_min_5','d_pk_size_min_10','u_pk_size_min_10','d_pk_size_min_20','u_pk_size_min_20','d_pk_size_min_all','u_pk_size_min_all',
                                                'd_pk_size_gt100_mean_05','u_pk_size_gt100mean_05','d_pk_size_gt100_mean_1','u_pk_size_gt100_mean_1','d_pk_size_gt100_mean_3','u_pk_size_gt100_mean_3','d_pk_size_gt100_mean_5','u_pk_size_gt100_mean_5','d_pk_size_gt100_mean_10','u_pk_size_gt100_mean_10','d_pk_size_gt100_mean_20','u_pk_size_gt100_mean_20','d_pk_size_gt100_mean_all','u_pk_size_gt100_mean_all',
                                                'd_pk_size_gt100_median_05','u_pk_size_gt100_median_05','d_pk_size_gt100_median_1','u_pk_size_gt100_median_1','d_pk_size_gt100_median_3','u_pk_size_gt100_median_3','d_pk_size_gt100_median_5','u_pk_size_gt100_medina_5','d_pk_size_gt100_median_10','u_pk_size_gt100_median_10','d_pk_size_gt100_median_20','u_pk_size_gt100_median_20','d_pk_size_gt100_median_all','u_pk_size_gt100_median_all',
                                                'd_pk_size_std_gt100_05','u_pk_size_std_gt100_05','d_pk_size_std_gt100_1','u_pk_size_std_gt100_1','d_pk_size_std_gt100_3','u_pk_size_std_gt100_3','d_pk_size_std_gt100_5','u_pk_size_std_gt100_5','d_pk_size_std_gt100_10','u_pk_size_std_gt100_10','d_pk_size_std_gt100_20','u_pk_size_std_gt100_20','d_pk_size_std_gt100_all','u_pk_size_std_gt100_all',
                                                'd_pk_size_gt100_max_05','u_pk_size_gt100_max_05','d_pk_size_gt100_max_1','u_pk_size_gt100_max_1','d_pk_size_gt100_max_3','u_pk_size_gt100_max_3','d_pk_size_gt100_max_5','u_pk_size_gt100_max_5','d_pk_size_gt100_max_10','u_pk_size_gt100_max_10','d_pk_size_gt100_max_20','u_pk_size_gt100_max_20','d_pk_size_gt100_max_all','u_pk_size_gt100_max_all',
                                                'd_pk_size_gt100_min_05','u_pk_size_gt100_min_05','d_pk_size_gt100_min_1','u_pk_size_gt100_min_1','d_pk_size_gt100_min_3','u_pk_size_gt100_min_3','d_pk_size_gt100_min_5','u_pk_size_gt100_min_5','d_pk_size_gt100_min_10','u_pk_size_gt100_min_10','d_pk_size_gt100_min_20','u_pk_size_gt100_min_20','d_pk_size_gt100_min_all','u_pk_size_gt100_min_all'])

            

############################


    
####################################
                                        pcap =rdpcap('/media/loop/Backup/vm/tos1/'+str(it)+'/iteration_' + str(it)+ '_video_' + str(vd)+'_mode_'+(md)+ '_net_' + str(ii) +'_host_'+ str(ll)+ '_algo_' + str(mm)+ '_protocol_' + str(pp)+'_server_' + str(kk)+'/iteration_' + str(it)+ '_video_' + str(vd)+'_mode_'+(md)+ '_net_' + str(ii) +'_host_'+ str(ll)+ '_algo_' + str(mm)+ '_protocol_' + str(pp)+'_server_' + str(kk)+'_ap.pcap')


#### full connection
                                        connection=[];       
                                        flag=True
                                        for ppp in pcap:                               
                                            if (ppp.haslayer(TCP)):
                                                if (ppp[IP].dst == '10.0.0.1'):
                                                    if (ppp[TCP].flags == 'FA' or ppp[TCP].flags == 'F'):
                                                        connection.append(ppp[TCP].sport)
      
                                        start=int(0)
                                        end_time=180
                                        begin=0
                                        lll=len(xx)
                                        aaa=xx.iloc[lll-1,0]
                                        aaa=float(aaa)
                                        duration=aaa

                                      
## throughput bit per second and packet count per second interval
                                        kkk=0
                                        for i in np.arange(start, duration+0.5, 0.5):
                                            print(i)
                                            ul_05=0; dl_05=0; ul_1=0; dl_1=0;  ul_3=0; dl_3=0; ul_5=0; dl_5=0; ul_10=0; dl_10=0; ul_20=0; dl_20=0;ul_all=0; dl_all=0;
                                            
                                            uc_05=0; dc_05=0; uc_1=0; dc_1=0; uc_3=0; dc_3=0; uc_5=0; dc_5=0; uc_10=0; dc_10=0; uc_20=0; dc_20=0; uc_all=0; dc_all=0;
                                            uc_gt100_05=0; dc_gt100_05=0; uc_gt100_1=0; dc_gt100_1=0;  uc_gt100_3=0; dc_gt100_3=0; uc_gt100_5=0; dc_gt100_5=0;  uc_gt100_10=0; dc_gt100_10=0; uc_gt100_20=0; dc_gt100_20=0;uc_gt100_all=0; dc_gt100_all=0; 
                                            
                                            ua_05=0; da_05=0;ua_1=0; da_1=0;  ua_3=0; da_3=0; ua_5=0; da_5=0;  ua_10=0; da_10=0; ua_20=0; da_20=0; ua_all=0; da_all=0; 
                                            d_ia_05=[] ; u_ia_05=[] ;d_ia_1=[] ; u_ia_1=[] ; d_ia_3=[] ;u_ia_3=[] ;d_ia_5=[] ;u_ia_5=[] ; d_ia_10=[] ; u_ia_10=[] ; d_ia_20=[] ; u_ia_20=[] ;d_ia_all=[] ;u_ia_all=[];
                                            
                                            d_pk_size_05=[] ; u_pk_size_05=[] ;d_pk_size_1=[] ; u_pk_size_1=[] ;d_pk_size_3=[] ;u_pk_size_3=[] ;d_pk_size_5=[] ;u_pk_size_5=[] ;  d_pk_size_10=[] ; u_pk_size_10=[] ;  d_pk_size_20=[] ; u_pk_size_20=[] ;d_pk_size_all=[] ;u_pk_size_all=[];
                                            d_pk_size_gt100_05=[] ; u_pk_size_gt100_05=[] ;d_pk_size_gt100_1=[] ; u_pk_size_gt100_1=[] ;d_pk_size_gt100_3=[] ;u_pk_size_gt100_3=[] ;d_pk_size_gt100_5=[] ;u_pk_size_gt100_5=[] ; d_pk_size_gt100_10=[] ; u_pk_size_gt100_10=[] ; d_pk_size_gt100_20=[] ; u_pk_size_gt100_20=[] ;d_pk_size_gt100_all=[] ; u_pk_size_gt100_all=[];

                                            ut_05=begin; dt_05=begin;ut_1=begin; dt_1=begin;  ut_3=begin; dt_3=begin; ut_5=begin; dt_5=begin; ut_10=begin; dt_10=begin;ut_20=begin; dt_20=begin; ut_all=begin; dt_all=begin;

                                            for p in pcap:
                                                 
                                                # 0.5 sec window
                                                if (p.haslayer(TCP)) and ((float(p.time-pcap[0].time))>= i) and  ((float(p.time-pcap[0].time))< i+0.5) and (p[TCP].sport in connection or p[TCP].dport in connection):
                                                    
                                                    ## throughput and packet
                                                    if(p[IP].src== '10.0.0.1'):# downlink
                                                        dl_05=dl_05+(int(len(p[IP]))*8)
                                                        dc_05=dc_05+1
                                                        if int(len(p))>=100:# ignore ack pk
                                                            dc_gt100_05=dc_gt100_05+1

                                                        ## ia and packet size
                                                        da_05=float(p.time-dt_05)
                                                        d_ia_05.append(da_05)
                                                        dt_05=p.time
                                                        d_pk_size_05.append(int(len(p[IP])))
                                                        if int(len(p))>=100:# ignore ack pk
                                                            d_pk_size_gt100_05.append(int(len(p[IP])))
                                                        
                                                            
                                                    if(p[IP].dst== '10.0.0.1'):# uplink
                                                        ul_05=ul_05+(int(len(p[IP]))*8)
                                                        uc_05=uc_05+1
                                                        if int(len(p))>=100:# ignore ack pk
                                                            uc_gt100_05=uc_gt100_05+1
                                                        
                                                           ## ia and packet size
                                                        ua_05=float(p.time-ut_05)
                                                        u_ia_05.append(ua_05)
                                                        ut_05=p.time
                                                        u_pk_size_05.append(int(len(p[IP])))
                                                        if int(len(p))>=100:# ignore ack pk
                                                            u_pk_size_gt100_05.append(int(len(p[IP])))    
                                                   
                                                   
                                                        
                                                           
                                                # 1 sec window
                                                if (p.haslayer(TCP)) and ((float(p.time-pcap[0].time))>= i-0.5) and  ((float(p.time-pcap[0].time))< i+0.5) and (p[TCP].sport in connection or p[TCP].dport in connection):
                                                    
                                                    ## throughput and packet
                                                    if(p[IP].src== '10.0.0.1'):# downlink
                                                        dl_1=dl_1+(int(len(p[IP]))*8)
                                                        dc_1=dc_1+1
                                                        if int(len(p))>=100:# ignore ack pk
                                                            dc_gt100_1=dc_gt100_1+1

                                                        ## ia and packet size
                                                        da_1=float(p.time-dt_1)
                                                        d_ia_1.append(da_1)
                                                        dt_1=p.time
                                                        d_pk_size_1.append(int(len(p[IP])))
                                                        if int(len(p))>=100:# ignore ack pk
                                                            d_pk_size_gt100_1.append(int(len(p[IP])))
                                                        
                                                            
                                                    if(p[IP].dst== '10.0.0.1'):# uplink
                                                        ul_1=ul_1+(int(len(p[IP]))*8)
                                                        uc_1=uc_1+1
                                                        if int(len(p))>=100:# ignore ack pk
                                                            uc_gt100_1=uc_gt100_1+1
                                                        
                                                           ## ia and packet size
                                                        ua_1=float(p.time-ut_1)
                                                        u_ia_1.append(ua_1)
                                                        ut_1=p.time
                                                        u_pk_size_1.append(int(len(p[IP])))
                                                        if int(len(p))>=100:# ignore ack pk
                                                            u_pk_size_gt100_1.append(int(len(p[IP])))    
                                                   
                                                           
                                                    
                                                # 3 sec window                            
                                                if (p.haslayer(TCP)) and ((float(p.time-pcap[0].time))>= i-2.5) and  ((float(p.time-pcap[0].time))< i+0.5) and (p[TCP].sport in connection or p[TCP].dport in connection):
                                                    if(p[IP].src== '10.0.0.1'):# downlink
                                                        dl_3=dl_3+(int(len(p[IP]))*8)
                                                        dc_3=dc_3+1
                                                        if int(len(p))>=100:# ignore ack pk
                                                            dc_gt100_3=dc_gt100_3+1
                                                            
                                                        da_3=float(p.time-dt_3)
                                                        d_ia_3.append(da_3)
                                                        dt_3=p.time
                                                        d_pk_size_3.append(int(len(p[IP])))
                                                        if int(len(p))>=100:# ignore ack pk
                                                            d_pk_size_gt100_3.append(int(len(p[IP])))
                                                        
                                                            
                                                    if(p[IP].dst== '10.0.0.1'):# uplink
                                                        ul_3=ul_3+(int(len(p[IP]))*8)
                                                        uc_3=uc_3+1
                                                        if int(len(p))>=100:# ignore ack pk
                                                            uc_gt100_3=uc_gt100_3+1
                                                            
                                                        ua_3=float(p.time-ut_3)
                                                        u_ia_3.append(ua_3)
                                                        ut_3=p.time
                                                        u_pk_size_3.append(int(len(p[IP])))
                                                        if int(len(p))>=100:# ignore ack pk
                                                            u_pk_size_gt100_3.append(int(len(p[IP])))
                                                            
                                                        
                                                 # 5 sec window                            
                                                if (p.haslayer(TCP)) and ((float(p.time-pcap[0].time))>= i-4.5) and  ((float(p.time-pcap[0].time))< i+0.5) and (p[TCP].sport in connection or p[TCP].dport in connection):
                                                    if(p[IP].src== '10.0.0.1'):# downlink
                                                        dl_5=dl_5+(int(len(p[IP]))*8)
                                                        dc_5=dc_5+1
                                                        if int(len(p))>=100:# ignore ack pk
                                                            dc_gt100_5=dc_gt100_5+1
                                                            
                                                        da_5=float(p.time-dt_5)
                                                        d_ia_5.append(da_5)
                                                        dt_5=p.time
                                                        d_pk_size_5.append(int(len(p[IP])))
                                                        if int(len(p))>=100:# ignore ack pk
                                                            d_pk_size_gt100_5.append(int(len(p[IP])))
                                                        
                                                            
                                                    if(p[IP].dst== '10.0.0.1'):# uplink
                                                        ul_5=ul_5+(int(len(p[IP]))*8)
                                                        uc_5=uc_5+1
                                                        if int(len(p))>=100:# ignore ack pk
                                                            uc_gt100_5=uc_gt100_5+1
                                                            
                                                        ua_5=float(p.time-ut_5)
                                                        u_ia_5.append(ua_5)
                                                        ut_5=p.time
                                                        u_pk_size_5.append(int(len(p[IP])))
                                                        if int(len(p))>=100:# ignore ack pk
                                                            u_pk_size_gt100_5.append(int(len(p[IP])))
                                                            
                                                # 10 sec window           
                                                if (p.haslayer(TCP)) and ((float(p.time-pcap[0].time))>= i-9.5) and  ((float(p.time-pcap[0].time))< i+0.5) and (p[TCP].sport in connection or p[TCP].dport in connection):
                                                    
                                                    if(p[IP].src== '10.0.0.1'):# downlink
                                                        dl_10=dl_10+(int(len(p[IP]))*8)
                                                        dc_10=dc_10+1
                                                        if int(len(p))>=100:# ignore ack pk
                                                            dc_gt100_10=dc_gt100_10+1
                                                            
                                                        da_10=float(p.time-dt_10)
                                                        d_ia_10.append(da_10)
                                                        dt_10=p.time
                                                        d_pk_size_10.append(int(len(p[IP])))
                                                        if int(len(p))>=100:# ignore ack pk
                                                            d_pk_size_gt100_10.append(int(len(p[IP])))
                                                        
                                                            
                                                    if(p[IP].dst== '10.0.0.1'):# uplink
                                                        ul_10=ul_10+(int(len(p[IP]))*8)
                                                        uc_10=uc_10+1
                                                        if int(len(p))>=100:# ignore ack pk
                                                            uc_gt100_10=uc_gt100_10+1
                                                            
                                                        ua_10=float(p.time-ut_10)
                                                        u_ia_10.append(ua_10)
                                                        ut_10=p.time
                                                        u_pk_size_10.append(int(len(p[IP])))
                                                        if int(len(p))>=100:# ignore ack pk
                                                            u_pk_size_gt100_10.append(int(len(p[IP])))
                                                # 20 sec window           
                                                if (p.haslayer(TCP)) and ((float(p.time-pcap[0].time))>= i-19.5) and  ((float(p.time-pcap[0].time))< i+0.5) and (p[TCP].sport in connection or p[TCP].dport in connection):
                                                    
                                                    if(p[IP].src== '10.0.0.1'):# downlink
                                                        dl_20=dl_10+(int(len(p[IP]))*8)
                                                        dc_20=dc_10+1
                                                        if int(len(p))>=100:# ignore ack pk
                                                            dc_gt100_20=dc_gt100_20+1
                                                            
                                                        da_20=float(p.time-dt_20)
                                                        d_ia_20.append(da_20)
                                                        dt_20=p.time
                                                        d_pk_size_20.append(int(len(p[IP])))
                                                        if int(len(p))>=100:# ignore ack pk
                                                            d_pk_size_gt100_20.append(int(len(p[IP])))
                                                        
                                                            
                                                    if(p[IP].dst== '10.0.0.1'):# uplink
                                                        ul_20=ul_20+(int(len(p[IP]))*8)
                                                        uc_20=uc_20+1
                                                        if int(len(p))>=100:# ignore ack pk
                                                            uc_gt100_20=uc_gt100_20+1
                                                            
                                                        ua_20=float(p.time-ut_20)
                                                        u_ia_20.append(ua_20)
                                                        ut_20=p.time
                                                        u_pk_size_20.append(int(len(p[IP])))
                                                        if int(len(p))>=100:# ignore ack pk
                                                            u_pk_size_gt100_20.append(int(len(p[IP])))
                                                            
                                                        
                                                            
                                                            
                                                # past all time             
                                                if (p.haslayer(TCP)) and ((float(p.time-pcap[0].time))>= start) and  ((float(p.time-pcap[0].time))< i+0.5) and (p[TCP].sport in connection or p[TCP].dport in connection):
                                                    if(p[IP].src== '10.0.0.1'):# downlink
                                                        dl_all=dl_all+(int(len(p[IP]))*8)
                                                        dc_all=dc_all+1
                                                        if int(len(p))>=100:# ignore ack pk
                                                            dc_gt100_all=dc_gt100_all+1
                                                            
                                                        da_all=float(p.time-dt_all)
                                                        d_ia_all.append(da_all)
                                                        dt_all=p.time
                                                        d_pk_size_all.append(int(len(p[IP])))
                                                        if int(len(p))>=100:# ignore ack pk
                                                            d_pk_size_gt100_all.append(int(len(p[IP])))
                                                        
                                                        
                                                            
                                                            
                                                    if(p[IP].dst== '10.0.0.1'):# uplink
                                                        ul_all=ul_all+(int(len(p[IP]))*8)
                                                        uc_all=uc_all+1
                                                        if int(len(p))>=100:# ignore ack pk
                                                            uc_gt100_all=uc_gt100_all+1
                                                            
                                                        ua_all=float(p.time-ut_all)
                                                        u_ia_all.append(ua_all)
                                                        ut_all=p.time
                                                        u_pk_size_all.append(int(len(p[IP])))
                                                        if int(len(p))>=100:# ignore ack pk
                                                            u_pk_size_gt100_all.append(int(len(p[IP])))
                                                            
                                                        
                                                        
                                                            
                                                       
                                                            
                                                            
                                                     
                                                elif ((float(p.time-pcap[0].time))>= i+0.5):            
                                                #elif (p.haslayer(TCP)) and ((float(p.time-pcap[0].time))>= i+0.5) and (p[TCP].sport in connection or p[TCP].dport in connection):
                                                    
                                                  
                                                    if i==0:
                                                        temp=0.5
                                                    else:
                                                        temp=i
                                                  
                                                    #try:
                                            
                                                    if len( d_ia_05)==0:
                                                        d_ia_05.append(0)
                                                    if len( u_ia_05)==0:
                                                        u_ia_05.append(0)
                                                        
                                                    
                                                    if len( d_ia_1)==0:
                                                        d_ia_1.append(0)
                                                    if len( u_ia_1)==0:
                                                        u_ia_1.append(0)
                                                    
                                                    if len( d_ia_3)==0:
                                                        d_ia_3.append(0)
                                                    if len( u_ia_3)==0:
                                                        u_ia_3.append(0)
                                                    
                                                    if len( d_ia_5)==0:
                                                        d_ia_5.append(0)
                                                    if len( u_ia_5)==0:
                                                        u_ia_5.append(0)
                                                        
                                                   
                                                    
                                                    if len( d_ia_10)==0:
                                                        d_ia_10.append(0)
                                                    if len( u_ia_10)==0:
                                                        u_ia_10.append(0)
                                                    
                                                    if len( d_ia_20)==0:
                                                        d_ia_20.append(0)
                                                    if len( u_ia_20)==0:
                                                        u_ia_20.append(0)
                                                    
                                                    if len( d_ia_all)==0:
                                                        d_ia_all.append(0)
                                                    if len( u_ia_all)==0:
                                                        u_ia_all.append(0)
                                                        
                                                    if len(d_pk_size_05)==0:
                                                        d_pk_size_05.append(0)
                                                    if len(u_pk_size_05)==0:
                                                        u_pk_size_05.append(0)
                                                           
                                                    if len(d_pk_size_1)==0:
                                                        d_pk_size_1.append(0)
                                                    if len(u_pk_size_1)==0:
                                                        u_pk_size_1.append(0)
                                                           
                                                    if len( d_pk_size_3)==0:
                                                        d_pk_size_3.append(0)
                                                    if len(u_pk_size_3)==0:
                                                        u_pk_size_3.append(0)
                                                           
                                                    if len( d_pk_size_5)==0:
                                                        d_pk_size_5.append(0)
                                                    if len(u_pk_size_5)==0:
                                                        u_pk_size_5.append(0)
                                                           
                                                    if len( d_pk_size_10)==0:
                                                        d_pk_size_10.append(0)
                                                    if len(u_pk_size_10)==0:
                                                        u_pk_size_10.append(0)
                                                           
                                                    if len( d_pk_size_20)==0:
                                                        d_pk_size_20.append(0)
                                                    if len(u_pk_size_20)==0:
                                                        u_pk_size_20.append(0) 
                                                           
                                                    if len( d_pk_size_all)==0:
                                                        d_pk_size_all.append(0)
                                                    if len(u_pk_size_all)==0:
                                                        u_pk_size_all.append(0)
                                                    
                                                    
                                                    if len(d_pk_size_gt100_05)==0:
                                                        d_pk_size_gt100_05.append(0)
                                                    if len(u_pk_size_gt100_05)==0:
                                                        u_pk_size_gt100_05.append(0)
                                                           
                                                    if len(d_pk_size_gt100_1)==0:
                                                        d_pk_size_gt100_1.append(0)
                                                    if len(u_pk_size_gt100_1)==0:
                                                        u_pk_size_gt100_1.append(0)
                                                           
                                                    if len( d_pk_size_gt100_3)==0:
                                                        d_pk_size_gt100_3.append(0)
                                                    if len(u_pk_size_gt100_3)==0:
                                                        u_pk_size_gt100_3.append(0)
                                                           
                                                    if len( d_pk_size_gt100_5)==0:
                                                        d_pk_size_gt100_5.append(0)
                                                    if len(u_pk_size_gt100_5)==0:
                                                        u_pk_size_gt100_5.append(0)
                                                           
                                                    if len( d_pk_size_gt100_10)==0:
                                                        d_pk_size_gt100_10.append(0)
                                                    if len(u_pk_size_gt100_10)==0:
                                                        u_pk_size_gt100_10.append(0)
                                                           
                                                    if len( d_pk_size_gt100_20)==0:
                                                        d_pk_size_gt100_20.append(0)
                                                    if len(u_pk_size_gt100_20)==0:
                                                        u_pk_size_gt100_20.append(0) 
                                                           
                                                    if len( d_pk_size_gt100_all)==0:
                                                        d_pk_size_gt100_all.append(0)
                                                    if len(u_pk_size_gt100_all)==0:
                                                        u_pk_size_gt100_all.append(0)
                                                    
                                                             
                                                        
                                                   
                                                 
                                                            
                                                        
                                                    data.loc[i]=[ it, md , ii, vd, kk, ll, mm, pp, \
                                                                  xx.iloc[kkk,0], xx.iloc[kkk,5],xx.iloc[kkk,8],xx.iloc[kkk,9],xx.iloc[kkk,10], \
                                                                  dl_05/0.5, ul_05/0.5, dl_1/1, ul_1/1, dl_3/3, ul_3/3, dl_5/5, ul_5/5,dl_10/10, ul_10/10,dl_20/20, ul_20/20, dl_all/temp, ul_all/temp, \
                                                                  dc_05, uc_05, dc_1, uc_1, dc_3, uc_3, dc_5, uc_5,dc_10, uc_10,dc_20, uc_20, dc_all, uc_all,\
                                                                  dc_gt100_05, uc_gt100_05,dc_gt100_1, uc_gt100_1, dc_gt100_3, uc_gt100_3, dc_gt100_5, uc_gt100_5, dc_gt100_10, uc_gt100_10, dc_gt100_20, uc_gt100_20, dc_gt100_all, uc_gt100_all,\
                                                                  np.mean(d_ia_05), np.mean(u_ia_05),np.mean(d_ia_1), np.mean(u_ia_1), np.mean(d_ia_3), np.mean(u_ia_3),  np.mean(d_ia_5), np.mean(u_ia_5), np.mean(d_ia_10), np.mean(u_ia_10), np.mean(d_ia_20), np.mean(u_ia_20), np.mean(d_ia_all), np.mean(u_ia_all), \
                                                                  np.median(d_ia_05), np.median(u_ia_05), np.median(d_ia_1),np.median(u_ia_1), np.median(d_ia_3), np.median(u_ia_3), np.median(d_ia_5),np.median(u_ia_5), np.median(d_ia_10),np.median(u_ia_10), np.median(d_ia_20),np.median(u_ia_20), np.median(d_ia_all), np.median(u_ia_all), \
                                                                  np.std(d_ia_05), np.std(u_ia_05), np.std(d_ia_1), np.std(u_ia_1), np.std(d_ia_3), np.std(u_ia_3),  np.std(d_ia_5), np.std(u_ia_5),np.std(d_ia_10), np.std(u_ia_10),np.std(d_ia_20), np.std(u_ia_20), np.std(d_ia_all), np.std(u_ia_all), \
                                                                  np.max(d_ia_05), np.max(u_ia_05),  np.max(d_ia_1), np.max(u_ia_1), np.max(d_ia_3), np.max(u_ia_3),  np.max(d_ia_5), np.max(u_ia_5),np.max(d_ia_10), np.max(u_ia_10), np.max(d_ia_20), np.max(u_ia_20),   np.max(d_ia_all), np.max(u_ia_all), \
                                                                  np.min(d_ia_05), np.min(u_ia_05), np.min(d_ia_1), np.min(u_ia_1), np.min(d_ia_3), np.min(u_ia_3),  np.min(d_ia_5), np.min(u_ia_5),np.min(d_ia_10), np.min(u_ia_10),np.min(d_ia_20), np.min(u_ia_20),    np.min(d_ia_all), np.min(u_ia_all),\
                                                                  np.mean(d_pk_size_05), np.mean(u_pk_size_05),np.mean(d_pk_size_1), np.mean(u_pk_size_1), np.mean(d_pk_size_3), np.mean(u_pk_size_3),  np.mean(d_pk_size_5), np.mean(u_pk_size_5),np.mean(d_pk_size_10), np.mean(u_pk_size_10),np.mean(d_pk_size_20), np.mean(u_pk_size_20), np.mean(d_pk_size_all), np.mean(u_pk_size_all), \
                                                                  np.median(d_pk_size_05), np.median(u_pk_size_05), np.median(d_pk_size_1), np.median(u_pk_size_1), np.median(d_pk_size_3), np.median(u_pk_size_3),  np.median(d_pk_size_5), np.median(u_pk_size_5), np.median(d_pk_size_10), np.median(u_pk_size_10),  np.median(d_pk_size_20), np.median(u_pk_size_20), np.median(d_pk_size_all), np.median(u_pk_size_all), \
                                                                  np.std(d_pk_size_05), np.std(u_pk_size_05),np.std(d_pk_size_1), np.std(u_pk_size_1), np.std(d_pk_size_3), np.std(u_pk_size_3),  np.std(d_pk_size_5), np.std(u_pk_size_5), np.std(d_pk_size_10), np.std(u_pk_size_10), np.std(d_pk_size_20), np.std(u_pk_size_20),  np.std(d_pk_size_all), np.std(u_pk_size_all), \
                                                                  np.max(d_pk_size_05), np.max(u_pk_size_05),np.max(d_pk_size_1), np.max(u_pk_size_1), np.max(d_pk_size_3), np.max(u_pk_size_3),  np.max(d_pk_size_5), np.max(u_pk_size_5), np.max(d_pk_size_10), np.max(u_pk_size_10), np.max(d_pk_size_20), np.max(u_pk_size_20),np.max(d_pk_size_all), np.max(u_pk_size_all), \
                                                                  np.min(d_pk_size_05), np.min(u_pk_size_05),np.min(d_pk_size_1), np.min(u_pk_size_1), np.min(d_pk_size_3), np.min(u_pk_size_3),  np.min(d_pk_size_5), np.min(u_pk_size_5),  np.min(d_pk_size_10), np.min(u_pk_size_10),
                                                                  np.min(d_pk_size_20), np.min(u_pk_size_20), np.min(d_pk_size_all), np.min(u_pk_size_all), \
                                                                  np.mean(d_pk_size_gt100_05), np.mean(u_pk_size_gt100_05),np.mean(d_pk_size_gt100_1), np.mean(u_pk_size_gt100_1), np.mean(d_pk_size_gt100_3), np.mean(u_pk_size_gt100_3),  np.mean(d_pk_size_gt100_5), np.mean(u_pk_size_gt100_5),np.mean(d_pk_size_gt100_10), np.mean(u_pk_size_gt100_10),np.mean(d_pk_size_gt100_20), np.mean(u_pk_size_gt100_20), np.mean(d_pk_size_gt100_all), np.mean(u_pk_size_gt100_all), \
                                                                  np.median(d_pk_size_gt100_05), np.median(u_pk_size_gt100_05), np.median(d_pk_size_gt100_1), np.median(u_pk_size_gt100_1), np.median(d_pk_size_gt100_3), np.median(u_pk_size_gt100_3),  np.median(d_pk_size_gt100_5), np.median(u_pk_size_gt100_5), np.median(d_pk_size_gt100_10), np.median(u_pk_size_gt100_10),  np.median(d_pk_size_gt100_20), np.median(u_pk_size_gt100_20), np.median(d_pk_size_gt100_all), np.median(u_pk_size_gt100_all), \
                                                                  np.std(d_pk_size_gt100_05), np.std(u_pk_size_gt100_05),np.std(d_pk_size_gt100_1), np.std(u_pk_size_gt100_1), np.std(d_pk_size_gt100_3), np.std(u_pk_size_gt100_3),  np.std(d_pk_size_gt100_5), np.std(u_pk_size_gt100_5), np.std(d_pk_size_gt100_10), np.std(u_pk_size_gt100_10), np.std(d_pk_size_gt100_20), np.std(u_pk_size_gt100_20),  np.std(d_pk_size_gt100_all), np.std(u_pk_size_gt100_all), \
                                                                  np.max(d_pk_size_gt100_05), np.max(u_pk_size_gt100_05),np.max(d_pk_size_gt100_1), np.max(u_pk_size_gt100_1), np.max(d_pk_size_gt100_3), np.max(u_pk_size_gt100_3),  np.max(d_pk_size_gt100_5), np.max(u_pk_size_gt100_5), np.max(d_pk_size_gt100_10), np.max(u_pk_size_gt100_10), np.max(d_pk_size_gt100_20), np.max(u_pk_size_gt100_20),np.max(d_pk_size_gt100_all), np.max(u_pk_size_gt100_all), \
                                                                  np.min(d_pk_size_gt100_05), np.min(u_pk_size_gt100_05),np.min(d_pk_size_gt100_1), np.min(u_pk_size_gt100_1), np.min(d_pk_size_gt100_3), np.min(u_pk_size_gt100_3),  np.min(d_pk_size_gt100_5), np.min(u_pk_size_gt100_5),  np.min(d_pk_size_gt100_10), np.min(u_pk_size_gt100_10),np.min(d_pk_size_gt100_20), np.min(u_pk_size_gt100_20), np.min(d_pk_size_gt100_all), np.min(u_pk_size_gt100_all)

                                                        ]
                                                    ##pass
                                                    kkk=kkk+1
                                                    ul_05=0; dl_05=0;ul_1=0; dl_1=0;  ul_3=0; dl_3=0; ul_5=0; dl_5=0;ul_10=0; dl_10=0;ul_20=0; dl_20=0; ul_all=0; dl_all=0; 
                                                    uc_05=0; dc_05=0;uc_1=0; dc_1=0;  uc_3=0; dc_3=0; uc_5=0; dc_5=0; uc_10=0; dc_10=0; uc_20=0; dc_20=0; uc_all=0; dc_all=0; 
                                                    uc_gt100_05=0; dc_gt100_05=0; uc_gt100_1=0; dc_gt100_1=0;  uc_gt100_3=0; dc_gt100_3=0; uc_gt100_5=0; dc_gt100_5=0; uc_gt100_10=0; dc_gt100_10=0;uc_gt100_20=0; dc_gt100_20=0;   uc_gt100_all=0; dc_gt100_all=0; 
                                                    ua_05=0; da_05=0; ua_1=0; da_1=0;  ua_3=0; da_3=0; ua_5=0; da_5=0; ua_10=0; da_10=0; ua_20=0; da_20=0; ua_all=0; da_all=0; 
                                                    temp=0
                                                    break
                                        export_csv = data.to_csv ('/media/loop/Backup/vm/tos1/'+str(it)+'/iteration_' + str(it)+ '_video_' + str(vd)+'_mode_'+(md)+ '_net_' + str(ii) +'_host_'+ str(ll)+ '_algo_' + str(mm)+ '_protocol_' + str(pp)+'_server_' + str(kk)+'/realtime.csv', index = None, header=True)
                                        print('done')
                                        print('iteration_' + str(it)+ '_video_' + str(vd)+'_mode_'+(md)+ '_net_' + str(ii) +'_host_'+ str(ll)+ '_algo_' + str(mm)+ '_protocol_' + str(pp)+'_server_' + str(kk))
                                    except:
                                        
                                        pass

# %%
import pandas as pd
import logging


mode=['3g','4g','5g'] 
#mode=['5g'] 
host=[1] 

algo=['conventional','bba', 'arbiter','elastic','bba','logistic'] # adaptation algorithm  'elastic','bba','logistic'

#algo=['logistic'] 
net3= ['train', 'ferry','car','bus','metro'] # mobility for 3g

net4=['bus', 'train', 'static','car','pedestrian'] # mobility for 4g

net5=[ 'Static-1','Static-2', 'Static-3', 'Driving-1', 'Driving-2'] # mobility for 5g

prot=['tcp']

sertype=['WSGI']

video_id=['tos1']

iteration = 1

df= pd.DataFrame(columns= ['iteration','mode','mobility','video','server-type','host','algo','protocol',
                            'Time(s)','Stall_event','Bitrate', 'Resolution(w)','Resolution(h)',
                            'd_th_05','u_th_05','d_th_1','u_th_1','d_th_3','u_th_3','d_th_5','u_th_5','d_th_10','u_th_10','d_th_20','u_th_20','d_th_all','u_th_all',                      
                            'd_pk_05','u_pk_05','d_pk_1','u_pk_1','d_pk_3','u_pk_3','d_pk_5','u_pk_5','d_pk_10','u_pk_10','d_pk_20','u_pk_20','d_pk_all','u_pk_all',
                            'd_pkgt100_05','u_pkgt100_05','d_pkgt100_1','u_pkgt100_1','d_pkgt100_3','u_pkgt100_3','d_pkgt100_5','u_pkgt100_5','d_pkgt100_10','u_pkgt100_10','d_pkgt100_20','u_pkgt100_20','d_pkgt100_all','u_pkgt100_all',
                            'd_ia_mean_05','u_ia_mean_05','d_ia_mean_1','u_ia_mean_1','d_ia_mean_3','u_ia_mean_3','d_ia_mean_5','u_ia_mean_5','d_ia_mean_10','u_ia_mean_10','d_ia_mean_20','u_ia_mean_20','d_ia_mean_all','u_ia_mean_all',
                            'd_ia_median_05','u_ia_median_05','d_ia_median_1','u_ia_median_1','d_ia_median_3','u_ia_median_3','d_ia_median_5','u_ia_medina_5','d_ia_median_10','u_ia_median_10','d_ia_median_20','u_ia_median_20','d_ia_median_all','u_ia_median_all',
                            'd_ia_std_05','u_ia_std_05','d_ia_std_1','u_ia_std_1','d_ia_std_3','u_ia_std_3','d_ia_std_5','u_ia_std_5','d_ia_std_10','u_ia_std_10','d_ia_std_20','u_ia_std_20','d_ia_std_all','u_ia_std_all',
                            'd_ia_max_05','u_ia_max_05','d_ia_max_1','u_ia_max_1','d_ia_max_3','u_ia_max_3','d_ia_max_5','u_ia_max_5','d_ia_max_10','u_ia_max_10','d_ia_max_20','u_ia_max_20','d_ia_max_all','u_ia_max_all',
                            'd_ia_min_05','u_ia_min_05','d_ia_min_1','u_ia_min_1','d_ia_min_3','u_ia_min_3','d_ia_min_5','u_ia_min_5','d_ia_min_10','u_ia_min_10','d_ia_min_20','u_ia_min_20','d_ia_min_all','u_ia_min_all',
                            'd_pk_size_mean_05','u_pk_size_mean_05','d_pk_size_mean_1','u_pk_size_mean_1','d_pk_size_mean_3','u_pk_size_mean_3','d_pk_size_mean_5','u_pk_size_mean_5','d_pk_size_mean_10','u_pk_size_mean_10','d_pk_size_mean_20','u_pk_size_mean_20','d_pk_size_mean_all','u_pk_size_mean_all',
                            'd_pk_size_median_05','u_pk_size_median_05','d_pk_size_median_1','u_pk_size_median_1','d_pk_size_median_3','u_pk_size_median_3','d_pk_size_median_5','u_pk_size_medina_5','d_pk_size_median_10','u_pk_size_median_10','d_pk_size_median_20','u_pk_size_median_20','d_pk_size_median_all','u_pk_size_median_all',
                            'd_pk_size_std_05','u_pk_size_std_05','d_pk_size_std_1','u_pk_size_std_1','d_pk_size_std_3','u_pk_size_std_3','d_pk_size_std_5','u_pk_size_std_5','d_pk_size_std_10','u_pk_size_std_10','d_pk_size_std_20','u_pk_size_std_20','d_pk_size_std_all','u_pk_size_std_all',
                            'd_pk_size_max_05','u_pk_size_max_05','d_pk_size_max_1','u_pk_size_max_1','d_pk_size_max_3','u_pk_size_max_3','d_pk_size_max_5','u_pk_size_max_5','d_pk_size_max_10','u_pk_size_max_10','d_pk_size_max_20','u_pk_size_max_20','d_pk_size_max_all','u_pk_size_max_all',
                            'd_pk_size_min_05','u_pk_size_min_05','d_pk_size_min_1','u_pk_size_min_1','d_pk_size_min_3','u_pk_size_min_3','d_pk_size_min_5','u_pk_size_min_5','d_pk_size_min_10','u_pk_size_min_10','d_pk_size_min_20','u_pk_size_min_20','d_pk_size_min_all','u_pk_size_min_all',
                            'd_pk_size_gt100_mean_05','u_pk_size_gt100mean_05','d_pk_size_gt100_mean_1','u_pk_size_gt100_mean_1','d_pk_size_gt100_mean_3','u_pk_size_gt100_mean_3','d_pk_size_gt100_mean_5','u_pk_size_gt100_mean_5','d_pk_size_gt100_mean_10','u_pk_size_gt100_mean_10','d_pk_size_gt100_mean_20','u_pk_size_gt100_mean_20','d_pk_size_gt100_mean_all','u_pk_size_gt100_mean_all',
                            'd_pk_size_gt100_median_05','u_pk_size_gt100_median_05','d_pk_size_gt100_median_1','u_pk_size_gt100_median_1','d_pk_size_gt100_median_3','u_pk_size_gt100_median_3','d_pk_size_gt100_median_5','u_pk_size_gt100_medina_5','d_pk_size_gt100_median_10','u_pk_size_gt100_median_10','d_pk_size_gt100_median_20','u_pk_size_gt100_median_20','d_pk_size_gt100_median_all','u_pk_size_gt100_median_all',
                            'd_pk_size_std_gt100_05','u_pk_size_std_gt100_05','d_pk_size_std_gt100_1','u_pk_size_std_gt100_1','d_pk_size_std_gt100_3','u_pk_size_std_gt100_3','d_pk_size_std_gt100_5','u_pk_size_std_gt100_5','d_pk_size_std_gt100_10','u_pk_size_std_gt100_10','d_pk_size_std_gt100_20','u_pk_size_std_gt100_20','d_pk_size_std_gt100_all','u_pk_size_std_gt100_all',
                            'd_pk_size_gt100_max_05','u_pk_size_gt100_max_05','d_pk_size_gt100_max_1','u_pk_size_gt100_max_1','d_pk_size_gt100_max_3','u_pk_size_gt100_max_3','d_pk_size_gt100_max_5','u_pk_size_gt100_max_5','d_pk_size_gt100_max_10','u_pk_size_gt100_max_10','d_pk_size_gt100_max_20','u_pk_size_gt100_max_20','d_pk_size_gt100_max_all','u_pk_size_gt100_max_all',
                            'd_pk_size_gt100_min_05','u_pk_size_gt100_min_05','d_pk_size_gt100_min_1','u_pk_size_gt100_min_1','d_pk_size_gt100_min_3','u_pk_size_gt100_min_3','d_pk_size_gt100_min_5','u_pk_size_gt100_min_5','d_pk_size_gt100_min_10','u_pk_size_gt100_min_10','d_pk_size_gt100_min_20','u_pk_size_gt100_min_20','d_pk_size_gt100_min_all','u_pk_size_gt100_min_all'])

            


for it in range(iteration):
    it=it+5
    for md in mode:
            if md =='3g':
                net=net3
            elif md=='4g':
                net=net4
            elif md=='5g':
                net=net5
            for ii in net:
                for vd in video_id:
                    for kk in sertype:
                        for ll in host:
                            for mm in algo:
                                 for pp in prot:
                                        try:
                                            d= pd.read_csv('/media/loop/Backup/vm/tos1/'+str(it)+'/iteration_' + str(it)+ '_video_' + str(vd)+'_mode_'+(md)+ '_net_' + str(ii) +'_host_'+ str(ll)+ '_algo_' + str(mm)+ '_protocol_' + str(pp)+'_server_' + str(kk)+'/realtime.csv')
                                            #print(ii )
                                            df=df.append(d) 
                                            df.iloc[0:0]
                                          
                                        except:
                                            #logging.error('CSV filemissing: mode_'+str(md)+ '_net_'+str(ii)+'_doc_'+str(jj)+'_num_'+str(kk)+'_host_'+str(ll)+'_algo_'+str(mm))
                                            pass
       
        
export_csv = df.to_csv('/media/loop/Backup/vm/tos1/it_5_tcp.csv', index = None, header=True)

# %%
import pandas as pd
import logging

df= pd.DataFrame(columns= ['iteration','mode','mobility','video','server-type','host','algo','protocol',
                            'Time(s)','Stall_event','Bitrate', 'Resolution(w)','Resolution(h)',
                            'd_th_05','u_th_05','d_th_1','u_th_1','d_th_3','u_th_3','d_th_5','u_th_5','d_th_10','u_th_10','d_th_20','u_th_20','d_th_all','u_th_all',                      
                            'd_pk_05','u_pk_05','d_pk_1','u_pk_1','d_pk_3','u_pk_3','d_pk_5','u_pk_5','d_pk_10','u_pk_10','d_pk_20','u_pk_20','d_pk_all','u_pk_all',
                            'd_pkgt100_05','u_pkgt100_05','d_pkgt100_1','u_pkgt100_1','d_pkgt100_3','u_pkgt100_3','d_pkgt100_5','u_pkgt100_5','d_pkgt100_10','u_pkgt100_10','d_pkgt100_20','u_pkgt100_20','d_pkgt100_all','u_pkgt100_all',
                            'd_ia_mean_05','u_ia_mean_05','d_ia_mean_1','u_ia_mean_1','d_ia_mean_3','u_ia_mean_3','d_ia_mean_5','u_ia_mean_5','d_ia_mean_10','u_ia_mean_10','d_ia_mean_20','u_ia_mean_20','d_ia_mean_all','u_ia_mean_all',
                            'd_ia_median_05','u_ia_median_05','d_ia_median_1','u_ia_median_1','d_ia_median_3','u_ia_median_3','d_ia_median_5','u_ia_medina_5','d_ia_median_10','u_ia_median_10','d_ia_median_20','u_ia_median_20','d_ia_median_all','u_ia_median_all',
                            'd_ia_std_05','u_ia_std_05','d_ia_std_1','u_ia_std_1','d_ia_std_3','u_ia_std_3','d_ia_std_5','u_ia_std_5','d_ia_std_10','u_ia_std_10','d_ia_std_20','u_ia_std_20','d_ia_std_all','u_ia_std_all',
                            'd_ia_max_05','u_ia_max_05','d_ia_max_1','u_ia_max_1','d_ia_max_3','u_ia_max_3','d_ia_max_5','u_ia_max_5','d_ia_max_10','u_ia_max_10','d_ia_max_20','u_ia_max_20','d_ia_max_all','u_ia_max_all',
                            'd_ia_min_05','u_ia_min_05','d_ia_min_1','u_ia_min_1','d_ia_min_3','u_ia_min_3','d_ia_min_5','u_ia_min_5','d_ia_min_10','u_ia_min_10','d_ia_min_20','u_ia_min_20','d_ia_min_all','u_ia_min_all',
                            'd_pk_size_mean_05','u_pk_size_mean_05','d_pk_size_mean_1','u_pk_size_mean_1','d_pk_size_mean_3','u_pk_size_mean_3','d_pk_size_mean_5','u_pk_size_mean_5','d_pk_size_mean_10','u_pk_size_mean_10','d_pk_size_mean_20','u_pk_size_mean_20','d_pk_size_mean_all','u_pk_size_mean_all',
                            'd_pk_size_median_05','u_pk_size_median_05','d_pk_size_median_1','u_pk_size_median_1','d_pk_size_median_3','u_pk_size_median_3','d_pk_size_median_5','u_pk_size_medina_5','d_pk_size_median_10','u_pk_size_median_10','d_pk_size_median_20','u_pk_size_median_20','d_pk_size_median_all','u_pk_size_median_all',
                            'd_pk_size_std_05','u_pk_size_std_05','d_pk_size_std_1','u_pk_size_std_1','d_pk_size_std_3','u_pk_size_std_3','d_pk_size_std_5','u_pk_size_std_5','d_pk_size_std_10','u_pk_size_std_10','d_pk_size_std_20','u_pk_size_std_20','d_pk_size_std_all','u_pk_size_std_all',
                            'd_pk_size_max_05','u_pk_size_max_05','d_pk_size_max_1','u_pk_size_max_1','d_pk_size_max_3','u_pk_size_max_3','d_pk_size_max_5','u_pk_size_max_5','d_pk_size_max_10','u_pk_size_max_10','d_pk_size_max_20','u_pk_size_max_20','d_pk_size_max_all','u_pk_size_max_all',
                            'd_pk_size_min_05','u_pk_size_min_05','d_pk_size_min_1','u_pk_size_min_1','d_pk_size_min_3','u_pk_size_min_3','d_pk_size_min_5','u_pk_size_min_5','d_pk_size_min_10','u_pk_size_min_10','d_pk_size_min_20','u_pk_size_min_20','d_pk_size_min_all','u_pk_size_min_all',
                            'd_pk_size_gt100_mean_05','u_pk_size_gt100mean_05','d_pk_size_gt100_mean_1','u_pk_size_gt100_mean_1','d_pk_size_gt100_mean_3','u_pk_size_gt100_mean_3','d_pk_size_gt100_mean_5','u_pk_size_gt100_mean_5','d_pk_size_gt100_mean_10','u_pk_size_gt100_mean_10','d_pk_size_gt100_mean_20','u_pk_size_gt100_mean_20','d_pk_size_gt100_mean_all','u_pk_size_gt100_mean_all',
                            'd_pk_size_gt100_median_05','u_pk_size_gt100_median_05','d_pk_size_gt100_median_1','u_pk_size_gt100_median_1','d_pk_size_gt100_median_3','u_pk_size_gt100_median_3','d_pk_size_gt100_median_5','u_pk_size_gt100_medina_5','d_pk_size_gt100_median_10','u_pk_size_gt100_median_10','d_pk_size_gt100_median_20','u_pk_size_gt100_median_20','d_pk_size_gt100_median_all','u_pk_size_gt100_median_all',
                            'd_pk_size_std_gt100_05','u_pk_size_std_gt100_05','d_pk_size_std_gt100_1','u_pk_size_std_gt100_1','d_pk_size_std_gt100_3','u_pk_size_std_gt100_3','d_pk_size_std_gt100_5','u_pk_size_std_gt100_5','d_pk_size_std_gt100_10','u_pk_size_std_gt100_10','d_pk_size_std_gt100_20','u_pk_size_std_gt100_20','d_pk_size_std_gt100_all','u_pk_size_std_gt100_all',
                            'd_pk_size_gt100_max_05','u_pk_size_gt100_max_05','d_pk_size_gt100_max_1','u_pk_size_gt100_max_1','d_pk_size_gt100_max_3','u_pk_size_gt100_max_3','d_pk_size_gt100_max_5','u_pk_size_gt100_max_5','d_pk_size_gt100_max_10','u_pk_size_gt100_max_10','d_pk_size_gt100_max_20','u_pk_size_gt100_max_20','d_pk_size_gt100_max_all','u_pk_size_gt100_max_all',
                            'd_pk_size_gt100_min_05','u_pk_size_gt100_min_05','d_pk_size_gt100_min_1','u_pk_size_gt100_min_1','d_pk_size_gt100_min_3','u_pk_size_gt100_min_3','d_pk_size_gt100_min_5','u_pk_size_gt100_min_5','d_pk_size_gt100_min_10','u_pk_size_gt100_min_10','d_pk_size_gt100_min_20','u_pk_size_gt100_min_20','d_pk_size_gt100_min_all','u_pk_size_gt100_min_all'])

            
iteration = 5

for it in range(iteration):
    it=it+1
    try:
        d= pd.read_csv('/media/loop/Backup/vm/tos1/tcp/online/it_'+str(it)+'_tcp.csv')
        #print(ii )
        df=df.append(d) 
        df.iloc[0:0]

    except:
        #logging.error('CSV filemissing: mode_'+str(md)+ '_net_'+str(ii)+'_doc_'+str(jj)+'_num_'+str(kk)+'_host_'+str(ll)+'_algo_'+str(mm))
        pass
       
        
export_csv = df.to_csv('/media/loop/Backup/vm/tos1/tcp/online/tcp.csv', index = None, header=True)
