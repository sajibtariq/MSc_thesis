# %%
#import nest_asyncio
#nest_asyncio.apply()
import pandas as pd
#from scapy.all import *
import numpy as np
import pandas as pd
import os
mode=['3g','4g','5g'] 
#mode=['5g'] 
host=[1] 

algo=['conventional','bba', 'arbiter','elastic','bba','logistic'] # adaptation algorithm  'elastic','bba','logistic'

#algo=['logistic'] 
net3= ['train', 'ferry','car','bus','metro'] # mobility for 3g

net4=['bus', 'train', 'static','car','pedestrian'] # mobility for 4g

net5=[ 'Static-1','Static-2', 'Static-3', 'Driving-1', 'Driving-2'] # mobility for 5g

prot=['quic']

sertype=['WSGI']

video_id=['tos1']

iteration = 1


for it in range(iteration):
    it=it+5
    for md in mode:
            if md =='3g':
                net=net3
            elif md=='4g':
                net=net4
            elif md=='5g':
                net=net5
            for ii in net:
                for vd in video_id:
                    for kk in sertype:
                        for ll in host:
                            for mm in algo:
                                 for pp in prot:
                                    try:
                                        #data=pd.DataFrame(columns=['Time (s)','PB_status','Seg_no','Seg_start_ac','Seg_start_cus','Stall-event','Stall_du_ac','Stall_dur_cus','Bitrate','Width','Height'])

                                        xx=pd.read_csv('/media/loop/Backup/vm/tos1/'+str(it)+'/iteration_' + str(it)+ '_video_' + str(vd)+'_mode_'+(md)+ '_net_' + str(ii) +'_host_'+ str(ll)+ '_algo_' + str(mm)+ '_protocol_' + str(pp)+'_server_' + str(kk)+'/iteration_'  + str(it)+ '_video_' + str(vd)+'_mode_'+(md)+ '_net_' + str(ii) +'_host_'+ str(ll)+ '_algo_' + str(mm)+ '_protocol_' + str(pp)+'_server_' + str(kk)+'1.txt', delim_whitespace=True, header=None)
                                        avg=pd.DataFrame()
                                        #xx=pd.read_csv('/home/loop/Videos/log/tcp.txt', delim_whitespace=True, header=None)
                                        x=xx.drop([0])
                                        conditions = [
                                            (x[[12]]=='320'),
                                            (x[[12]]=='384'),
                                            (x[[12]]=='512'),
                                            (x[[12]]=='640'),
                                            (x[[12]]=='736'),
                                            (x[[12]]=='1280'),
                                            (x[[12]]=='1920') ]
                                        choices = ['1', '2', '3','4', '5', '6','7']
                                        x['quality'] = np.select(conditions, choices, default='None')
                                        
                                        x['prev_quality'] = x['quality'].shift()
                                        conditions = [
                                            (x['quality']==x['prev_quality']),
                                            (x['quality']!=x['prev_quality']) ]
                                        choices = ['0', '1' ]
                                        x['quality_switch'] = np.select(conditions, choices)
                                        a=((x['quality_switch'].value_counts()).values)
                                        b=int(a[1])-1

                                        #x['quality_switch'].value_counts().values
                                        duration=   180+ ((x[3].astype(int).sum())/1000)+ (int(x.iloc[1,1])/1000)

                                        avg['Actual_duration']= [int(180)]
                                        avg['Total_duration']= [duration]                                          
                                        avg['Avg_bitrate']= [x[4].astype(int).mean()]
                                        avg['Stall_ratio']= [(((x[3].astype(int).sum())/180000.00))*100] # stall ratio
                                        avg['Avg_quality']= [round(x['quality'].astype(int).mean())]
                                        avg['Avg_mos']=[x[18].astype(float).mean()]
                                        avg['Initial_delay']=[int(x.iloc[1,1])/1000] #sec
                                        avg['Quality_switch']=[int(b)] 
                                        print('done')
                                        export_csv = avg.to_csv ('/media/loop/Backup/vm/tos1/'+str(it)+'/iteration_' + str(it)+ '_video_' + str(vd)+'_mode_'+(md)+ '_net_' + str(ii) +'_host_'+ str(ll)+ '_algo_' + str(mm)+ '_protocol_' + str(pp)+'_server_' + str(kk)+'/average-log.csv', index = None, header=True)
                                    except:
                                        os.system('echo iteration_' + str(it)+ '_video_' + str(vd)+'_mode_'+(md)+ '_net_' + str(ii) +'_host_'+ str(ll)+ '_algo_' + str(mm)+ '_protocol_' + str(pp)+'_server_' + str(kk))

# %% [markdown]
# # QUIC

# %%
import pandas as pd
import logging


mode=['3g','4g','5g'] 
#mode=['5g'] 
host=[1] 

algo=['conventional','bba', 'arbiter','elastic','bba','logistic'] # adaptation algorithm  'elastic','bba','logistic'

#algo=['logistic'] 
net3= ['train', 'ferry','car','bus','metro'] # mobility for 3g

net4=['bus', 'train', 'static','car','pedestrian'] # mobility for 4g

net5=[ 'Static-1','Static-2', 'Static-3', 'Driving-1', 'Driving-2'] # mobility for 5g

prot=['quic']

sertype=['WSGI']

video_id=['tos1']

iteration = 1



            


for it in range(iteration):
    it=it+5
    for md in mode:
            if md =='3g':
                net=net3
            elif md=='4g':
                net=net4
            elif md=='5g':
                net=net5
            for ii in net:
                for vd in video_id:
                    for kk in sertype:
                        for ll in host:
                            for mm in algo:
                                 for pp in prot:
                                         #df= pd.DataFrame()
                                        df= pd.DataFrame(columns= ['iteration','mode','mobility','video','server-type','host','algo','protocol',
                                                                    'Total_duration','Avg_bitrate','Stall_ratio', 'Avg_quality','Avg_mos','Initial_delay', 'Quality_switch',
                                                                    'd_th_avg','d_th_median','d_th_max','d_th_min','d_th_std','d_th_f25','d_th_f50','d_th_l25','d_th_l50','d_th_p10', 'd_th_p20','d_th_p30',  'd_th_p40',  'd_th_p50',  'd_th_p60', 'd_th_p70',  'd_th_p80', 'd_th_p90',
                                                                    'u_th_avg','u_th_median','u_th_max','u_th_min','u_th_std','u_th_f25','u_th_f50','u_th_l25','u_th_l50','u_th_p10', 'u_th_p20','u_th_p30',  'u_th_p40',  'u_th_p50',  'u_th_p60', 'u_th_p70',  'u_th_p80', 'u_th_p90',        
                                                                    'd_pk_total','d_pk_avg','d_pk_median','d_pk_max','d_pk_min','d_pk_std','d_pk_f25','d_pk_f50','d_pk_l25','d_pk_l50','d_pk_p10', 'd_pk_p20','d_pk_p30',  'd_pk_p40',  'd_pk_p50',  'd_pk_p60', 'd_pk_p70',  'd_pk_p80', 'd_pk_p90',
                                                                    'u_pk_total','u_pk_avg','u_pk_median','u_pk_max','u_pk_min','u_pk_std','u_pk_f25','u_pk_f50','u_pk_l25','u_pk_l50','u_pk_p10', 'u_pk_p20','u_pk_p30',  'u_pk_p40',  'u_pk_p50',  'u_pk_p60', 'u_pk_p70',  'u_pk_p80', 'u_pk_p90',
                                                                    'd_pk_size_avg','d_pk_size_median','d_pk_size_max','d_pk_size_min','d_pk_size_std','d_pk_size_f25','d_pk_size_f50','d_pk_size_l25','d_pk_size_l50','d_pk_size_p10', 'd_pk_size_p20','d_pk_size_p30',  'd_pk_size_p40',  'd_pk_size_p50',  'd_pk_size_p60', 'd_pk_size_p70',  'd_pk_size_p80', 'd_pk_psize_90',
                                                                    'u_pk_size_avg','u_pk_size_median','u_pk_size_max','u_pk_size_min','u_pk_size_std','u_pk_size_f25','u_pk_size_f50','u_pk_size_l25','u_pk_size_l50','u_pk_size_p10', 'u_pk_size_p20','u_pk_size_p30',  'u_pk_size_p40',  'u_pk_size_p50',  'u_pk_size_p60', 'u_pk_size_p70',  'u_pk_size_p80', 'u_pk_size_p90',
                                                                    'd_ia_avg','d_ia_median','d_ia_max','d_ia_min','d_ia_std','d_ia_f25','d_ia_f50','d_ia_l25','d_ia_l50','d_ia_p10', 'd_ia_p20','d_ia_p30',  'd_ia_p40',  'd_ia_p50',  'd_ia_p60', 'd_ia_p70',  'd_ia_p80', 'd_ia_p90',
                                                                    'u_ia_avg','u_ia_median','u_ia_max','u_ia_min','u_ia_std','u_ia_f25','u_ia_f50','u_ia_l25','u_ia_l50','u_ia_p10', 'u_ia_p20','u_ia_p30',  'u_ia_p40',  'u_ia_p50',  'u_ia_p60', 'u_ia_p70',  'u_ia_p80', 'u_ia_p90',        
                                                                  ])
                                        try:
                                            d= pd.read_csv('/media/loop/Backup/vm/tos1/'+str(it)+'/iteration_' + str(it)+ '_video_' + str(vd)+'_mode_'+(md)+ '_net_' + str(ii) +'_host_'+ str(ll)+ '_algo_' + str(mm)+ '_protocol_' + str(pp)+'_server_' + str(kk)+'/realtime.csv')

                                            xx= pd.read_csv('/media/loop/Backup/vm/tos1/'+str(it)+'/iteration_' + str(it)+ '_video_' + str(vd)+'_mode_'+(md)+ '_net_' + str(ii) +'_host_'+ str(ll)+ '_algo_' + str(mm)+ '_protocol_' + str(pp)+'_server_' + str(kk)+'/average-log.csv')
                                          
                                          
                                            ln=len(d)
                                            f2=int(ln/4)
                                            f5=int(ln/2)
                                            l2=int(ln-f2)
                                            
                                            df.loc[0]=[ it, md , ii, vd, kk, ll, mm, pp, \
                                                        xx.iloc[0,1], xx.iloc[0,2],xx.iloc[0,3],xx.iloc[0,4],xx.iloc[0,5], xx.iloc[0,6], xx.iloc[0,7], \
                                                        d.d_th_05.mean(), d.d_th_05.median(),d.d_th_05.max(),d.d_th_05.min(),d.d_th_05.std(), (d.d_th_05[0:f2]).mean(), (d.d_th_05[0:f5]).mean(), (d.d_th_05[l2:ln]).mean(), (d.d_th_05[f5:ln]).mean(), d['d_th_05'].quantile(.10),d['d_th_05'].quantile(.20),d['d_th_05'].quantile(.30),d['d_th_05'].quantile(.40),d['d_th_05'].quantile(.50),d['d_th_05'].quantile(.60),d['d_th_05'].quantile(.70),d['d_th_05'].quantile(.80),d['d_th_05'].quantile(.90), \
                                                        d.u_th_05.mean(), d.u_th_05.median(),d.u_th_05.max(),d.u_th_05.min(),d.u_th_05.std(), (d.u_th_05[0:f2]).mean(), (d.u_th_05[0:f5]).mean(), (d.u_th_05[l2:ln]).mean(), (d.u_th_05[f5:ln]).mean(), d['u_th_05'].quantile(.10),d['u_th_05'].quantile(.20),d['u_th_05'].quantile(.30),d['u_th_05'].quantile(.40),d['u_th_05'].quantile(.50),d['u_th_05'].quantile(.60),d['u_th_05'].quantile(.70),d['u_th_05'].quantile(.80),d['u_th_05'].quantile(.90), \
                                                        d.d_pk_05.sum(),d.d_pk_05.mean(), d.d_pk_05.median(),d.d_pk_05.max(),d.d_pk_05.min(),d.d_pk_05.std(), (d.d_pk_05[0:f2]).sum(), (d.d_pk_05[0:f5]).sum(), (d.d_pk_05[l2:ln]).sum(), (d.d_pk_05[f5:ln]).sum(), d['d_pk_05'].quantile(.10),d['d_pk_05'].quantile(.20),d['d_pk_05'].quantile(.30),d['d_pk_05'].quantile(.40),d['d_pk_05'].quantile(.50),d['d_pk_05'].quantile(.60),d['d_pk_05'].quantile(.70),d['d_pk_05'].quantile(.80),d['d_pk_05'].quantile(.90), \
                                                        d.u_pk_05.sum(),d.u_pk_05.mean(), d.u_pk_05.median(),d.u_pk_05.max(),d.u_pk_05.min(),d.u_pk_05.std(), (d.u_pk_05[0:f2]).sum(), (d.u_pk_05[0:f5]).sum(), (d.u_pk_05[l2:ln]).sum(), (d.u_pk_05[f5:ln]).sum(), d['u_pk_05'].quantile(.10),d['u_pk_05'].quantile(.20),d['u_pk_05'].quantile(.30),d['u_pk_05'].quantile(.40),d['u_pk_05'].quantile(.50),d['u_pk_05'].quantile(.60),d['u_pk_05'].quantile(.70),d['u_pk_05'].quantile(.80),d['u_pk_05'].quantile(.90), \
                                                        d.d_pk_size_mean_05.mean(), d.d_pk_size_mean_05.median(),d.d_pk_size_mean_05.max(),d.d_pk_size_mean_05.min(),d.d_pk_size_mean_05.std(), (d.d_pk_size_mean_05[0:f2]).mean(), (d.d_pk_size_mean_05[0:f5]).mean(), (d.d_pk_size_mean_05[l2:ln]).mean(), (d.d_pk_size_mean_05[f5:ln]).mean(), d['d_pk_size_mean_05'].quantile(.10),d['d_pk_size_mean_05'].quantile(.20),d['d_pk_size_mean_05'].quantile(.30),d['d_pk_size_mean_05'].quantile(.40),d['d_pk_size_mean_05'].quantile(.50),d['d_pk_size_mean_05'].quantile(.60),d['d_pk_size_mean_05'].quantile(.70),d['d_pk_size_mean_05'].quantile(.80),d['d_pk_size_mean_05'].quantile(.90), \
                                                        d.u_pk_size_mean_05.mean(), d.u_pk_size_mean_05.median(),d.u_pk_size_mean_05.max(),d.u_pk_size_mean_05.min(),d.u_pk_size_mean_05.std(), (d.u_pk_size_mean_05[0:f2]).mean(), (d.u_pk_size_mean_05[0:f5]).mean(), (d.u_pk_size_mean_05[l2:ln]).mean(), (d.u_pk_size_mean_05[f5:ln]).mean(), d['u_pk_size_mean_05'].quantile(.10),d['u_pk_size_mean_05'].quantile(.20),d['u_pk_size_mean_05'].quantile(.30),d['u_pk_size_mean_05'].quantile(.40),d['u_pk_size_mean_05'].quantile(.50),d['u_pk_size_mean_05'].quantile(.60),d['u_pk_size_mean_05'].quantile(.70),d['u_pk_size_mean_05'].quantile(.80),d['u_pk_size_mean_05'].quantile(.90), \
                                                        d.d_ia_mean_05.mean(), d.d_ia_mean_05.median(),d.d_ia_mean_05.max(),d.d_ia_mean_05.min(),d.d_ia_mean_05.std(), (d.d_ia_mean_05[0:f2]).mean(), (d.d_ia_mean_05[0:f5]).mean(), (d.d_ia_mean_05[l2:ln]).mean(), (d.d_ia_mean_05[f5:ln]).mean(), d['d_ia_mean_05'].quantile(.10),d['d_ia_mean_05'].quantile(.20),d['d_ia_mean_05'].quantile(.30),d['d_ia_mean_05'].quantile(.40),d['d_ia_mean_05'].quantile(.50),d['d_ia_mean_05'].quantile(.60),d['d_ia_mean_05'].quantile(.70),d['d_ia_mean_05'].quantile(.80),d['d_ia_mean_05'].quantile(.90), \
                                                        d.u_ia_mean_05.mean(), d.u_ia_mean_05.median(),d.u_ia_mean_05.max(),d.u_ia_mean_05.min(),d.u_ia_mean_05.std(), (d.u_ia_mean_05[0:f2]).mean(), (d.u_ia_mean_05[0:f5]).mean(), (d.u_ia_mean_05[l2:ln]).mean(), (d.u_ia_mean_05[f5:ln]).mean(), d['u_ia_mean_05'].quantile(.10),d['u_ia_mean_05'].quantile(.20),d['u_ia_mean_05'].quantile(.30),d['u_ia_mean_05'].quantile(.40),d['u_ia_mean_05'].quantile(.50),d['u_ia_mean_05'].quantile(.60),d['u_ia_mean_05'].quantile(.70),d['u_ia_mean_05'].quantile(.80),d['u_ia_mean_05'].quantile(.90), \
                                                     ]
                
                                            export_csv = df.to_csv ('/media/loop/Backup/vm/tos1/'+str(it)+'/iteration_' + str(it)+ '_video_' + str(vd)+'_mode_'+(md)+ '_net_' + str(ii) +'_host_'+ str(ll)+ '_algo_' + str(mm)+ '_protocol_' + str(pp)+'_server_' + str(kk)+'/offline.csv', index = None, header=True)
                                        except:
                                            #logging.error('CSV filemissing: mode_'+str(md)+ '_net_'+str(ii)+'_doc_'+str(jj)+'_num_'+str(kk)+'_host_'+str(ll)+'_algo_'+str(mm))
                                            pass

# %%
import pandas as pd
import logging


mode=['3g','4g','5g'] 
#mode=['5g'] 
host=[1] 

algo=['conventional','bba', 'arbiter','elastic','bba','logistic'] # adaptation algorithm  'elastic','bba','logistic'

#algo=['logistic'] 
net3= ['train', 'ferry','car','bus','metro'] # mobility for 3g

net4=['bus', 'train', 'static','car','pedestrian'] # mobility for 4g

net5=[ 'Static-1','Static-2', 'Static-3', 'Driving-1', 'Driving-2'] # mobility for 5g

prot=['quic']

sertype=['WSGI']

video_id=['tos1']

iteration = 1
df= pd.DataFrame(columns= ['iteration','mode','mobility','video','server-type','host','algo','protocol',
                            'Total_duration','Avg_bitrate','Stall_ratio', 'Avg_quality','Avg_mos','Initial_delay', 'Quality_switch',
                            'd_th_avg','d_th_median','d_th_max','d_th_min','d_th_std','d_th_f25','d_th_f50','d_th_l25','d_th_l50','d_th_p10', 'd_th_p20','d_th_p30',  'd_th_p40',  'd_th_p50',  'd_th_p60', 'd_th_p70',  'd_th_p80', 'd_th_p90',
                            'u_th_avg','u_th_median','u_th_max','u_th_min','u_th_std','u_th_f25','u_th_f50','u_th_l25','u_th_l50','u_th_p10', 'u_th_p20','u_th_p30',  'u_th_p40',  'u_th_p50',  'u_th_p60', 'u_th_p70',  'u_th_p80', 'u_th_p90',        
                            'd_pk_total','d_pk_avg','d_pk_median','d_pk_max','d_pk_min','d_pk_std','d_pk_f25','d_pk_f50','d_pk_l25','d_pk_l50','d_pk_p10', 'd_pk_p20','d_pk_p30',  'd_pk_p40',  'd_pk_p50',  'd_pk_p60', 'd_pk_p70',  'd_pk_p80', 'd_pk_p90',
                            'u_pk_total','u_pk_avg','u_pk_median','u_pk_max','u_pk_min','u_pk_std','u_pk_f25','u_pk_f50','u_pk_l25','u_pk_l50','u_pk_p10', 'u_pk_p20','u_pk_p30',  'u_pk_p40',  'u_pk_p50',  'u_pk_p60', 'u_pk_p70',  'u_pk_p80', 'u_pk_p90',
                            'd_pk_size_avg','d_pk_size_median','d_pk_size_max','d_pk_size_min','d_pk_size_std','d_pk_size_f25','d_pk_size_f50','d_pk_size_l25','d_pk_size_l50','d_pk_size_p10', 'd_pk_size_p20','d_pk_size_p30',  'd_pk_size_p40',  'd_pk_size_p50',  'd_pk_size_p60', 'd_pk_size_p70',  'd_pk_size_p80', 'd_pk_psize_90',
                            'u_pk_size_avg','u_pk_size_median','u_pk_size_max','u_pk_size_min','u_pk_size_std','u_pk_size_f25','u_pk_size_f50','u_pk_size_l25','u_pk_size_l50','u_pk_size_p10', 'u_pk_size_p20','u_pk_size_p30',  'u_pk_size_p40',  'u_pk_size_p50',  'u_pk_size_p60', 'u_pk_size_p70',  'u_pk_size_p80', 'u_pk_size_p90',
                            'd_ia_avg','d_ia_median','d_ia_max','d_ia_min','d_ia_std','d_ia_f25','d_ia_f50','d_ia_l25','d_ia_l50','d_ia_p10', 'd_ia_p20','d_ia_p30',  'd_ia_p40',  'd_ia_p50',  'd_ia_p60', 'd_ia_p70',  'd_ia_p80', 'd_ia_p90',
                            'u_ia_avg','u_ia_median','u_ia_max','u_ia_min','u_ia_std','u_ia_f25','u_ia_f50','u_ia_l25','u_ia_l50','u_ia_p10', 'u_ia_p20','u_ia_p30',  'u_ia_p40',  'u_ia_p50',  'u_ia_p60', 'u_ia_p70',  'u_ia_p80', 'u_ia_p90',        
                          ])

for it in range(iteration):
    it=it+4
    for md in mode:
            if md =='3g':
                net=net3
            elif md=='4g':
                net=net4
            elif md=='5g':
                net=net5
            for ii in net:
                for vd in video_id:
                    for kk in sertype:
                        for ll in host:
                            for mm in algo:
                                 for pp in prot:
                                        try:
                                            d= pd.read_csv('/media/loop/Backup/vm/tos1/'+str(it)+'/iteration_' + str(it)+ '_video_' + str(vd)+'_mode_'+(md)+ '_net_' + str(ii) +'_host_'+ str(ll)+ '_algo_' + str(mm)+ '_protocol_' + str(pp)+'_server_' + str(kk)+'/offline.csv')
                                            #print(ii )
                                            df=df.append(d) 
                                            df.iloc[0:0]
                                          
                                        except:
                                            #logging.error('CSV filemissing: mode_'+str(md)+ '_net_'+str(ii)+'_doc_'+str(jj)+'_num_'+str(kk)+'_host_'+str(ll)+'_algo_'+str(mm))
                                            pass
       
        
export_csv = df.to_csv('/media/loop/Backup/vm/tos1/it_4_quic_average.csv', index = None, header=True)

# %%
import pandas as pd
import logging


iteration = 5

df= pd.DataFrame(columns= ['iteration','mode','mobility','video','server-type','host','algo','protocol',
                            'Total_duration','Avg_bitrate','Stall_ratio', 'Avg_quality','Avg_mos','Initial_delay', 'Quality_switch',
                            'd_th_avg','d_th_median','d_th_max','d_th_min','d_th_std','d_th_f25','d_th_f50','d_th_l25','d_th_l50','d_th_p10', 'd_th_p20','d_th_p30',  'd_th_p40',  'd_th_p50',  'd_th_p60', 'd_th_p70',  'd_th_p80', 'd_th_p90',
                            'u_th_avg','u_th_median','u_th_max','u_th_min','u_th_std','u_th_f25','u_th_f50','u_th_l25','u_th_l50','u_th_p10', 'u_th_p20','u_th_p30',  'u_th_p40',  'u_th_p50',  'u_th_p60', 'u_th_p70',  'u_th_p80', 'u_th_p90',        
                            'd_pk_total','d_pk_avg','d_pk_median','d_pk_max','d_pk_min','d_pk_std','d_pk_f25','d_pk_f50','d_pk_l25','d_pk_l50','d_pk_p10', 'd_pk_p20','d_pk_p30',  'd_pk_p40',  'd_pk_p50',  'd_pk_p60', 'd_pk_p70',  'd_pk_p80', 'd_pk_p90',
                            'u_pk_total','u_pk_avg','u_pk_median','u_pk_max','u_pk_min','u_pk_std','u_pk_f25','u_pk_f50','u_pk_l25','u_pk_l50','u_pk_p10', 'u_pk_p20','u_pk_p30',  'u_pk_p40',  'u_pk_p50',  'u_pk_p60', 'u_pk_p70',  'u_pk_p80', 'u_pk_p90',
                            'd_pk_size_avg','d_pk_size_median','d_pk_size_max','d_pk_size_min','d_pk_size_std','d_pk_size_f25','d_pk_size_f50','d_pk_size_l25','d_pk_size_l50','d_pk_size_p10', 'd_pk_size_p20','d_pk_size_p30',  'd_pk_size_p40',  'd_pk_size_p50',  'd_pk_size_p60', 'd_pk_size_p70',  'd_pk_size_p80', 'd_pk_psize_90',
                            'u_pk_size_avg','u_pk_size_median','u_pk_size_max','u_pk_size_min','u_pk_size_std','u_pk_size_f25','u_pk_size_f50','u_pk_size_l25','u_pk_size_l50','u_pk_size_p10', 'u_pk_size_p20','u_pk_size_p30',  'u_pk_size_p40',  'u_pk_size_p50',  'u_pk_size_p60', 'u_pk_size_p70',  'u_pk_size_p80', 'u_pk_size_p90',
                            'd_ia_avg','d_ia_median','d_ia_max','d_ia_min','d_ia_std','d_ia_f25','d_ia_f50','d_ia_l25','d_ia_l50','d_ia_p10', 'd_ia_p20','d_ia_p30',  'd_ia_p40',  'd_ia_p50',  'd_ia_p60', 'd_ia_p70',  'd_ia_p80', 'd_ia_p90',
                            'u_ia_avg','u_ia_median','u_ia_max','u_ia_min','u_ia_std','u_ia_f25','u_ia_f50','u_ia_l25','u_ia_l50','u_ia_p10', 'u_ia_p20','u_ia_p30',  'u_ia_p40',  'u_ia_p50',  'u_ia_p60', 'u_ia_p70',  'u_ia_p80', 'u_ia_p90',        
                          ])

for it in range(iteration):
    it=it+1
    try:
        d= pd.read_csv('/media/loop/Backup/vm/tos1/tcp/offline/it_'+str(it)+'_quic_average.csv')
        #print(ii )
        df=df.append(d) 
        df.iloc[0:0]

    except:
        #logging.error('CSV filemissing: mode_'+str(md)+ '_net_'+str(ii)+'_doc_'+str(jj)+'_num_'+str(kk)+'_host_'+str(ll)+'_algo_'+str(mm))
        pass
       
        
export_csv = df.to_csv('/media/loop/Backup/vm/tos1/tcp/offline/quic_average.csv', index = None, header=True)

# %% [markdown]
# # TCP

# %%
import pandas as pd
import logging


mode=['3g','4g','5g'] 
#mode=['5g'] 
host=[1] 

algo=['conventional','bba', 'arbiter','elastic','bba','logistic'] # adaptation algorithm  'elastic','bba','logistic'

#algo=['logistic'] 
net3= ['train', 'ferry','car','bus','metro'] # mobility for 3g

net4=['bus', 'train', 'static','car','pedestrian'] # mobility for 4g

net5=[ 'Static-1','Static-2', 'Static-3', 'Driving-1', 'Driving-2'] # mobility for 5g

prot=['tcp']

sertype=['WSGI']

video_id=['tos1']

iteration = 1



            


for it in range(iteration):
    it=it+5
    for md in mode:
            if md =='3g':
                net=net3
            elif md=='4g':
                net=net4
            elif md=='5g':
                net=net5
            for ii in net:
                for vd in video_id:
                    for kk in sertype:
                        for ll in host:
                            for mm in algo:
                                 for pp in prot:  
                                          #df= pd.DataFrame()
                                        df= pd.DataFrame(columns= ['iteration','mode','mobility','video','server-type','host','algo','protocol',
                                                                    'Total_duration','Avg_bitrate','Stall_ratio', 'Avg_quality','Avg_mos','Initial_delay', 'Quality_switch',
                                                                    'd_th_avg','d_th_median','d_th_max','d_th_min','d_th_std','d_th_f25','d_th_f50','d_th_l25','d_th_l50','d_th_p10', 'd_th_p20','d_th_p30',  'd_th_p40',  'd_th_p50',  'd_th_p60', 'd_th_p70',  'd_th_p80', 'd_th_p90',
                                                                    'u_th_avg','u_th_median','u_th_max','u_th_min','u_th_std','u_th_f25','u_th_f50','u_th_l25','u_th_l50','u_th_p10', 'u_th_p20','u_th_p30',  'u_th_p40',  'u_th_p50',  'u_th_p60', 'u_th_p70',  'u_th_p80', 'u_th_p90',        
                                                                    'd_pk_total','d_pk_avg','d_pk_median','d_pk_max','d_pk_min','d_pk_std','d_pk_f25','d_pk_f50','d_pk_l25','d_pk_l50','d_pk_p10', 'd_pk_p20','d_pk_p30',  'd_pk_p40',  'd_pk_p50',  'd_pk_p60', 'd_pk_p70',  'd_pk_p80', 'd_pk_p90',
                                                                    'u_pk_total','u_pk_avg','u_pk_median','u_pk_max','u_pk_min','u_pk_std','u_pk_f25','u_pk_f50','u_pk_l25','u_pk_l50','u_pk_p10', 'u_pk_p20','u_pk_p30',  'u_pk_p40',  'u_pk_p50',  'u_pk_p60', 'u_pk_p70',  'u_pk_p80', 'u_pk_p90',
                                                                    'd_pkgt100_total','d_pkgt100_avg','d_pkgt100_median','d_pkgt100_max','d_pkgt100_min','d_pkgt100_std','d_pkgt100_f25','d_pkgt100_f50','d_pkgt100_l25','d_pkgt100_l50','d_pkgt100_p10', 'd_pkgt100_p20','d_pkgt100_p30',  'd_pkgt100_p40',  'd_pkgt100_p50',  'd_pkgt100_p60', 'd_pkgt100_p70',  'd_pkgt100_p80', 'd_pkgt100_p90',
                                                                    'u_pkgt100_total','u_pkgt100_avg','u_pkgt100_median','u_pkgt100_max','u_pkgt100_min','u_pkgt100_std','u_pkgt100_f25','u_pkgt100_f50','u_pkgt100_l25','u_pkgt100_l50','u_pkgt100_p10', 'u_pkgt100_p20','u_pkgt100_p30',  'u_pkgt100_p40',  'u_pkgt100_p50',  'u_pkgt100_p60', 'u_pkgt100_p70',  'u_pkgt100_p80', 'u_pkgt100_p90',
                                                                    'd_pk_size_avg','d_pk_size_median','d_pk_size_max','d_pk_size_min','d_pk_size_std','d_pk_size_f25','d_pk_size_f50','d_pk_size_l25','d_pk_size_l50','d_pk_size_p10', 'd_pk_size_p20','d_pk_size_p30',  'd_pk_size_p40',  'd_pk_size_p50',  'd_pk_size_p60', 'd_pk_size_p70',  'd_pk_size_p80', 'd_pk_psize_90',
                                                                    'u_pk_size_avg','u_pk_size_median','u_pk_size_max','u_pk_size_min','u_pk_size_std','u_pk_size_f25','u_pk_size_f50','u_pk_size_l25','u_pk_size_l50','u_pk_size_p10', 'u_pk_size_p20','u_pk_size_p30',  'u_pk_size_p40',  'u_pk_size_p50',  'u_pk_size_p60', 'u_pk_size_p70',  'u_pk_size_p80', 'u_pk_size_p90',
                                                                    'd_pk_size_gt100_avg','d_pk_size_gt100_median','d_pk_size_gt100_max','d_pk_size_gt100_min','d_pk_size_gt100_std','d_pk_size_gt100_f25','d_pk_size_gt100_f50','d_pk_size_gt100_l25','d_pk_size_gt100_l50','d_pk_size_gt100_p10', 'd_pk_size_gt100_p20','d_pk_size_gt100_p30',  'd_pk_size_gt100_p40',  'd_pk_size_gt100_p50',  'd_pk_size_gt100_p60', 'd_pk_size_gt100_p70',  'd_pk_size_gt100_p80', 'd_pk_gt100_p90',
                                                                    'u_pk_size_gt100_avg','u_pk_size_gt100_median','u_pk_size_gt100_max','u_pk_size_gt100_min','u_pk_size_gt100_std','u_pk_size_gt100_f25','u_pk_size_gt100_f50','u_pk_size_gt100_l25','u_pk_size_gt100_l50','u_pk_size_gt100_p10', 'u_pk_size_gt100_p20','u_pk_size_gt100_p30',  'u_pk_size_gt100_p40',  'u_pk_size_gt100_p50',  'u_pk_size_gt100_p60', 'u_pk_size_gt100_p70',  'u_pk_size_gt100_p80', 'u_pk_size_gt100_p90',
                                                                    'd_ia_avg','d_ia_median','d_ia_max','d_ia_min','d_ia_std','d_ia_f25','d_ia_f50','d_ia_l25','d_ia_l50','d_ia_p10', 'd_ia_p20','d_ia_p30',  'd_ia_p40',  'd_ia_p50',  'd_ia_p60', 'd_ia_p70',  'd_ia_p80', 'd_ia_p90',
                                                                    'u_ia_avg','u_ia_median','u_ia_max','u_ia_min','u_ia_std','u_ia_f25','u_ia_f50','u_ia_l25','u_ia_l50','u_ia_p10', 'u_ia_p20','u_ia_p30',  'u_ia_p40',  'u_ia_p50',  'u_ia_p60', 'u_ia_p70',  'u_ia_p80', 'u_ia_p90',        
                                                                  ])
                                        try:
                                            d= pd.read_csv('/media/loop/Backup/vm/tos1/'+str(it)+'/iteration_' + str(it)+ '_video_' + str(vd)+'_mode_'+(md)+ '_net_' + str(ii) +'_host_'+ str(ll)+ '_algo_' + str(mm)+ '_protocol_' + str(pp)+'_server_' + str(kk)+'/realtime.csv')

                                            xx= pd.read_csv('/media/loop/Backup/vm/tos1/'+str(it)+'/iteration_' + str(it)+ '_video_' + str(vd)+'_mode_'+(md)+ '_net_' + str(ii) +'_host_'+ str(ll)+ '_algo_' + str(mm)+ '_protocol_' + str(pp)+'_server_' + str(kk)+'/average-log.csv')
                                          
                                          
                                            ln=len(d)
                                            f2=int(ln/4)
                                            f5=int(ln/2)
                                            l2=int(ln-f2)
                                            
                                            df.loc[0]=[ it, md , ii, vd, kk, ll, mm, pp, \
                                                        xx.iloc[0,1], xx.iloc[0,2],xx.iloc[0,3],xx.iloc[0,4],xx.iloc[0,5], xx.iloc[0,6], xx.iloc[0,7], \
                                                        d.d_th_05.mean(), d.d_th_05.median(),d.d_th_05.max(),d.d_th_05.min(),d.d_th_05.std(), (d.d_th_05[0:f2]).mean(), (d.d_th_05[0:f5]).mean(), (d.d_th_05[l2:ln]).mean(), (d.d_th_05[f5:ln]).mean(), d['d_th_05'].quantile(.10),d['d_th_05'].quantile(.20),d['d_th_05'].quantile(.30),d['d_th_05'].quantile(.40),d['d_th_05'].quantile(.50),d['d_th_05'].quantile(.60),d['d_th_05'].quantile(.70),d['d_th_05'].quantile(.80),d['d_th_05'].quantile(.90), \
                                                        d.u_th_05.mean(), d.u_th_05.median(),d.u_th_05.max(),d.u_th_05.min(),d.u_th_05.std(), (d.u_th_05[0:f2]).mean(), (d.u_th_05[0:f5]).mean(), (d.u_th_05[l2:ln]).mean(), (d.u_th_05[f5:ln]).mean(), d['u_th_05'].quantile(.10),d['u_th_05'].quantile(.20),d['u_th_05'].quantile(.30),d['u_th_05'].quantile(.40),d['u_th_05'].quantile(.50),d['u_th_05'].quantile(.60),d['u_th_05'].quantile(.70),d['u_th_05'].quantile(.80),d['u_th_05'].quantile(.90), \
                                                        d.d_pk_05.sum(),d.d_pk_05.mean(), d.d_pk_05.median(),d.d_pk_05.max(),d.d_pk_05.min(),d.d_pk_05.std(), (d.d_pk_05[0:f2]).sum(), (d.d_pk_05[0:f5]).sum(), (d.d_pk_05[l2:ln]).sum(), (d.d_pk_05[f5:ln]).sum(), d['d_pk_05'].quantile(.10),d['d_pk_05'].quantile(.20),d['d_pk_05'].quantile(.30),d['d_pk_05'].quantile(.40),d['d_pk_05'].quantile(.50),d['d_pk_05'].quantile(.60),d['d_pk_05'].quantile(.70),d['d_pk_05'].quantile(.80),d['d_pk_05'].quantile(.90), \
                                                        d.u_pk_05.sum(),d.u_pk_05.mean(), d.u_pk_05.median(),d.u_pk_05.max(),d.u_pk_05.min(),d.u_pk_05.std(), (d.u_pk_05[0:f2]).sum(), (d.u_pk_05[0:f5]).sum(), (d.u_pk_05[l2:ln]).sum(), (d.u_pk_05[f5:ln]).sum(), d['u_pk_05'].quantile(.10),d['u_pk_05'].quantile(.20),d['u_pk_05'].quantile(.30),d['u_pk_05'].quantile(.40),d['u_pk_05'].quantile(.50),d['u_pk_05'].quantile(.60),d['u_pk_05'].quantile(.70),d['u_pk_05'].quantile(.80),d['u_pk_05'].quantile(.90), \
                                                        d.d_pkgt100_05.sum(),d.d_pkgt100_05.mean(), d.d_pkgt100_05.median(),d.d_pkgt100_05.max(),d.d_pkgt100_05.min(),d.d_pkgt100_05.std(), (d.d_pkgt100_05[0:f2]).sum(), (d.d_pkgt100_05[0:f5]).sum(), (d.d_pkgt100_05[l2:ln]).sum(), (d.d_pkgt100_05[f5:ln]).sum(), d['d_pkgt100_05'].quantile(.10),d['d_pkgt100_05'].quantile(.20),d['d_pkgt100_05'].quantile(.30),d['d_pkgt100_05'].quantile(.40),d['d_pkgt100_05'].quantile(.50),d['d_pkgt100_05'].quantile(.60),d['d_pkgt100_05'].quantile(.70),d['d_pkgt100_05'].quantile(.80),d['d_pkgt100_05'].quantile(.90), \
                                                        d.u_pkgt100_05.sum(),d.u_pkgt100_05.mean(), d.u_pkgt100_05.median(),d.u_pkgt100_05.max(),d.u_pkgt100_05.min(),d.u_pkgt100_05.std(), (d.u_pkgt100_05[0:f2]).sum(), (d.u_pkgt100_05[0:f5]).sum(), (d.u_pkgt100_05[l2:ln]).sum(), (d.u_pkgt100_05[f5:ln]).sum(), d['u_pkgt100_05'].quantile(.10),d['u_pkgt100_05'].quantile(.20),d['u_pkgt100_05'].quantile(.30),d['u_pkgt100_05'].quantile(.40),d['u_pkgt100_05'].quantile(.50),d['u_pkgt100_05'].quantile(.60),d['u_pkgt100_05'].quantile(.70),d['u_pkgt100_05'].quantile(.80),d['u_pkgt100_05'].quantile(.90), \
                                                        d.d_pk_size_mean_05.mean(), d.d_pk_size_mean_05.median(),d.d_pk_size_mean_05.max(),d.d_pk_size_mean_05.min(),d.d_pk_size_mean_05.std(), (d.d_pk_size_mean_05[0:f2]).mean(), (d.d_pk_size_mean_05[0:f5]).mean(), (d.d_pk_size_mean_05[l2:ln]).mean(), (d.d_pk_size_mean_05[f5:ln]).mean(), d['d_pk_size_mean_05'].quantile(.10),d['d_pk_size_mean_05'].quantile(.20),d['d_pk_size_mean_05'].quantile(.30),d['d_pk_size_mean_05'].quantile(.40),d['d_pk_size_mean_05'].quantile(.50),d['d_pk_size_mean_05'].quantile(.60),d['d_pk_size_mean_05'].quantile(.70),d['d_pk_size_mean_05'].quantile(.80),d['d_pk_size_mean_05'].quantile(.90), \
                                                        d.u_pk_size_mean_05.mean(), d.u_pk_size_mean_05.median(),d.u_pk_size_mean_05.max(),d.u_pk_size_mean_05.min(),d.u_pk_size_mean_05.std(), (d.u_pk_size_mean_05[0:f2]).mean(), (d.u_pk_size_mean_05[0:f5]).mean(), (d.u_pk_size_mean_05[l2:ln]).mean(), (d.u_pk_size_mean_05[f5:ln]).mean(), d['u_pk_size_mean_05'].quantile(.10),d['u_pk_size_mean_05'].quantile(.20),d['u_pk_size_mean_05'].quantile(.30),d['u_pk_size_mean_05'].quantile(.40),d['u_pk_size_mean_05'].quantile(.50),d['u_pk_size_mean_05'].quantile(.60),d['u_pk_size_mean_05'].quantile(.70),d['u_pk_size_mean_05'].quantile(.80),d['u_pk_size_mean_05'].quantile(.90), \
                                                        d.d_pk_size_gt100_mean_05.mean(), d.d_pk_size_gt100_mean_05.median(),d.d_pk_size_gt100_mean_05.max(),d.d_pk_size_gt100_mean_05.min(),d.d_pk_size_gt100_mean_05.std(), (d.d_pk_size_gt100_mean_05[0:f2]).mean(), (d.d_pk_size_gt100_mean_05[0:f5]).mean(), (d.d_pk_size_gt100_mean_05[l2:ln]).mean(), (d.d_pk_size_gt100_mean_05[f5:ln]).mean(), d['d_pk_size_gt100_mean_05'].quantile(.10),d['d_pk_size_gt100_mean_05'].quantile(.20),d['d_pk_size_gt100_mean_05'].quantile(.30),d['d_pk_size_gt100_mean_05'].quantile(.40),d['d_pk_size_gt100_mean_05'].quantile(.50),d['d_pk_size_gt100_mean_05'].quantile(.60),d['d_pk_size_gt100_mean_05'].quantile(.70),d['d_pk_size_gt100_mean_05'].quantile(.80),d['d_pk_size_gt100_mean_05'].quantile(.90), \
                                                        d.u_pk_size_gt100mean_05.mean(), d.u_pk_size_gt100mean_05.median(),d.u_pk_size_gt100mean_05.max(),d.u_pk_size_gt100mean_05.min(),d.u_pk_size_gt100mean_05.std(), (d.u_pk_size_gt100mean_05[0:f2]).mean(), (d.u_pk_size_gt100mean_05[0:f5]).mean(), (d.u_pk_size_gt100mean_05[l2:ln]).mean(), (d.u_pk_size_gt100mean_05[f5:ln]).mean(), d['u_pk_size_gt100mean_05'].quantile(.10),d['u_pk_size_gt100mean_05'].quantile(.20),d['u_pk_size_gt100mean_05'].quantile(.30),d['u_pk_size_gt100mean_05'].quantile(.40),d['u_pk_size_gt100mean_05'].quantile(.50),d['u_pk_size_gt100mean_05'].quantile(.60),d['u_pk_size_gt100mean_05'].quantile(.70),d['u_pk_size_gt100mean_05'].quantile(.80),d['u_pk_size_gt100mean_05'].quantile(.90), \
                                                        d.d_ia_mean_05.mean(), d.d_ia_mean_05.median(),d.d_ia_mean_05.max(),d.d_ia_mean_05.min(),d.d_ia_mean_05.std(), (d.d_ia_mean_05[0:f2]).mean(), (d.d_ia_mean_05[0:f5]).mean(), (d.d_ia_mean_05[l2:ln]).mean(), (d.d_ia_mean_05[f5:ln]).mean(), d['d_ia_mean_05'].quantile(.10),d['d_ia_mean_05'].quantile(.20),d['d_ia_mean_05'].quantile(.30),d['d_ia_mean_05'].quantile(.40),d['d_ia_mean_05'].quantile(.50),d['d_ia_mean_05'].quantile(.60),d['d_ia_mean_05'].quantile(.70),d['d_ia_mean_05'].quantile(.80),d['d_ia_mean_05'].quantile(.90), \
                                                        d.u_ia_mean_05.mean(), d.u_ia_mean_05.median(),d.u_ia_mean_05.max(),d.u_ia_mean_05.min(),d.u_ia_mean_05.std(), (d.u_ia_mean_05[0:f2]).mean(), (d.u_ia_mean_05[0:f5]).mean(), (d.u_ia_mean_05[l2:ln]).mean(), (d.u_ia_mean_05[f5:ln]).mean(), d['u_ia_mean_05'].quantile(.10),d['u_ia_mean_05'].quantile(.20),d['u_ia_mean_05'].quantile(.30),d['u_ia_mean_05'].quantile(.40),d['u_ia_mean_05'].quantile(.50),d['u_ia_mean_05'].quantile(.60),d['u_ia_mean_05'].quantile(.70),d['u_ia_mean_05'].quantile(.80),d['u_ia_mean_05'].quantile(.90), \
                                                     ]
                
                                            export_csv = df.to_csv ('/media/loop/Backup/vm/tos1/'+str(it)+'/iteration_' + str(it)+ '_video_' + str(vd)+'_mode_'+(md)+ '_net_' + str(ii) +'_host_'+ str(ll)+ '_algo_' + str(mm)+ '_protocol_' + str(pp)+'_server_' + str(kk)+'/offline.csv', index = None, header=True)
                                        except:
                                            #logging.error('CSV filemissing: mode_'+str(md)+ '_net_'+str(ii)+'_doc_'+str(jj)+'_num_'+str(kk)+'_host_'+str(ll)+'_algo_'+str(mm))
                                            pass

# %%
import pandas as pd
import logging


mode=['3g','4g','5g'] 
#mode=['5g'] 
host=[1] 

algo=['conventional','bba', 'arbiter','elastic','bba','logistic'] # adaptation algorithm  'elastic','bba','logistic'

#algo=['logistic'] 
net3= ['train', 'ferry','car','bus','metro'] # mobility for 3g

net4=['bus', 'train', 'static','car','pedestrian'] # mobility for 4g

net5=[ 'Static-1','Static-2', 'Static-3', 'Driving-1', 'Driving-2'] # mobility for 5g

prot=['tcp']

sertype=['WSGI']

video_id=['tos1']

iteration = 1

df= pd.DataFrame(columns= ['iteration','mode','mobility','video','server-type','host','algo','protocol',
                                                                    'Total_duration','Avg_bitrate','Stall_ratio', 'Avg_quality','Avg_mos','Initial_delay', 'Quality_switch',
                                                                    'd_th_avg','d_th_median','d_th_max','d_th_min','d_th_std','d_th_f25','d_th_f50','d_th_l25','d_th_l50','d_th_p10', 'd_th_p20','d_th_p30',  'd_th_p40',  'd_th_p50',  'd_th_p60', 'd_th_p70',  'd_th_p80', 'd_th_p90',
                                                                    'u_th_avg','u_th_median','u_th_max','u_th_min','u_th_std','u_th_f25','u_th_f50','u_th_l25','u_th_l50','u_th_p10', 'u_th_p20','u_th_p30',  'u_th_p40',  'u_th_p50',  'u_th_p60', 'u_th_p70',  'u_th_p80', 'u_th_p90',        
                                                                    'd_pk_total','d_pk_avg','d_pk_median','d_pk_max','d_pk_min','d_pk_std','d_pk_f25','d_pk_f50','d_pk_l25','d_pk_l50','d_pk_p10', 'd_pk_p20','d_pk_p30',  'd_pk_p40',  'd_pk_p50',  'd_pk_p60', 'd_pk_p70',  'd_pk_p80', 'd_pk_p90',
                                                                    'u_pk_total','u_pk_avg','u_pk_median','u_pk_max','u_pk_min','u_pk_std','u_pk_f25','u_pk_f50','u_pk_l25','u_pk_l50','u_pk_p10', 'u_pk_p20','u_pk_p30',  'u_pk_p40',  'u_pk_p50',  'u_pk_p60', 'u_pk_p70',  'u_pk_p80', 'u_pk_p90',
                                                                    'd_pkgt100_total','d_pkgt100_avg','d_pkgt100_median','d_pkgt100_max','d_pkgt100_min','d_pkgt100_std','d_pkgt100_f25','d_pkgt100_f50','d_pkgt100_l25','d_pkgt100_l50','d_pkgt100_p10', 'd_pkgt100_p20','d_pkgt100_p30',  'd_pkgt100_p40',  'd_pkgt100_p50',  'd_pkgt100_p60', 'd_pkgt100_p70',  'd_pkgt100_p80', 'd_pkgt100_p90',
                                                                    'u_pkgt100_total','u_pkgt100_avg','u_pkgt100_median','u_pkgt100_max','u_pkgt100_min','u_pkgt100_std','u_pkgt100_f25','u_pkgt100_f50','u_pkgt100_l25','u_pkgt100_l50','u_pkgt100_p10', 'u_pkgt100_p20','u_pkgt100_p30',  'u_pkgt100_p40',  'u_pkgt100_p50',  'u_pkgt100_p60', 'u_pkgt100_p70',  'u_pkgt100_p80', 'u_pkgt100_p90',
                                                                    'd_pk_size_avg','d_pk_size_median','d_pk_size_max','d_pk_size_min','d_pk_size_std','d_pk_size_f25','d_pk_size_f50','d_pk_size_l25','d_pk_size_l50','d_pk_size_p10', 'd_pk_size_p20','d_pk_size_p30',  'd_pk_size_p40',  'd_pk_size_p50',  'd_pk_size_p60', 'd_pk_size_p70',  'd_pk_size_p80', 'd_pk_psize_90',
                                                                    'u_pk_size_avg','u_pk_size_median','u_pk_size_max','u_pk_size_min','u_pk_size_std','u_pk_size_f25','u_pk_size_f50','u_pk_size_l25','u_pk_size_l50','u_pk_size_p10', 'u_pk_size_p20','u_pk_size_p30',  'u_pk_size_p40',  'u_pk_size_p50',  'u_pk_size_p60', 'u_pk_size_p70',  'u_pk_size_p80', 'u_pk_size_p90',
                                                                    'd_pk_size_gt100_avg','d_pk_size_gt100_median','d_pk_size_gt100_max','d_pk_size_gt100_min','d_pk_size_gt100_std','d_pk_size_gt100_f25','d_pk_size_gt100_f50','d_pk_size_gt100_l25','d_pk_size_gt100_l50','d_pk_size_gt100_p10', 'd_pk_size_gt100_p20','d_pk_size_gt100_p30',  'd_pk_size_gt100_p40',  'd_pk_size_gt100_p50',  'd_pk_size_gt100_p60', 'd_pk_size_gt100_p70',  'd_pk_size_gt100_p80', 'd_pk_gt100_p90',
                                                                    'u_pk_size_gt100_avg','u_pk_size_gt100_median','u_pk_size_gt100_max','u_pk_size_gt100_min','u_pk_size_gt100_std','u_pk_size_gt100_f25','u_pk_size_gt100_f50','u_pk_size_gt100_l25','u_pk_size_gt100_l50','u_pk_size_gt100_p10', 'u_pk_size_gt100_p20','u_pk_size_gt100_p30',  'u_pk_size_gt100_p40',  'u_pk_size_gt100_p50',  'u_pk_size_gt100_p60', 'u_pk_size_gt100_p70',  'u_pk_size_gt100_p80', 'u_pk_size_gt100_p90',
                                                                    'd_ia_avg','d_ia_median','d_ia_max','d_ia_min','d_ia_std','d_ia_f25','d_ia_f50','d_ia_l25','d_ia_l50','d_ia_p10', 'd_ia_p20','d_ia_p30',  'd_ia_p40',  'd_ia_p50',  'd_ia_p60', 'd_ia_p70',  'd_ia_p80', 'd_ia_p90',
                                                                    'u_ia_avg','u_ia_median','u_ia_max','u_ia_min','u_ia_std','u_ia_f25','u_ia_f50','u_ia_l25','u_ia_l50','u_ia_p10', 'u_ia_p20','u_ia_p30',  'u_ia_p40',  'u_ia_p50',  'u_ia_p60', 'u_ia_p70',  'u_ia_p80', 'u_ia_p90',        
                                                                  ])

for it in range(iteration):
    it=it+5
    for md in mode:
            if md =='3g':
                net=net3
            elif md=='4g':
                net=net4
            elif md=='5g':
                net=net5
            for ii in net:
                for vd in video_id:
                    for kk in sertype:
                        for ll in host:
                            for mm in algo:
                                 for pp in prot:
                                        try:
                                            d= pd.read_csv('/media/loop/Backup/vm/tos1/'+str(it)+'/iteration_' + str(it)+ '_video_' + str(vd)+'_mode_'+(md)+ '_net_' + str(ii) +'_host_'+ str(ll)+ '_algo_' + str(mm)+ '_protocol_' + str(pp)+'_server_' + str(kk)+'/offline.csv')
                                            #print(ii )
                                            df=df.append(d) 
                                            df.iloc[0:0]
                                          
                                        except:
                                            #logging.error('CSV filemissing: mode_'+str(md)+ '_net_'+str(ii)+'_doc_'+str(jj)+'_num_'+str(kk)+'_host_'+str(ll)+'_algo_'+str(mm))
                                            pass
       
        
export_csv = df.to_csv('/media/loop/Backup/vm/tos1/it_5_tcp_average.csv', index = None, header=True)

# %%
import pandas as pd
import logging


iteration = 5

df= pd.DataFrame(columns= ['iteration','mode','mobility','video','server-type','host','algo','protocol',
                                                                    'Total_duration','Avg_bitrate','Stall_ratio', 'Avg_quality','Avg_mos','Initial_delay', 'Quality_switch',
                                                                    'd_th_avg','d_th_median','d_th_max','d_th_min','d_th_std','d_th_f25','d_th_f50','d_th_l25','d_th_l50','d_th_p10', 'd_th_p20','d_th_p30',  'd_th_p40',  'd_th_p50',  'd_th_p60', 'd_th_p70',  'd_th_p80', 'd_th_p90',
                                                                    'u_th_avg','u_th_median','u_th_max','u_th_min','u_th_std','u_th_f25','u_th_f50','u_th_l25','u_th_l50','u_th_p10', 'u_th_p20','u_th_p30',  'u_th_p40',  'u_th_p50',  'u_th_p60', 'u_th_p70',  'u_th_p80', 'u_th_p90',        
                                                                    'd_pk_total','d_pk_avg','d_pk_median','d_pk_max','d_pk_min','d_pk_std','d_pk_f25','d_pk_f50','d_pk_l25','d_pk_l50','d_pk_p10', 'd_pk_p20','d_pk_p30',  'd_pk_p40',  'd_pk_p50',  'd_pk_p60', 'd_pk_p70',  'd_pk_p80', 'd_pk_p90',
                                                                    'u_pk_total','u_pk_avg','u_pk_median','u_pk_max','u_pk_min','u_pk_std','u_pk_f25','u_pk_f50','u_pk_l25','u_pk_l50','u_pk_p10', 'u_pk_p20','u_pk_p30',  'u_pk_p40',  'u_pk_p50',  'u_pk_p60', 'u_pk_p70',  'u_pk_p80', 'u_pk_p90',
                                                                    'd_pkgt100_total','d_pkgt100_avg','d_pkgt100_median','d_pkgt100_max','d_pkgt100_min','d_pkgt100_std','d_pkgt100_f25','d_pkgt100_f50','d_pkgt100_l25','d_pkgt100_l50','d_pkgt100_p10', 'd_pkgt100_p20','d_pkgt100_p30',  'd_pkgt100_p40',  'd_pkgt100_p50',  'd_pkgt100_p60', 'd_pkgt100_p70',  'd_pkgt100_p80', 'd_pkgt100_p90',
                                                                    'u_pkgt100_total','u_pkgt100_avg','u_pkgt100_median','u_pkgt100_max','u_pkgt100_min','u_pkgt100_std','u_pkgt100_f25','u_pkgt100_f50','u_pkgt100_l25','u_pkgt100_l50','u_pkgt100_p10', 'u_pkgt100_p20','u_pkgt100_p30',  'u_pkgt100_p40',  'u_pkgt100_p50',  'u_pkgt100_p60', 'u_pkgt100_p70',  'u_pkgt100_p80', 'u_pkgt100_p90',
                                                                    'd_pk_size_avg','d_pk_size_median','d_pk_size_max','d_pk_size_min','d_pk_size_std','d_pk_size_f25','d_pk_size_f50','d_pk_size_l25','d_pk_size_l50','d_pk_size_p10', 'd_pk_size_p20','d_pk_size_p30',  'd_pk_size_p40',  'd_pk_size_p50',  'd_pk_size_p60', 'd_pk_size_p70',  'd_pk_size_p80', 'd_pk_psize_90',
                                                                    'u_pk_size_avg','u_pk_size_median','u_pk_size_max','u_pk_size_min','u_pk_size_std','u_pk_size_f25','u_pk_size_f50','u_pk_size_l25','u_pk_size_l50','u_pk_size_p10', 'u_pk_size_p20','u_pk_size_p30',  'u_pk_size_p40',  'u_pk_size_p50',  'u_pk_size_p60', 'u_pk_size_p70',  'u_pk_size_p80', 'u_pk_size_p90',
                                                                    'd_pk_size_gt100_avg','d_pk_size_gt100_median','d_pk_size_gt100_max','d_pk_size_gt100_min','d_pk_size_gt100_std','d_pk_size_gt100_f25','d_pk_size_gt100_f50','d_pk_size_gt100_l25','d_pk_size_gt100_l50','d_pk_size_gt100_p10', 'd_pk_size_gt100_p20','d_pk_size_gt100_p30',  'd_pk_size_gt100_p40',  'd_pk_size_gt100_p50',  'd_pk_size_gt100_p60', 'd_pk_size_gt100_p70',  'd_pk_size_gt100_p80', 'd_pk_gt100_p90',
                                                                    'u_pk_size_gt100_avg','u_pk_size_gt100_median','u_pk_size_gt100_max','u_pk_size_gt100_min','u_pk_size_gt100_std','u_pk_size_gt100_f25','u_pk_size_gt100_f50','u_pk_size_gt100_l25','u_pk_size_gt100_l50','u_pk_size_gt100_p10', 'u_pk_size_gt100_p20','u_pk_size_gt100_p30',  'u_pk_size_gt100_p40',  'u_pk_size_gt100_p50',  'u_pk_size_gt100_p60', 'u_pk_size_gt100_p70',  'u_pk_size_gt100_p80', 'u_pk_size_gt100_p90',
                                                                    'd_ia_avg','d_ia_median','d_ia_max','d_ia_min','d_ia_std','d_ia_f25','d_ia_f50','d_ia_l25','d_ia_l50','d_ia_p10', 'd_ia_p20','d_ia_p30',  'd_ia_p40',  'd_ia_p50',  'd_ia_p60', 'd_ia_p70',  'd_ia_p80', 'd_ia_p90',
                                                                    'u_ia_avg','u_ia_median','u_ia_max','u_ia_min','u_ia_std','u_ia_f25','u_ia_f50','u_ia_l25','u_ia_l50','u_ia_p10', 'u_ia_p20','u_ia_p30',  'u_ia_p40',  'u_ia_p50',  'u_ia_p60', 'u_ia_p70',  'u_ia_p80', 'u_ia_p90',        
                                                                  ])

for it in range(iteration):
    it=it+1
    try:
        d= pd.read_csv('/media/loop/Backup/vm/tos1/tcp/offline/it_'+str(it)+'_tcp_average.csv')
        #print(ii )
        df=df.append(d) 
        df.iloc[0:0]

    except:
        #logging.error('CSV filemissing: mode_'+str(md)+ '_net_'+str(ii)+'_doc_'+str(jj)+'_num_'+str(kk)+'_host_'+str(ll)+'_algo_'+str(mm))
        pass
       
        
export_csv = df.to_csv('/media/loop/Backup/vm/tos1/tcp/offline/tcp_average.csv', index = None, header=True)
